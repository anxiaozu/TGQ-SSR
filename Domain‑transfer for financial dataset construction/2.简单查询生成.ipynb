# %%
schema_name = "fin_schema"

graph_path = "finbench"
graph_oid = 17368

label_where_key = {
    "account":"nickname",
    "company":"companyname",
    "person":"personname",
    "medium":"mediumtype",
}


exclude_return_keys = set({"type","label"})

# %%
list(label_where_key.keys())
# Out:
# ['account', 'company', 'person', 'medium']

# %% [markdown]
# ## 生成medical schmea的语句
# ```
# create graph medical_schema;
# set graph_path = medical_schema;
#
# create (n:node {name: 'first_level_departments'});
# create (n:node {name: 'second_level_departments'});
# create (n:node {name: 'inspection_means'});
# create (n:node {name: 'treatment_plan'});
# create (n:node {name: 'manufacturer'});
# create (n:node {name: 'disease'});
# create (n:node {name: 'symptoms'});
# create (n:node {name: 'drug'});
# create (n:node {name: 'food'});
# create (n:node {name: 'recipe'});
#
# match (n:node {name: 'disease'}),(m:node {name: 'drug'}) create (n)-[:relation {name:'highly_rated_medicines'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'food'}) create (n)-[:relation {name:'suitable_to_eat'}]->(m);
# match (n:node {name: 'second_level_departments'}),(m:node {name: 'first_level_departments'}) create (n)-[:relation {name:'belong_to'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'drug'}) create (n)-[:relation {name:'common_used'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'disease'}) create (n)-[:relation {name:'complication'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'food'}) create (n)-[:relation {name:'avoid_eating'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'second_level_departments'}) create (n)-[:relation {name:'affiliation_department'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'treatment_plan'}) create (n)-[:relation {name:'treatment'}]->(m);
# match (n:node {name: 'manufacturer'}),(m:node {name: 'drug'}) create (n)-[:relation {name:'produce_medicine'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'symptoms'}) create (n)-[:relation {name:'with_symptoms'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'recipe'}) create (n)-[:relation {name:'recommended_recipes'}]->(m);
# match (n:node {name: 'disease'}),(m:node {name: 'inspection_means'}) create (n)-[:relation {name:'diagnostic_tests'}]->(m);
#
# ```

# %%
## 查询生成 首先处理schema
## 对于agensGRaph 需要手动生成schenma
## 同时 我们认为正过来和倒过去是一个pattren  这儿可以写算法解决的 怎么写呢

## 这里我们只关心属性的查询和 一跳二跳的查询   变长路径查询占用10%

# %%
basepatern = "(n1)"

basepatern_set = "n"
pattern_remove_set =set(basepatern_set)
all_pattern = []
all_pattern.append(basepatern)
def generate_pattern(basepatern,basepatern_set,i):
    new_need_iter = []
    new_pattern1 = basepatern+'-[r'+str(i)+']'+'->(n'+str(i+1)+')'
    new_pattern2 = basepatern+'<-[r'+str(i)+']'+'-(n'+str(i+1)+')'

    new_pattern1_set = basepatern_set+'|-r-n'
    new_pattern2_set = basepatern_set+'-r-|n'
    if new_pattern1_set in pattern_remove_set or new_pattern1_set[::-1] in pattern_remove_set:
        pass
    else:
        all_pattern.append(new_pattern1)
        pattern_remove_set.add(new_pattern1_set)
    if new_pattern2_set in pattern_remove_set or new_pattern2_set[::-1] in pattern_remove_set:
        pass
    else:
        all_pattern.append(new_pattern2)        
        pattern_remove_set.add(new_pattern2_set)
    new_need_iter.append(new_pattern1)
    new_need_iter.append(new_pattern2)
    if i < 1:  ## 这里必须确定一个问题， 多跳的自然语言很难描述   所以我们应该把跳数缩短，更复杂的查询用户可以第二次查询
        generate_pattern(new_need_iter[0],new_pattern1_set, i+1)
        generate_pattern(new_need_iter[1],new_pattern2_set, i+1)

## 正过来和倒过去是一个pattern怎么处理 
generate_pattern(basepatern,basepatern_set,1)
print(len(all_pattern))
all_pattern
# Out:
# 2
# ['(n1)', '(n1)-[r1]->(n2)']

# %% [markdown]
# ```
# match (n) return n;
# match (n)-[r]->(m) return n,r,m;
# match (n1)-[r1]->(m2)-[r2]->(n3) return n1,r1,n2,r2,n3;
# ```

# %%
cypher_schema_query = []
for pattern in all_pattern:
    query = "match " + pattern +" return distinct *"
    cypher_schema_query.append(query)
cypher_schema_query
# Out:
# ['match (n1) return distinct *', 'match (n1)-[r1]->(n2) return distinct *']

# %%
import re
import json
node_pattern = re.compile(r'(.+?)\[(.+?)\](\{.*?\})', re.S)
edge_pattern = re.compile(r'(.+?)\[(.+?)\]\[(.+?),(.+?)\](\{.*?\})', re.S)
def resolve_node(row_data):
    m = node_pattern.match(row_data)
    label = m.group(1)
    vid = m.group(2)
    props = json.loads(m.group(3))
    return (label, vid, props)

def resolve_edge(row_data):
    m = edge_pattern.match(row_data)
    label = m.group(1)
    eid = m.group(2)
    start = m.group(3)
    end = m.group(4)
    props = json.loads(m.group(5))
    return (label, eid, start, end, props)

def resolve_path(row_data):
    edges = []
    allmatch = edge_pattern.findall(row_data)
    for m in allmatch:
        label = m[0]
        if label.startswith(","):
            label =label[1:]
        eid = m[1]
        start = m[2]
        end = m[3]
        props = json.loads(m[4])
        edges.append( (label, eid, start, end, props))
    print(edges)
    return edges

# %%
cypher_schema_query = sorted(cypher_schema_query, key=len)

new_pattern = []
## 对schema进行查询
import psycopg
import random


pg_con = psycopg.connect(
            dbname="postgres",
            host="localhost",
            user="omm",
            password="ZAQ1234@esz",
            port=5432)
     
       
cur = pg_con.cursor()
cur.execute(f"set graph_path = {schema_name}")
for query in cypher_schema_query:
    cur.execute(query)
    rows = cur.fetchall()
    print("数据的总行数:",len(rows),"\t","查询语句",query)
    for row in rows:
        rate = random.random()
        pattern = ""
        if (len(rows) < 500 and rate < 50/len(rows) )  or (len(rows) > 500 and rate < 10/len(rows) ):
            node_index = 1
            edge_index = 1 
            last_node_id = -1       
            for i in range(len(row)):
                    row_data = str(row[i])
                    is_node = node_pattern.match(row_data)
                    is_edge = edge_pattern.match(row_data)
                    if row_data.startswith('[') and row_data.endswith(']') :
                        row_data = row_data[1:len(row_data)-1]
                        edges = resolve_path(row_data)
                    elif is_edge:
                        edge = resolve_edge(row_data)
                        edge_label = edge[4]['name']
                        edge_start_id = edge[2]
                        if edge_start_id == last_node_id:
                            pattern=pattern+"-[r"+str(edge_index)+":"+edge_label+"]->"
                        else:
                            pattern=pattern+"<-[r"+str(edge_index)+":"+edge_label+"]-"     
                        edge_index = edge_index+1
                    elif is_node:
                        node = resolve_node(row_data)
                        node_label = node[2]['name']
                        last_node_id = node[1]
                        pattern=pattern+"(n"+str(node_index)+":"+node_label+")"
                        node_index = node_index+1
            print(pattern)
            new_pattern.append(pattern)
pg_con.close()
print(len(new_pattern))
# 方法一：使用json.dump()函数保存为JSON格式并写入文件
with open("new_pattern.json", "w") as file:
    json.dump(new_pattern, file,indent=4)
# Out:
# 数据的总行数: 5 	 查询语句 match (n1) return distinct *
# (n1:account)
# (n1:company)
# (n1:loan)
# (n1:medium)
# (n1:person)
# 数据的总行数: 12 	 查询语句 match (n1)-[r1]->(n2) return distinct *
# (n1:account)-[r1:accountrepayloan]->(n2:loan)
# (n1:account)-[r1:accounttransferaccount]->(n2:account)
# (n1:account)-[r1:accountwithdrawaccount]->(n2:account)
# (n1:company)-[r1:companyapplyloan]->(n2:loan)
# (n1:company)-[r1:companyguaranteecompany]->(n2:company)
# (n1:company)-[r1:companyinvestcompany]->(n2:company)
# (n1:loan)-[r1:loandepositaccount]->(n2:account)
# (n1:medium)-[r1:mediumsigninaccount]->(n2:account)
# (n1:person)-[r1:personapplyLoan]->(n2:loan)
# (n1:person)-[r1:personguaranteeperson]->(n2:person)
# (n1:person)-[r1:personinvestcompany]->(n2:company)
# (n1:person)-[r1:personownaccount]->(n2:account)
# 17

# %%
cypher_querys = []
for pattern in new_pattern:
    cypher_querys.append("match "+pattern+" return * limit 50")
print(len(cypher_querys))    
cypher_querys
# Out:
# 17
# ['match (n1:account) return * limit 50',
#  'match (n1:company) return * limit 50',
#  'match (n1:loan) return * limit 50',
#  'match (n1:medium) return * limit 50',
#  'match (n1:person) return * limit 50',
#  'match (n1:account)-[r1:accountrepayloan]->(n2:loan) return * limit 50',
#  'match (n1:account)-[r1:accounttransferaccount]->(n2:account) return * limit 50',
#  'match (n1:account)-[r1:accountwithdrawaccount]->(n2:account) return * limit 50',
#  'match (n1:company)-[r1:companyapplyloan]->(n2:loan) return * limit 50',
#  'match (n1:company)-[r1:companyguaranteecompany]->(n2:company) return * limit 50',
#  'match (n1:company)-[r1:companyinvestcompany]->(n2:company) return * limit 50',
#  'match (n1:loan)-[r1:loandepositaccount]->(n2:account) return * limit 50',
#  'match (n1:medium)-[r1:mediumsigninaccount]->(n2:account) return * limit 50',
#  'match (n1:person)-[r1:personapplyLoan]->(n2:loan) return * limit 50',
#  'match (n1:person)-[r1:personguaranteeperson]->(n2:person) return * limit 50',
#  'match (n1:person)-[r1:personinvestcompany]->(n2:company) return * limit 50',
#  'match (n1:person)-[r1:personownaccount]->(n2:account) return * limit 50']

# %%
## 通过数据库的base_schema pattern 查询数据库 生成带有 where return order by
import re
import json

# 从文件加载JSON数据
with open('new_pattern.json', 'r') as file:
    new_pattern = json.load(file)

cypher_querys = []
for pattern in new_pattern:
    cypher_querys.append("match "+pattern+" return * limit 50")


node_pattern = re.compile(r'(.+?)\[(.+?)\](\{.*?\})', re.S)
edge_pattern = re.compile(r'(.+?)\[(.+?)\]\[(.+?),(.+?)\](\{.*?\})', re.S)

def resolve_node(row_data):
    m = node_pattern.match(row_data)
    label = m.group(1)
    vid = m.group(2)
    props = json.loads(m.group(3))
    return (label, vid, props)

def resolve_edge(row_data):
    m = edge_pattern.match(row_data)
    label = m.group(1)
    eid = m.group(2)
    start = m.group(3)
    end = m.group(4)
    props = json.loads(m.group(5))
    return (label, eid, start, end, props)

def resolve_path(row_data):
    edges = []
    allmatch = edge_pattern.findall(row_data)
    for m in allmatch:
        label = m[0]
        if label.startswith(","):
            label =label[1:]
        eid = m[1]
        start = m[2]
        end = m[3]
        props = json.loads(m[4])
        edges.append( (label, eid, start, end, props))
    print(edges)
    return edges

import psycopg
import random


cypher_base_query = []

# node_func = ["id({})","properties({})","keys({})","count({})"]
# edge_func =  ["id({})","properties({})","keys({})","endNode({})","startNode({})","type({})"]
# string_func= ["rTrim({})","lTrim({})","trim({})","toUpper({})","toLower({})","reverse({})"]

pg_con = psycopg.connect(
            dbname="postgres",
            host="localhost",
            user="omm",
            password="ZAQ1234@esz",
            port=5432,
            options="-c statement_timeout=10000"
            )
     
pg_con.autocommit=True        
cur = pg_con.cursor()
cur.execute(f"set graph_path = {graph_path}")


for pattern in cypher_querys:
    try:
        cur.execute(pattern)
        rows = cur.fetchall()
        print("数据的总行数:",len(rows))

        base_query_pattern = pattern.replace("return * limit 50","")
        column_names = [desc[0] for desc in cur.description]
        for row in rows:
            where_key = []
            return_key = []
            for i in range(len(row)):
                row_data = str(row[i])
                if "feature_emd" != column_names[i]:
                    var_name = column_names[i]

                    is_node = node_pattern.match(row_data)
                    is_edge = edge_pattern.match(row_data)
                    if row_data.startswith('[') and row_data.endswith(']') :
                        row_data = row_data[1:len(row_data)-1]
                        edges = resolve_path(row_data)
                    elif is_edge:
                        edge = resolve_edge(row_data)
                        properties = edge[4]
                        keys = list(properties.keys())
                        for key in keys:
                            return_key.append(var_name+"."+key)

                    elif is_node:
                        node = resolve_node(row_data)
                        node_label = node[0]
                        properties = node[2]
                        keys = list(properties.keys())
                        for key in keys:
                            if key not in exclude_return_keys:
                                return_key.append(var_name+"."+key)
                        ### where 条件的拼接只出现在这里
                        if node_label in label_where_key:
                            where_key.append(var_name+"."+label_where_key[node_label]+"='"+properties[label_where_key[node_label]]+"'" )
                        
           

            ## 返回值
            return_key = random.sample(return_key,random.randint(1,len(return_key)) )
            if len(where_key) >0:
                where_key = random.sample(where_key,random.randint(1,len(where_key)) )

            if len(return_key) > 1:
                return_param = ", ".join(return_key)
            else:
                return_param =   return_key[0]         
            
            return_param = " return "+ return_param 


                        # order by 
            order_param = ""
            if random.random()<0.3:
                which_could_order_by =[key for key in return_key 
                                       if key.endswith('.name') 
                                      ]
                if len(which_could_order_by) >0:
                    order_param = order_param + " order by "+ which_could_order_by[random.randint(0,len(which_could_order_by)-1)]
                    if random.random()<0.3:
                        order_param = order_param + " desc"

            
            
            where_param = ''

            if len(where_key) > 1:
                where_param = " and ".join(where_key)
            elif len(where_key) == 1:
                where_param = where_key[0]
            else:    
                continue
            where_param = " where "+where_param    

            cypher_base_query.append(base_query_pattern+where_param+return_param + order_param)         
    except Exception as e:
        print("-------------------------",e)
pg_con.close()

print(len(cypher_base_query))
# 方法一：使用json.dump()函数保存为JSON格式并写入文件
with open("cypher_base_query.json", "w") as file:
    json.dump(cypher_base_query, file,indent=4)
# Out:
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 50
# 数据的总行数: 0
# 数据的总行数: 0
# 数据的总行数: 50
# 数据的总行数: 50
# 700

# %%
### 接着处理语句  添加limit 和 skip 关键字  t同时替换掉一些非法的属性值 agens 区分大小写 
### 赋予30的概率吧

import json
import random
# 从文件加载JSON数据
cypher_base_with_limit_skip_query=[]
with open('cypher_base_query.json', 'r') as file:
    cypher_base_query = json.load(file)
for base_query in  cypher_base_query:
    base_query = base_query.replace("   "," ")

    if random.random()<0.3:
       
        if random.random()<0.3:
            skip = random.randint(1,20)    
            base_query = base_query + " skip " + str(skip)  + " limit " + str(random.randint(1,20))
        else:
            base_query = base_query + " limit " + str(random.randint(1,20)) 
        cypher_base_with_limit_skip_query.append(base_query)    
    else:
        cypher_base_with_limit_skip_query.append(base_query)

    
print(len(cypher_base_with_limit_skip_query))
# 方法一：使用json.dump()函数保存为JSON格式并写入文件
with open("cypher_base_with_limit_skip_query.json", "w") as file:
    json.dump(cypher_base_with_limit_skip_query, file,indent=4)
# Out:
# 700

# %%
#### 过滤掉没有结果的值和查询超时的值
## 对schema进行查询
import psycopg
cypher_base_with_limit_skip_query_filter_none = []
pg_con = psycopg.connect(
            dbname="postgres",
            host="localhost",
            user="omm",
            password="ZAQ1234@esz",
            port=5432,
            options="-c statement_timeout=10000")
     
pg_con.autocommit=True       
cur = pg_con.cursor()
cur.execute(f"set graph_path = {graph_path}")
for query in cypher_base_with_limit_skip_query:
    try:
        cur.execute(query)
        rows = cur.fetchall()
        print("数据的总行数:",len(rows),"\t","查询语句",query)
        if len(rows) > 0:
            cypher_base_with_limit_skip_query_filter_none.append(query)
    except Exception as e:
        print(e)       

pg_con.close()

print(len(cypher_base_with_limit_skip_query_filter_none))
# 方法一：使用json.dump()函数保存为JSON格式并写入文件
with open("cypher_base_with_limit_skip_query_filter_none.json", "w") as file:
    json.dump(cypher_base_with_limit_skip_query_filter_none, file,indent=4)
# Out:
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Renato Holness' return n1.createtime, n1.accountlevel, n1.lastlogintime, n1.nickname, n1.phonenum
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Kurt Fernandes' return n1.createtime, n1.freqlogintype, n1.nickname, n1.accountid, n1.phonenum, n1.email
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Laverna Model' return n1.lastlogintime, n1.accouttype, n1.createtime, n1.email, n1.phonenum, n1.accountid
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Peggy Gayheart' return n1.phonenum, n1.accouttype, n1.email
# 数据的总行数: 0 	 查询语句 match (n1:account)  where n1.nickname='Eleni Mccleve' return n1.lastlogintime, n1.email, n1.freqlogintype, n1.createtime, n1.isblocked skip 5 limit 14
# 数据的总行数: 0 	 查询语句 match (n1:account)  where n1.nickname='Bethann Fasching' return n1.phonenum, n1.accountlevel, n1.createtime skip 5 limit 2
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Mayra Minkoff' return n1.isblocked, n1.freqlogintype, n1.lastlogintime, n1.nickname, n1.accouttype, n1.phonenum, n1.createtime, n1.accountid limit 9
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Linwood Musca' return n1.isblocked, n1.freqlogintype, n1.accouttype, n1.phonenum, n1.nickname, n1.accountlevel
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Quincy Palevic' return n1.phonenum, n1.accountid, n1.freqlogintype, n1.isblocked, n1.lastlogintime
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Randolph Gica' return n1.phonenum, n1.accountlevel, n1.isblocked, n1.nickname, n1.lastlogintime
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Lesa Fuchser' return n1.isblocked, n1.lastlogintime, n1.createtime, n1.accountid, n1.nickname, n1.accouttype
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Freeman Murchinson' return n1.lastlogintime, n1.accountlevel
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Von Kwiecinski' return n1.accountlevel, n1.email, n1.freqlogintype, n1.nickname, n1.phonenum, n1.createtime, n1.lastlogintime, n1.accouttype, n1.accountid limit 2
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Keri Dowless' return n1.createtime, n1.accountid, n1.phonenum, n1.accouttype, n1.nickname, n1.email, n1.lastlogintime, n1.accountlevel limit 5
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Mee Litehiser' return n1.phonenum limit 12
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Preston Sankovich' return n1.accountlevel, n1.isblocked, n1.lastlogintime, n1.accountid, n1.phonenum, n1.createtime
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Jared Keeran' return n1.lastlogintime, n1.accountlevel, n1.isblocked
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Betsey Kristensen' return n1.lastlogintime, n1.accountid, n1.accouttype, n1.freqlogintype, n1.nickname, n1.email, n1.accountlevel
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Gennie Mautz' return n1.isblocked, n1.freqlogintype, n1.nickname, n1.lastlogintime, n1.email
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Paula Kreiman' return n1.createtime, n1.phonenum, n1.freqlogintype, n1.email limit 11
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Laurence Mccoil' return n1.nickname, n1.createtime, n1.freqlogintype, n1.accouttype, n1.email, n1.accountid
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Norberto Cocco' return n1.createtime, n1.email, n1.phonenum, n1.accountlevel, n1.nickname
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Mimi Voelkel' return n1.email, n1.accountid, n1.accountlevel, n1.nickname
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Jimmie Poldrack' return n1.accountlevel, n1.nickname, n1.isblocked, n1.email limit 5
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Hilario Dedecker' return n1.email, n1.lastlogintime
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Crissy Rehmann' return n1.lastlogintime, n1.accountlevel, n1.phonenum, n1.createtime
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Mohammad Creitz' return n1.accountid, n1.nickname, n1.createtime, n1.accouttype, n1.freqlogintype, n1.isblocked
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Leo Astudillo' return n1.lastlogintime, n1.nickname, n1.accountid limit 7
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Andre Craigwell' return n1.accountlevel, n1.lastlogintime, n1.createtime, n1.freqlogintype, n1.nickname, n1.accouttype, n1.email, n1.phonenum, n1.accountid
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Vince Moznett' return n1.isblocked, n1.email, n1.nickname, n1.phonenum, n1.accountid, n1.accountlevel, n1.createtime, n1.lastlogintime, n1.freqlogintype, n1.accouttype limit 18
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Harold Apolito' return n1.createtime, n1.lastlogintime, n1.phonenum, n1.email, n1.isblocked, n1.accountid, n1.freqlogintype
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Theresia Wight' return n1.phonenum limit 8
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Rogelio Thaut' return n1.phonenum, n1.accouttype, n1.accountid, n1.freqlogintype, n1.email, n1.nickname
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Deangelo Gephart' return n1.freqlogintype, n1.nickname, n1.phonenum
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Eve Pusateri' return n1.createtime
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Tania Kensey' return n1.accountlevel, n1.createtime, n1.accountid, n1.lastlogintime, n1.isblocked, n1.freqlogintype, n1.accouttype, n1.nickname, n1.email limit 13
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Alesia Dragovich' return n1.freqlogintype limit 11
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Donn Burgbacher' return n1.accouttype, n1.accountid, n1.isblocked, n1.lastlogintime, n1.accountlevel, n1.email, n1.freqlogintype
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Noe Trites' return n1.accountid, n1.nickname, n1.isblocked, n1.accountlevel, n1.phonenum, n1.accouttype, n1.email, n1.freqlogintype
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Bert Inverso' return n1.accountlevel, n1.accouttype, n1.createtime, n1.isblocked, n1.freqlogintype, n1.lastlogintime, n1.phonenum, n1.nickname, n1.email
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Lauren Marich' return n1.freqlogintype, n1.isblocked, n1.nickname, n1.accouttype, n1.accountlevel, n1.createtime, n1.accountid
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Danica Gollhofer' return n1.accountlevel, n1.accouttype
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Rubin Maenaga' return n1.lastlogintime, n1.createtime, n1.phonenum, n1.nickname, n1.accountid, n1.freqlogintype
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Clementine Buchberger' return n1.phonenum, n1.isblocked, n1.createtime, n1.accouttype, n1.nickname, n1.lastlogintime, n1.accountid, n1.freqlogintype, n1.accountlevel, n1.email
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Stephan Esqueda' return n1.phonenum, n1.freqlogintype, n1.accountlevel
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Andrew Sweeney' return n1.email, n1.accountlevel, n1.createtime
# 数据的总行数: 1 	 查询语句 match (n1:account)  where n1.nickname='Lolita Desilvo' return n1.lastlogintime, n1.phonenum, n1.email, n1.nickname, n1.freqlogintype
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Ferdinand Columbia' return n1.accouttype, n1.isblocked, n1.phonenum, n1.lastlogintime, n1.email, n1.nickname, n1.accountid
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Pamelia Vanvranken' return n1.accountid, n1.phonenum, n1.createtime, n1.freqlogintype, n1.accountlevel, n1.accouttype, n1.email, n1.lastlogintime, n1.nickname
# 数据的总行数: 2 	 查询语句 match (n1:account)  where n1.nickname='Faustino Marolf' return n1.freqlogintype, n1.accountid, n1.phonenum, n1.accouttype, n1.isblocked, n1.createtime, n1.accountlevel, n1.nickname, n1.lastlogintime
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Lesch-Bergnaum' return n1.business, n1.companyid limit 4
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Jacobson-Yost' return n1.country, n1.isblocked, n1.description, n1.companyname
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Jacobson-Cruickshank' return n1.isblocked
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Koss-Rogahn' return n1.companyid, n1.country, n1.createtime, n1.description, n1.business
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Bahringer-Daniel' return n1.business, n1.url, n1.companyname, n1.isblocked, n1.createtime, n1.country, n1.companyid limit 19
# 数据的总行数: 2 	 查询语句 match (n1:company)  where n1.companyname='Sawayn PLC' return n1.isblocked, n1.country, n1.companyid, n1.createtime, n1.city
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Boyer-Morissette' return n1.description, n1.country, n1.companyid
# 数据的总行数: 0 	 查询语句 match (n1:company)  where n1.companyname='Roberts LLC' return n1.url, n1.city, n1.companyid, n1.createtime, n1.companyname, n1.description, n1.business, n1.isblocked, n1.country skip 1 limit 20
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Auer PLC' return n1.companyname, n1.createtime, n1.business, n1.url
# 数据的总行数: 2 	 查询语句 match (n1:company)  where n1.companyname='Champlin PLC' return n1.description, n1.createtime
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Lockman Ltd' return n1.url, n1.isblocked, n1.companyname, n1.description, n1.companyid, n1.country, n1.createtime, n1.city limit 11
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Lynch-Green' return n1.url, n1.isblocked, n1.country
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Bernier-Hill' return n1.companyid, n1.url, n1.description, n1.createtime, n1.isblocked, n1.country, n1.city, n1.companyname
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Schneider-Erdman' return n1.city, n1.createtime, n1.url, n1.companyname, n1.description, n1.country, n1.isblocked, n1.business, n1.companyid
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Herzog Ltd' return n1.url, n1.companyname, n1.business, n1.isblocked, n1.city, n1.companyid
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Schulist-Pollich' return n1.createtime, n1.city, n1.companyname, n1.url, n1.country, n1.description
# 数据的总行数: 0 	 查询语句 match (n1:company)  where n1.companyname='Nikolaus-Feeney' return n1.url, n1.companyname, n1.country skip 12 limit 1
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Breitenberg-Schaden' return n1.city, n1.url, n1.isblocked, n1.companyname, n1.description, n1.business
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Wisoky Inc' return n1.companyid, n1.description, n1.country, n1.isblocked, n1.business, n1.companyname
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='McCullough-Witting' return n1.business, n1.isblocked, n1.description, n1.country, n1.url, n1.companyname
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Hilpert-Wyman' return n1.isblocked, n1.companyid, n1.createtime, n1.country, n1.companyname, n1.url, n1.business, n1.city, n1.description
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Ledner-Conroy' return n1.companyname, n1.description, n1.country, n1.createtime, n1.companyid, n1.isblocked, n1.city, n1.business, n1.url
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Hodkiewicz-Medhurst' return n1.city, n1.business, n1.companyname, n1.description, n1.country
# 数据的总行数: 0 	 查询语句 match (n1:company)  where n1.companyname='Jenkins-Macejkovic' return n1.url, n1.city, n1.createtime, n1.isblocked, n1.country skip 5 limit 20
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Howell Inc' return n1.description, n1.companyid, n1.createtime, n1.business
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Kautzer-Stamm' return n1.business, n1.url, n1.companyname, n1.companyid, n1.createtime, n1.isblocked, n1.country, n1.city, n1.description
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Labadie-Witting' return n1.business, n1.isblocked
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Veum Inc' return n1.country, n1.companyname limit 2
# 数据的总行数: 0 	 查询语句 match (n1:company)  where n1.companyname='Gleichner Inc' return n1.description, n1.createtime, n1.isblocked, n1.city, n1.country, n1.url, n1.companyid, n1.companyname, n1.business skip 15 limit 1
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Murray-Hickle' return n1.business, n1.city, n1.companyname, n1.description, n1.url, n1.isblocked, n1.createtime, n1.country, n1.companyid limit 4
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Jerde Ltd' return n1.country, n1.city, n1.isblocked, n1.business, n1.createtime, n1.url
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Jaskolski Group' return n1.city, n1.country, n1.url, n1.createtime, n1.companyname, n1.isblocked, n1.business, n1.description, n1.companyid limit 11
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Little Inc' return n1.companyname, n1.country, n1.url, n1.business, n1.description
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Legros-Paucek' return n1.city, n1.isblocked
# syntax error at or near "Amore"
# LINE 1: ...tch (n1:company)  where n1.companyname='Weimann-D'Amore' ret...
#                                                              ^
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Denesik-Mohr' return n1.city
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Fadel-Schumm' return n1.city, n1.url limit 2
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Pfeffer-Bradtke' return n1.companyname, n1.city, n1.description, n1.createtime, n1.country, n1.isblocked, n1.business, n1.url
# 数据的总行数: 0 	 查询语句 match (n1:company)  where n1.companyname='Herman-Bechtelar' return n1.city, n1.createtime, n1.country, n1.description, n1.business, n1.url, n1.companyid skip 16 limit 1
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Homenick-Jacobi' return n1.createtime, n1.description, n1.country, n1.companyid, n1.isblocked
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Wuckert Inc' return n1.isblocked
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Schmidt-Schroeder' return n1.country, n1.city, n1.url
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Haley Ltd' return n1.country, n1.isblocked, n1.city, n1.companyid, n1.url, n1.createtime
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Roob-Lowe' return n1.city, n1.description, n1.country, n1.url, n1.createtime, n1.companyname, n1.isblocked, n1.business
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Hoppe and Sons' return n1.country, n1.isblocked
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Grady Inc' return n1.country
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Kerluke-Kilback' return n1.country, n1.isblocked, n1.companyname, n1.business, n1.companyid, n1.createtime
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Hilpert and Sons' return n1.business, n1.url, n1.city, n1.description, n1.createtime, n1.companyname
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Tromp and Sons' return n1.companyname, n1.description
# 数据的总行数: 1 	 查询语句 match (n1:company)  where n1.companyname='Daugherty-Bode' return n1.city, n1.description, n1.business, n1.isblocked, n1.url, n1.country, n1.createtime
# 数据的总行数: 14 	 查询语句 match (n1:medium)  where n1.mediumtype='NFC' return n1.createtime skip 15 limit 14
# 数据的总行数: 91 	 查询语句 match (n1:medium)  where n1.mediumtype='MAC' return n1.isblocked, n1.mediumtype
# 数据的总行数: 12 	 查询语句 match (n1:medium)  where n1.mediumtype='ATM' return n1.mediumId, n1.createtime, n1.risklevel, n1.lastlogintime, n1.isblocked limit 12
# 数据的总行数: 18 	 查询语句 match (n1:medium)  where n1.mediumtype='IPv4' return n1.lastlogintime, n1.createtime, n1.isblocked, n1.mediumId limit 18
# 数据的总行数: 12 	 查询语句 match (n1:medium)  where n1.mediumtype='IPv4' return n1.isblocked, n1.mediumId limit 12
# 数据的总行数: 17 	 查询语句 match (n1:medium)  where n1.mediumtype='RFID' return n1.isblocked, n1.createtime, n1.risklevel, n1.mediumId, n1.lastlogintime limit 17
# 数据的总行数: 91 	 查询语句 match (n1:medium)  where n1.mediumtype='MAC' return n1.mediumId, n1.isblocked, n1.createtime, n1.risklevel, n1.mediumtype
# 数据的总行数: 114 	 查询语句 match (n1:medium)  where n1.mediumtype='ATM' return n1.risklevel, n1.mediumId
# 数据的总行数: 112 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.mediumtype, n1.isblocked
# 数据的总行数: 77 	 查询语句 match (n1:medium)  where n1.mediumtype='POS' return n1.lastlogintime, n1.risklevel, n1.createtime, n1.isblocked, n1.mediumId, n1.mediumtype
# 数据的总行数: 100 	 查询语句 match (n1:medium)  where n1.mediumtype='WIFI' return n1.isblocked, n1.lastlogintime, n1.createtime, n1.mediumtype, n1.mediumId
# 数据的总行数: 112 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.isblocked, n1.mediumtype, n1.createtime
# 数据的总行数: 82 	 查询语句 match (n1:medium)  where n1.mediumtype='IPv6' return n1.risklevel
# 数据的总行数: 82 	 查询语句 match (n1:medium)  where n1.mediumtype='IPv6' return n1.mediumId, n1.risklevel
# 数据的总行数: 100 	 查询语句 match (n1:medium)  where n1.mediumtype='WIFI' return n1.risklevel, n1.mediumId, n1.isblocked
# 数据的总行数: 112 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.isblocked, n1.risklevel, n1.mediumtype, n1.createtime, n1.lastlogintime, n1.mediumId
# 数据的总行数: 112 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.risklevel, n1.mediumId
# 数据的总行数: 98 	 查询语句 match (n1:medium)  where n1.mediumtype='NFC' return n1.isblocked, n1.risklevel, n1.lastlogintime
# 数据的总行数: 14 	 查询语句 match (n1:medium)  where n1.mediumtype='PHONE' return n1.isblocked, n1.risklevel, n1.lastlogintime, n1.mediumtype, n1.mediumId skip 17 limit 14
# 数据的总行数: 108 	 查询语句 match (n1:medium)  where n1.mediumtype='RFID' return n1.lastlogintime, n1.isblocked, n1.mediumtype, n1.createtime, n1.mediumId
# 数据的总行数: 112 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.risklevel, n1.mediumtype
# 数据的总行数: 102 	 查询语句 match (n1:medium)  where n1.mediumtype='PHONE' return n1.mediumtype, n1.createtime, n1.lastlogintime, n1.mediumId, n1.risklevel, n1.isblocked
# 数据的总行数: 98 	 查询语句 match (n1:medium)  where n1.mediumtype='NFC' return n1.isblocked, n1.mediumtype, n1.createtime
# 数据的总行数: 82 	 查询语句 match (n1:medium)  where n1.mediumtype='IPv6' return n1.mediumId, n1.isblocked, n1.lastlogintime, n1.mediumtype, n1.createtime
# 数据的总行数: 98 	 查询语句 match (n1:medium)  where n1.mediumtype='NFC' return n1.isblocked, n1.risklevel, n1.createtime
# 数据的总行数: 77 	 查询语句 match (n1:medium)  where n1.mediumtype='POS' return n1.isblocked, n1.mediumId, n1.mediumtype
# 数据的总行数: 4 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.createtime limit 4
# 数据的总行数: 112 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.createtime, n1.mediumId, n1.isblocked
# 数据的总行数: 6 	 查询语句 match (n1:medium)  where n1.mediumtype='NFC' return n1.mediumId, n1.createtime, n1.mediumtype limit 6
# 数据的总行数: 100 	 查询语句 match (n1:medium)  where n1.mediumtype='WIFI' return n1.mediumtype
# 数据的总行数: 2 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.risklevel, n1.isblocked, n1.createtime, n1.mediumtype, n1.lastlogintime limit 2
# 数据的总行数: 77 	 查询语句 match (n1:medium)  where n1.mediumtype='POS' return n1.lastlogintime
# 数据的总行数: 12 	 查询语句 match (n1:medium)  where n1.mediumtype='IPv4' return n1.createtime limit 12
# 数据的总行数: 98 	 查询语句 match (n1:medium)  where n1.mediumtype='NFC' return n1.mediumtype, n1.mediumId, n1.risklevel
# 数据的总行数: 91 	 查询语句 match (n1:medium)  where n1.mediumtype='MAC' return n1.mediumId
# 数据的总行数: 100 	 查询语句 match (n1:medium)  where n1.mediumtype='WIFI' return n1.lastlogintime, n1.isblocked
# 数据的总行数: 102 	 查询语句 match (n1:medium)  where n1.mediumtype='PHONE' return n1.isblocked
# 数据的总行数: 77 	 查询语句 match (n1:medium)  where n1.mediumtype='POS' return n1.risklevel, n1.mediumtype, n1.lastlogintime
# 数据的总行数: 18 	 查询语句 match (n1:medium)  where n1.mediumtype='ATM' return n1.risklevel, n1.lastlogintime skip 13 limit 18
# 数据的总行数: 112 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.mediumId
# 数据的总行数: 12 	 查询语句 match (n1:medium)  where n1.mediumtype='ATM' return n1.risklevel limit 12
# 数据的总行数: 2 	 查询语句 match (n1:medium)  where n1.mediumtype='IPv4' return n1.mediumtype skip 8 limit 2
# 数据的总行数: 114 	 查询语句 match (n1:medium)  where n1.mediumtype='ATM' return n1.isblocked, n1.createtime, n1.mediumtype
# 数据的总行数: 112 	 查询语句 match (n1:medium)  where n1.mediumtype='QRCode' return n1.lastlogintime
# 数据的总行数: 114 	 查询语句 match (n1:medium)  where n1.mediumtype='ATM' return n1.mediumtype
# 数据的总行数: 94 	 查询语句 match (n1:medium)  where n1.mediumtype='IPv4' return n1.lastlogintime, n1.risklevel
# 数据的总行数: 100 	 查询语句 match (n1:medium)  where n1.mediumtype='WIFI' return n1.lastlogintime, n1.risklevel, n1.mediumId, n1.isblocked
# 数据的总行数: 108 	 查询语句 match (n1:medium)  where n1.mediumtype='RFID' return n1.mediumId, n1.isblocked, n1.lastlogintime
# 数据的总行数: 114 	 查询语句 match (n1:medium)  where n1.mediumtype='ATM' return n1.mediumId, n1.isblocked, n1.createtime, n1.mediumtype
# 数据的总行数: 102 	 查询语句 match (n1:medium)  where n1.mediumtype='PHONE' return n1.risklevel
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Menville' return n1.country, n1.personId limit 10
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Rowe' return n1.birthday, n1.personId, n1.city
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Rowlands' return n1.personname, n1.country, n1.birthday, n1.gender, n1.createtime limit 13
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Kerschensteiner' return n1.createtime, n1.isBlocked, n1.birthday, n1.city, n1.country, n1.personname
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Abutalybov' return n1.personId, n1.city
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Bukofzer' return n1.country, n1.birthday, n1.isBlocked, n1.personId, n1.createtime, n1.personname, n1.city
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Shabazz' return n1.country, n1.createtime, n1.isBlocked, n1.gender, n1.personId, n1.birthday, n1.personname
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Zakharov' return n1.city, n1.personname, n1.createtime, n1.isBlocked, n1.birthday
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Baumgartner' return n1.createtime, n1.personname, n1.city, n1.country, n1.isBlocked, n1.birthday, n1.gender limit 11
# 数据的总行数: 0 	 查询语句 match (n1:person)  where n1.personname='Hodgman' return n1.personId, n1.createtime skip 12 limit 18
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Baardsen' return n1.city, n1.createtime, n1.gender, n1.isBlocked
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Castanon' return n1.personname, n1.country, n1.createtime limit 18
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Akhavan' return n1.isBlocked, n1.personname, n1.createtime, n1.city, n1.personId, n1.birthday, n1.gender
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Patten' return n1.gender, n1.city
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Hulbert' return n1.gender
# 数据的总行数: 0 	 查询语句 match (n1:person)  where n1.personname='House' return n1.personId, n1.personname skip 12 limit 17
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Gunn' return n1.country, n1.personId, n1.birthday limit 2
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Cook' return n1.country, n1.gender, n1.isBlocked
# syntax error at or near "Hearn"
# LINE 1: match (n1:person)  where n1.personname='O'Hearn' return n1.c...
#                                                   ^
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Brocklebank' return n1.birthday, n1.isBlocked
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Farnall' return n1.country, n1.isBlocked, n1.createtime, n1.birthday
# 数据的总行数: 0 	 查询语句 match (n1:person)  where n1.personname='Culver' return n1.country, n1.personname skip 4 limit 19
# 数据的总行数: 0 	 查询语句 match (n1:person)  where n1.personname='Hatfield' return n1.gender, n1.createtime, n1.personId, n1.isBlocked, n1.personname, n1.birthday, n1.country, n1.city skip 8 limit 14
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Aden' return n1.personname limit 17
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Moon' return n1.birthday, n1.createtime, n1.country, n1.gender
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Boyes' return n1.personname, n1.createtime, n1.gender, n1.isBlocked, n1.city, n1.birthday, n1.country, n1.personId
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Hergesheimer' return n1.country
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Itakura' return n1.isBlocked, n1.city, n1.personId, n1.country
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Buttiglione' return n1.personname, n1.createtime, n1.country, n1.personId
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Dafydd' return n1.gender, n1.isBlocked, n1.country, n1.city, n1.createtime, n1.personname, n1.personId, n1.birthday
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Gaztañaga' return n1.city, n1.gender, n1.country, n1.personname limit 9
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Bennahmias' return n1.createtime, n1.isBlocked, n1.country, n1.gender limit 7
# 数据的总行数: 0 	 查询语句 match (n1:person)  where n1.personname='Peart' return n1.gender, n1.personname, n1.city, n1.country, n1.personId, n1.createtime, n1.birthday skip 3 limit 10
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Dooley' return n1.personname, n1.personId, n1.gender, n1.country
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Rogerson' return n1.city, n1.isBlocked, n1.personId, n1.birthday, n1.createtime, n1.gender, n1.personname, n1.country
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Staudle' return n1.city, n1.isBlocked
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Sim' return n1.createtime, n1.gender
# 数据的总行数: 0 	 查询语句 match (n1:person)  where n1.personname='Le Lacheur' return n1.createtime, n1.personId, n1.city, n1.birthday, n1.gender, n1.personname, n1.country, n1.isBlocked skip 11 limit 13
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Domingo' return n1.city, n1.birthday, n1.personId, n1.gender, n1.createtime, n1.personname, n1.country limit 6
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Riby' return n1.country, n1.personname limit 2
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Kaljujarv' return n1.createtime, n1.city, n1.personname, n1.gender, n1.isBlocked, n1.birthday, n1.country, n1.personId
# 数据的总行数: 0 	 查询语句 match (n1:person)  where n1.personname='Vaccari' return n1.isBlocked, n1.gender skip 7 limit 15
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Barshadly' return n1.personId, n1.isBlocked
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Cutler' return n1.gender, n1.city, n1.birthday, n1.personname
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Alberstein' return n1.isBlocked, n1.birthday, n1.city, n1.personname
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Ide' return n1.createtime, n1.personname, n1.isBlocked, n1.birthday, n1.city, n1.personId
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Horton' return n1.createtime limit 15
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Sossamon' return n1.isBlocked, n1.personId, n1.country, n1.city, n1.createtime, n1.gender limit 6
# 数据的总行数: 1 	 查询语句 match (n1:person)  where n1.personname='Chaparro' return n1.personId, n1.createtime
# 数据的总行数: 0 	 查询语句 match (n1:person)  where n1.personname='Blaché' return n1.gender, n1.country, n1.personname, n1.personId, n1.createtime skip 15 limit 9
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n2.interestrate, n1.freqlogintype, n1.lastlogintime, n1.createtime, n2.loanamount, n2.balance, r1.createtime, n1.isblocked, n2.loanId, n2.createtime, n1.accountid, n1.email, n1.nickname, n1.phonenum, r1.amount, n1.accouttype, n1.accountlevel
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n1.freqlogintype, n2.loanId, n2.loanamount, n1.lastlogintime, n1.nickname, n1.accouttype, n2.loanusage, n2.createtime, r1.amount
# 数据的总行数: 15 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return r1.amount, n1.accouttype, n2.createtime, r1.createtime, n1.createtime, n2.loanusage, n1.nickname, n1.accountlevel, n2.interestrate, n2.balance, n1.isblocked, n2.loanId, n1.freqlogintype, n2.loanamount limit 15
# 数据的总行数: 15 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n2.createtime, n2.interestrate, n1.nickname, n1.freqlogintype, n1.accountid, n1.phonenum, n1.accouttype, n1.createtime, n2.loanId, n1.lastlogintime, n2.loanamount, r1.amount, n2.balance, n1.isblocked, n2.loanusage limit 15
# 数据的总行数: 0 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Patricia Towe' return r1.amount, n2.createtime, n2.loanamount, n1.accountlevel, n1.accouttype, r1.createtime, n1.createtime, n1.isblocked skip 9 limit 11
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return n1.nickname, n1.accountlevel, r1.amount, n2.loanId, n2.createtime, n1.phonenum, n1.lastlogintime, n2.balance, n1.createtime, n1.accountid, n2.loanusage, n1.isblocked, n1.freqlogintype, n1.email, n2.interestrate, r1.createtime, n1.accouttype
# 数据的总行数: 19 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return n2.balance, n2.interestrate, n2.createtime, n1.isblocked, n1.accountid, n1.nickname, r1.amount, n2.loanusage skip 5 limit 19
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return n1.nickname, n1.freqlogintype, n1.accountid
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return n1.accouttype, n2.loanusage, n2.loanId, n1.accountlevel, n2.createtime, n1.email, n1.freqlogintype, r1.amount, n1.createtime, r1.createtime, n2.balance, n1.phonenum, n1.isblocked, n1.accountid, n1.lastlogintime, n2.loanamount
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Mildred Clever' return n1.accountlevel, n2.createtime, n1.createtime, n1.lastlogintime, r1.amount, n1.accountid, n2.interestrate, n1.email, n1.accouttype, n1.phonenum, n1.nickname, n2.loanusage
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Mildred Clever' return n1.accouttype, n2.loanusage, n1.nickname, n2.createtime
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Randolph Gica' return n2.interestrate, n1.lastlogintime, n1.email, r1.createtime, n1.phonenum, n2.balance, n1.isblocked, n2.loanId, n2.createtime, n1.accountlevel
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Randolph Gica' return n1.isblocked, n1.accountid, n2.loanusage, n2.loanamount, r1.createtime, n1.email, r1.amount, n1.freqlogintype, n1.nickname, n2.balance
# 数据的总行数: 1 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Randolph Gica' return n2.loanusage, r1.amount, n1.phonenum, n2.balance, n1.accountid, n1.email, n1.accountlevel, n2.interestrate, n1.nickname skip 2 limit 1
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Randolph Gica' return n2.loanamount, n1.accountid, r1.amount, n1.email, n1.nickname, n2.balance, n1.phonenum, n2.loanusage, n2.createtime, n1.lastlogintime, n1.accountlevel
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n2.loanusage, n1.email, n1.createtime, n1.freqlogintype, n2.interestrate, n2.balance, n1.nickname, r1.createtime
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n1.phonenum, n2.interestrate, n1.accountid
# 数据的总行数: 15 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n2.loanamount, n2.loanusage, n1.lastlogintime, r1.amount, n1.accountid, n1.freqlogintype, r1.createtime, n2.createtime, n2.balance, n1.email, n1.phonenum, n1.accountlevel, n1.createtime, n1.isblocked, n2.interestrate limit 15
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n1.accountid, n2.loanusage, n1.createtime, n1.accouttype, r1.createtime, n1.nickname, n2.loanamount, n1.freqlogintype, n2.balance
# 数据的总行数: 4 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Thresa Jiran' return n1.phonenum, n2.createtime, n2.loanusage, n1.accountlevel, r1.createtime, r1.amount, n2.balance, n1.lastlogintime, n2.interestrate, n1.nickname, n1.isblocked limit 18
# 数据的总行数: 2 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n2.loanusage, n1.createtime, n1.accouttype, n1.isblocked, n1.email, n2.balance, n2.createtime, n2.loanId, n1.accountlevel, n2.loanamount, n1.phonenum, n1.lastlogintime, n1.nickname, r1.createtime, r1.amount, n1.freqlogintype limit 2
# 数据的总行数: 1 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n2.loanusage, n1.lastlogintime, n2.loanId limit 1
# 数据的总行数: 52 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n1.email, n2.interestrate, n2.loanusage, r1.amount, n1.lastlogintime, n2.loanId, n1.createtime, n1.accountlevel, n1.phonenum, n2.loanamount, r1.createtime, n1.isblocked, n1.accouttype, n1.nickname
# 数据的总行数: 52 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n2.loanId, n2.balance, n2.createtime, n1.accountlevel, r1.createtime, n1.isblocked, n2.loanamount, n1.lastlogintime, r1.amount
# 数据的总行数: 1 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Mary Cariaga' return n1.accountid, n1.createtime, r1.amount, n2.balance, n1.email, n2.loanId, n1.accountlevel, r1.createtime, n1.phonenum, n1.nickname, n1.isblocked
# 数据的总行数: 20 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Danica Gollhofer' return n1.freqlogintype, n2.interestrate, n2.loanId, n1.isblocked, n1.phonenum, n2.balance, n2.loanusage, n1.accountid, n1.accountlevel, n1.accouttype
# 数据的总行数: 15 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Danica Gollhofer' return n2.loanusage, r1.amount skip 5 limit 19
# 数据的总行数: 19 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Danica Gollhofer' return n2.balance, n2.createtime limit 19
# 数据的总行数: 20 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Danica Gollhofer' return n1.phonenum, n2.loanusage, n2.interestrate, r1.createtime, n2.loanamount, n1.createtime, n1.nickname
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Mildred Clever' return n1.isblocked, n2.loanusage, n1.accountid, n1.accouttype, n1.email, n1.accountlevel
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Mildred Clever' return n2.balance, n1.createtime, n1.phonenum, n1.lastlogintime, r1.createtime, n1.isblocked, n1.accountid, n1.freqlogintype, n2.loanamount, n2.loanusage, n2.createtime, n1.accouttype, r1.amount, n1.accountlevel, n2.loanId, n1.nickname, n1.email, n2.interestrate
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Mildred Clever' return n1.accouttype, n1.phonenum, r1.amount, n1.accountid, n1.email, r1.createtime, n1.nickname
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Mildred Clever' return n1.email, n2.loanusage, r1.createtime, n1.phonenum, n1.isblocked, n2.balance, n2.interestrate, n2.createtime, n1.lastlogintime, n1.freqlogintype, n1.nickname, n2.loanId, r1.amount, n1.createtime, n1.accountlevel
# 数据的总行数: 3 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n1.isblocked, n1.phonenum, n1.createtime, n2.createtime, n1.accountlevel skip 3 limit 3
# 数据的总行数: 13 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n1.isblocked, n1.phonenum, n2.createtime, n1.lastlogintime, n2.loanusage, n2.interestrate, n2.balance, n1.createtime, n1.email skip 17 limit 13
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n2.loanamount, n2.loanusage, n2.createtime, r1.createtime, n1.isblocked, n1.createtime, n1.accouttype
# 数据的总行数: 32 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n1.freqlogintype, r1.createtime, n1.accountlevel, n2.loanusage, n2.interestrate, n2.createtime, n1.lastlogintime, n1.createtime, n1.email, n1.nickname, n2.balance, n2.loanId
# 数据的总行数: 2 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Hope Metherell' return n1.email, n2.loanusage, n1.createtime, n1.accountlevel, n2.createtime, n1.freqlogintype, n2.balance, n1.accouttype, n2.loanamount skip 2 limit 19
# 数据的总行数: 1 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Antonietta Archbold' return n1.freqlogintype, n1.accouttype, n1.accountid limit 7
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return n1.nickname, n1.freqlogintype, n1.email, n1.isblocked, r1.amount, n1.createtime, n1.lastlogintime, r1.createtime
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return r1.amount, n1.accountlevel, n2.loanamount, n2.interestrate, n1.accouttype, n1.lastlogintime, n2.balance, n1.accountid, n2.loanId, n1.nickname, n1.freqlogintype, n2.createtime, n1.email, n1.isblocked, r1.createtime
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return n1.phonenum, n1.accountid, n2.createtime, n2.loanId, n2.balance, n2.loanusage, n1.createtime, n1.accouttype, n1.isblocked, n2.loanamount, n2.interestrate, r1.createtime, n1.accountlevel, n1.nickname, r1.amount
# 数据的总行数: 6 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return n2.loanId, n2.interestrate, r1.amount, n1.createtime, n2.loanusage, n1.email, n1.accountid, n1.phonenum, n1.lastlogintime, n2.loanamount, n1.accouttype, n2.balance, r1.createtime, n1.accountlevel, n1.isblocked, n2.createtime limit 6
# 数据的总行数: 52 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n2.loanId
# 数据的总行数: 52 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return r1.createtime, r1.amount, n2.loanusage
# 数据的总行数: 9 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n1.createtime, n1.accouttype, n1.accountlevel, n1.freqlogintype, n2.loanusage, n2.loanId, n1.email, n1.isblocked, n1.nickname, n2.createtime, n1.lastlogintime skip 19 limit 9
# 数据的总行数: 52 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n1.createtime, r1.createtime, n1.phonenum, n1.isblocked, n1.freqlogintype, n1.email, n1.nickname, n2.loanId, n2.interestrate, n1.accountid, r1.amount, n2.balance, n2.loanusage, n2.loanamount
# 数据的总行数: 42 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return r1.createtime, r1.amount, n2.interestrate, n2.loanamount, n2.loanusage, n1.phonenum, n1.isblocked
# 数据的总行数: 8 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return n2.interestrate, n2.createtime, n1.accountlevel, n1.createtime, n1.freqlogintype, n2.loanamount, n1.nickname, n2.balance, r1.amount, n1.lastlogintime, n2.loanId, n1.email, n1.accountid, r1.createtime, n1.isblocked, n2.loanusage, n1.accouttype, n1.phonenum limit 8
# 数据的总行数: 18 	 查询语句 match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Kathleen Salvador' return r1.createtime, n2.loanId, n1.accountid, n2.loanusage, n1.accountlevel, n1.nickname, n1.freqlogintype, n1.accouttype, n1.lastlogintime, n1.email, n1.createtime, n2.createtime, n2.balance, n1.isblocked, n2.interestrate, r1.amount, n2.loanamount, n1.phonenum limit 18
# 数据的总行数: 10 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Theresia Wight' return n1.isblocked, n1.freqlogintype, n2.lastlogintime, r1.goodstype, n1.createtime, n2.freqlogintype, n2.phonenum
# 数据的总行数: 3 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Peggy Gayheart' return n2.lastlogintime, r1.amount, n2.nickname, n1.isblocked, r1.ordernum, r1.goodstype, n2.phonenum, n2.isblocked, r1.comment, n1.lastlogintime, n2.accountlevel, n1.createtime, n2.accouttype, r1.paytype, n1.phonenum, n1.accountlevel, n1.email, n1.accountid, n2.accountid, r1.createtime, n2.createtime, n1.freqlogintype, n2.email, n1.accouttype, n1.nickname, n2.freqlogintype limit 3
# 数据的总行数: 4 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Theresia Wight' and n1.nickname='Peggy Gayheart' return r1.ordernum, n2.phonenum, r1.paytype, n1.createtime, n1.freqlogintype, n1.accountlevel, n2.lastlogintime, r1.comment, n1.accountid, n1.isblocked, n2.accouttype, n1.nickname, r1.goodstype, n2.email, n1.email, r1.createtime, n1.phonenum, n2.freqlogintype, n2.accountid, n1.accouttype, n1.lastlogintime, n2.nickname, n2.accountlevel, r1.amount
# 数据的总行数: 10 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Theresia Wight' return n1.accouttype, r1.comment, n2.lastlogintime, r1.createtime, n2.freqlogintype, r1.paytype, n1.lastlogintime, n1.phonenum, n2.accountlevel, n1.isblocked, n2.isblocked, n1.createtime, n1.freqlogintype, r1.ordernum, n2.accouttype, r1.amount, n2.nickname, n1.accountlevel, n1.accountid, n2.email limit 12
# 数据的总行数: 12 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Jimmie Poldrack' return n2.accountid, n1.isblocked, n2.lastlogintime, n2.email limit 12
# 数据的总行数: 20 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Andrew Sweeney' and n1.nickname='Jimmie Poldrack' return r1.ordernum, r1.createtime, n2.nickname, n1.accountlevel, n1.freqlogintype, r1.amount, n1.accouttype, r1.paytype, n2.freqlogintype, n1.phonenum, n2.accouttype, n2.phonenum, n1.accountid, n2.accountlevel, r1.comment, n2.createtime, r1.goodstype, n1.email, n1.lastlogintime, n1.nickname, n1.isblocked, n2.accountid, n1.createtime, n2.email, n2.lastlogintime
# 数据的总行数: 2 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Pamelia Vanvranken' and n1.nickname='Mohammad Creitz' return r1.createtime, n2.accountlevel, n1.email, n1.createtime, n1.lastlogintime, n2.isblocked, r1.amount, r1.ordernum, n1.freqlogintype, n1.phonenum, n2.createtime, n2.accouttype, n2.phonenum, n2.freqlogintype, n1.accouttype, n1.isblocked, n1.accountid, n2.email, r1.paytype, n2.accountid, r1.goodstype, n1.nickname, n1.accountlevel, n2.lastlogintime, n2.nickname
# 数据的总行数: 2 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Pamelia Vanvranken' and n1.nickname='Mohammad Creitz' return n1.accountid, n2.createtime, n2.isblocked, n2.phonenum, n1.accouttype, r1.comment, r1.ordernum, n2.accountlevel, n1.createtime, n1.freqlogintype, r1.paytype, n1.isblocked, n1.email, n2.lastlogintime limit 18
# 数据的总行数: 30 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Laura Hanavan' return n1.accountid, r1.ordernum, n2.accountlevel, r1.amount, r1.createtime, n2.freqlogintype, r1.comment, n1.freqlogintype, n2.email, n1.isblocked, n1.accountlevel, n2.isblocked, n2.phonenum
# 数据的总行数: 6 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Mee Litehiser' return r1.ordernum limit 6
# 数据的总行数: 4 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Laura Hanavan' and n1.nickname='Mee Litehiser' return n1.phonenum, r1.comment, r1.ordernum
# 数据的总行数: 38 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Mee Litehiser' return n2.createtime, n1.accountid, n1.accouttype, r1.ordernum, n1.phonenum, n1.createtime, n2.phonenum, n2.lastlogintime, n1.accountlevel, n2.accountlevel, n2.freqlogintype, n1.email, n1.isblocked, n1.lastlogintime, n1.freqlogintype, n2.nickname, r1.createtime, n2.isblocked
# 数据的总行数: 6 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Jacob Sheild' return r1.goodstype, n2.isblocked, r1.amount, n1.createtime, n1.freqlogintype, n2.accountlevel, n2.freqlogintype, r1.paytype, n2.nickname, n2.email, n2.accountid, n1.lastlogintime, n1.accountid, n1.accouttype, n1.phonenum limit 6
# 数据的总行数: 4 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Jacob Sheild' and n1.nickname='Betsey Kristensen' return n2.email, n1.phonenum, r1.ordernum, n2.nickname, r1.goodstype, n1.email, r1.comment, n2.accouttype
# 数据的总行数: 4 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Betsey Kristensen' and n2.nickname='Jacob Sheild' return n1.lastlogintime, n2.phonenum, r1.ordernum, n2.freqlogintype, n2.nickname, n2.isblocked, r1.goodstype, n2.accountlevel, n2.email, r1.createtime, n2.accountid, n2.lastlogintime
# 数据的总行数: 166 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Jacob Sheild' return n2.accountid, n2.accouttype, r1.createtime, n2.accountlevel, n2.createtime, r1.goodstype, n2.freqlogintype, n2.isblocked, n1.phonenum, n2.phonenum, n1.accountid, r1.ordernum
# 数据的总行数: 4 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Jimmie Poldrack' and n2.nickname='Jared Keeran' return n1.accountid, r1.amount, r1.comment, n2.phonenum, r1.goodstype, r1.paytype, n2.email, n1.createtime, n2.createtime, n1.lastlogintime, n1.email, n2.nickname
# 数据的总行数: 242 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Jimmie Poldrack' return n1.accouttype, n2.nickname, r1.createtime, n2.isblocked, n2.accountid, n2.createtime, r1.paytype, n1.freqlogintype, n2.lastlogintime, n2.freqlogintype, n1.nickname, n2.phonenum, r1.ordernum, n1.isblocked, n2.accountlevel, n1.accountid, n2.email, r1.amount, r1.comment, n1.accountlevel, n1.phonenum, r1.goodstype, n1.lastlogintime, n1.email
# 数据的总行数: 20 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Andrew Sweeney' and n1.nickname='Jimmie Poldrack' return r1.amount, n1.accountlevel, n2.email, n1.isblocked, n1.freqlogintype, n2.accountlevel, n2.freqlogintype, n1.email, r1.comment, r1.goodstype, n1.phonenum, r1.createtime, n1.createtime, n1.lastlogintime, r1.paytype, n2.createtime
# 数据的总行数: 20 	 查询语句 match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Andrew Sweeney' and n1.nickname='Jimmie Poldrack' return r1.createtime, n1.accountid, n2.accountlevel, n2.nickname, r1.amount, n2.createtime, n1.nickname, r1.comment, n2.email, n2.accountid, n2.phonenum, n1.accouttype, n2.isblocked, r1.paytype, r1.ordernum, r1.goodstype, n2.lastlogintime, n1.createtime, n1.freqlogintype
# ...
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n1.personname='Roba' and n2.companyname='Okuneva Group' return n2.companyid, n2.description, n2.country, n1.gender, n1.createtime, n2.url, n2.companyname, n1.birthday, r1.ratio, n1.city, r1.createtime, n2.createtime, n1.personId, n1.personname, n2.business, n2.isblocked, n1.country, n2.city, n1.isBlocked limit 13
# 数据的总行数: 3 	 查询语句 match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n2.companyname='Moen-Paucek' return n2.companyname, n2.isblocked, n2.business, n1.personId, n1.country, n2.url
# 数据的总行数: 7 	 查询语句 match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n2.companyname='Vandervort-Ziemann' return n1.createtime, n2.companyid, n1.personId, n1.isBlocked, n1.personname
# 数据的总行数: 3 	 查询语句 match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n2.companyname='Yundt Group' return n1.personId, n1.city, n2.isblocked, n2.city, n1.gender, n1.createtime, n1.birthday, n2.url, n2.country, r1.ratio, n1.personname, n1.isBlocked, n2.description, n2.business, n1.country, n2.createtime, n2.companyid, r1.createtime
# 数据的总行数: 6 	 查询语句 match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n2.companyname='Denesik PLC' return n1.city, n2.business
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n2.companyname='Luettgen-McGlynn' return n2.companyname, n1.isBlocked, n1.personname, r1.createtime, n1.gender, n1.personId, r1.ratio, n2.isblocked, n1.createtime, n1.birthday, n1.country, n1.city, n2.business, n2.description, n2.country, n2.city, n2.createtime
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Renato Holness' return n2.nickname, n1.personname, n1.gender, n1.birthday, n2.accouttype, n1.city, n1.country, n1.createtime, n2.freqlogintype, n2.lastlogintime
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Gunn' return n1.country, n2.accouttype, n2.accountlevel, r1.createtime, n2.accountid, n2.phonenum, n1.gender, n1.city, n1.isBlocked, n2.isblocked, n1.personname, n2.lastlogintime, n2.freqlogintype, n1.birthday limit 16
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Laverna Model' return r1.createtime, n1.createtime, n2.lastlogintime limit 18
# 数据的总行数: 6 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Hubertus Of Saxe-Coburg And Gotha' return n2.createtime, n1.gender, n1.personId, n1.city, n1.createtime, n2.email, n1.isBlocked, n2.nickname, n2.isblocked, n2.phonenum, n1.birthday, r1.createtime, n1.personname, n2.accountid
# 数据的总行数: 3 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Culver' return n1.gender, n2.accountid, n1.isBlocked, n1.personId, n2.accouttype, n2.lastlogintime, n1.personname, n2.freqlogintype, n1.country, n2.accountlevel, n2.email, n2.createtime, n1.createtime, r1.createtime, n2.phonenum, n1.birthday, n2.nickname, n1.city, n2.isblocked skip 1 limit 16
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Bethann Fasching' and n1.personname='Abutalybov' return n2.lastlogintime, n2.email, n1.personId, n1.birthday, n2.isblocked, n2.accountid, n1.personname, r1.createtime, n2.createtime, n1.gender, n1.city, n2.phonenum, n1.createtime, n1.country, n2.accountlevel, n2.nickname
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Mayra Minkoff' return n1.birthday, n1.createtime, n2.phonenum, n1.personId, n2.accouttype, n2.freqlogintype, n1.isBlocked
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Bukofzer' and n2.nickname='Linwood Musca' return n2.nickname, n2.freqlogintype, n1.birthday, n1.gender, n1.country, n2.lastlogintime, n1.personId, n1.createtime, n2.createtime, n2.phonenum, r1.createtime, n1.city, n1.isBlocked limit 14
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Quincy Palevic' return n2.phonenum, n2.lastlogintime, n2.isblocked, n1.isBlocked, n1.country, n1.city, n2.createtime, r1.createtime, n2.freqlogintype, n1.createtime, n1.personname, n1.birthday, n1.personId, n1.gender, n2.accouttype, n2.email, n2.accountid
# 数据的总行数: 3 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Copeland' return n2.nickname, n1.gender, n2.accountid, n1.personname, n2.accountlevel, n2.isblocked, n2.phonenum, n1.isBlocked, n1.createtime, n1.birthday, n2.freqlogintype, n1.personId, n1.city, n2.lastlogintime, n2.createtime, n2.accouttype, r1.createtime, n1.country skip 1 limit 5
# 数据的总行数: 3 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Farnall' return n1.personname, n2.createtime, n1.country, n2.accountlevel, n2.freqlogintype, n2.phonenum, r1.createtime, n1.personId, n2.email, n2.isblocked, n2.lastlogintime, n1.isBlocked, n1.createtime, n1.gender, n1.city, n2.accouttype
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Freeman Murchinson' return n2.freqlogintype, n2.nickname
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Von Kwiecinski' and n1.personname='Skala' return n1.country, n2.lastlogintime, n1.createtime, n1.personname, n2.accouttype limit 11
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Keri Dowless' return n1.isBlocked, n2.isblocked, n2.createtime, n1.city, n1.personname, n2.accountid, n1.country
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Mee Litehiser' and n1.personname='Ponce Enrile' return n2.freqlogintype, n1.isBlocked, n2.accouttype limit 1
# 数据的总行数: 3 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Shapiro' return n1.city, n1.birthday, n1.createtime, n1.personname, n2.email, n1.personId, r1.createtime
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Jared Keeran' and n1.personname='Bennahmias' return n2.isblocked, n2.lastlogintime, n2.createtime, r1.createtime, n1.birthday, n2.phonenum, n2.accouttype, n1.country, n1.personname
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Betsey Kristensen' and n1.personname='Sun' return n1.personId, n1.personname, n1.birthday, n2.isblocked, n1.gender, n1.country, n2.nickname, n1.isBlocked, n2.email, n2.freqlogintype, n2.accouttype, r1.createtime, n2.accountid, n2.createtime, n2.accountlevel, n2.phonenum, n1.city
# 数据的总行数: 8 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Elliot' return n2.createtime, n2.accountid, n1.personname
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Shapiro' and n2.nickname='Paula Kreiman' return n1.personId, n1.gender, n2.lastlogintime, n2.freqlogintype, n2.nickname, n1.createtime, n2.accountid, n2.phonenum, n2.isblocked, r1.createtime, n2.createtime, n1.city, n1.personname, n2.accouttype, n2.accountlevel, n1.birthday, n1.country, n2.email
# 数据的总行数: 0 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Baardsen' and n2.nickname='Laurence Mccoil' return n2.nickname, n2.phonenum, n1.createtime, n1.city, n2.accouttype, n1.birthday, n1.isBlocked, n2.accountid, n1.country, n2.email, n2.lastlogintime, n1.personname, n2.createtime, n1.personId, n2.freqlogintype, r1.createtime, n1.gender, n2.isblocked, n2.accountlevel skip 8 limit 10
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Vaccari' and n2.nickname='Norberto Cocco' return n2.freqlogintype, n2.isblocked, n1.gender, n1.personname, n1.country
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Mimi Voelkel' return n1.birthday, n1.gender
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Tsang' and n2.nickname='Jimmie Poldrack' return n2.accountlevel, n1.birthday, n1.isBlocked, n2.accouttype limit 13
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Hilario Dedecker' return n1.city, n2.phonenum, n1.birthday, n1.personname, n2.nickname, r1.createtime, n1.personId, n2.freqlogintype, n2.isblocked, n2.createtime, n2.accountid limit 14
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Crissy Rehmann' return n1.createtime, r1.createtime, n1.isBlocked, n1.gender, n2.email, n1.city, n1.country, n2.accountid, n2.lastlogintime, n1.personname, n2.accountlevel, n2.accouttype, n1.personId, n2.nickname, n2.isblocked, n1.birthday, n2.freqlogintype, n2.phonenum
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Akhavan' and n2.nickname='Mohammad Creitz' return n2.email, n1.gender
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Leo Astudillo' return n2.accountlevel, n1.isBlocked, n1.personname, n1.birthday, n1.city, n2.nickname, n2.accountid, n2.email, n1.personId, n2.accouttype, n2.isblocked, n2.phonenum, r1.createtime, n2.freqlogintype, n1.createtime, n2.createtime, n1.gender limit 5
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Andre Craigwell' return n1.gender, n2.accountlevel, n2.isblocked, n1.createtime, n2.freqlogintype, n1.birthday, r1.createtime
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Vince Moznett' return n2.lastlogintime, n2.accountid, n1.createtime, n1.personname, n2.isblocked limit 17
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Harold Apolito' and n1.personname='Sergio' return n2.accountid, n2.accouttype, n1.birthday, n2.nickname, n1.city
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Theresia Wight' and n1.personname='Lomer' return n2.createtime, n1.personId, n1.personname, n2.isblocked, n1.city, n2.accountlevel, r1.createtime, n1.birthday, n2.nickname limit 11
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Jackova' and n2.nickname='Rogelio Thaut' return n1.createtime, n2.phonenum, n1.personname, n1.isBlocked, n2.isblocked, n1.birthday, n2.nickname, n1.gender, n2.accountlevel
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Deangelo Gephart' and n1.personname='Schlingensief' return r1.createtime, n2.createtime, n2.phonenum, n1.gender, n2.nickname, n1.personId
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Eve Pusateri' and n1.personname='Le Lacheur' return n2.accountlevel, n2.nickname, n2.accouttype, n1.personname, n2.freqlogintype, n2.createtime, n2.email, n1.city, r1.createtime, n1.country, n2.accountid, n2.isblocked, n1.personId, n2.lastlogintime, n1.isBlocked, n1.gender, n1.birthday, n2.phonenum
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Tania Kensey' return n2.nickname, n2.isblocked, n2.freqlogintype, n1.createtime, r1.createtime, n1.birthday, n2.accouttype
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Alesia Dragovich' return r1.createtime, n2.freqlogintype, n2.email, n1.city, n1.personname, n1.birthday, n1.createtime, n2.nickname, n2.accountlevel, n2.accountid, n1.gender limit 6
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Donn Burgbacher' return n1.personname, n1.isBlocked, n2.email
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Arantes do Nascimento' return n2.nickname, n1.isBlocked, n1.personname, n2.accouttype, n2.accountlevel, n2.freqlogintype, n2.createtime, n1.city, n2.email, r1.createtime, n2.isblocked, n1.gender
# 数据的总行数: 0 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Beshenivsky' and n2.nickname='Bert Inverso' return n2.createtime, n2.phonenum, n2.accountid, n2.freqlogintype, n1.personname, n2.email, n1.isBlocked, n2.lastlogintime, n2.nickname, n1.personId, n2.accountlevel, r1.createtime, n2.accouttype, n1.createtime skip 10 limit 5
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Lauren Marich' return n2.isblocked, n1.birthday, r1.createtime, n2.accouttype, n2.phonenum, n2.accountlevel, n2.accountid, n2.freqlogintype, n1.personname, n2.nickname, n1.isBlocked, n2.createtime, n2.email, n1.createtime, n2.lastlogintime, n1.country
# 数据的总行数: 0 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Danica Gollhofer' and n1.personname='Algaze' return n1.personname, n2.nickname, n2.accountid, n2.email, n1.isBlocked, n2.isblocked, n1.birthday, n2.accountlevel, n2.freqlogintype, n1.personId, n1.country, n1.gender, n2.accouttype, r1.createtime, n2.phonenum, n1.createtime, n1.city, n2.createtime skip 5 limit 8
# 数据的总行数: 2 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Leverett' and n2.nickname='Rubin Maenaga' return n1.city, n2.lastlogintime, r1.createtime, n2.accountlevel, n2.accouttype, n1.country, n2.email, n2.phonenum, n1.personId, n2.accountid, n1.personname, n2.createtime, n1.gender, n1.birthday, n1.createtime, n2.nickname, n2.isblocked, n2.freqlogintype limit 17
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Sachet' and n2.nickname='Clementine Buchberger' return n2.nickname, n1.gender, n2.accouttype, n2.createtime, n2.phonenum, n2.accountlevel, n1.country, n2.accountid, n1.isBlocked, n1.createtime, n1.personId, n1.birthday, n2.isblocked, n2.email, r1.createtime, n1.city, n2.lastlogintime
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Stephan Esqueda' and n1.personname='Shapiro' return n1.city, n2.freqlogintype, n1.createtime, n1.personname, r1.createtime, n1.isBlocked, n1.birthday, n2.accountlevel, n2.nickname, n2.accouttype, n2.lastlogintime, n1.personId, n1.gender, n2.isblocked, n2.phonenum, n2.email, n2.accountid, n1.country, n2.createtime limit 18
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Andrew Sweeney' return n1.gender, n1.birthday, n1.city, n2.accountlevel, n2.createtime, n1.createtime, n1.personId limit 20
# 数据的总行数: 1 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Lolita Desilvo' return n2.isblocked, r1.createtime, n2.accouttype, n1.country, n1.gender, n1.isBlocked, n2.phonenum, n2.lastlogintime, n2.createtime, n2.email, n2.accountlevel, n1.birthday, n2.freqlogintype, n1.city, n2.nickname, n1.personname, n1.createtime
# 数据的总行数: 0 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Valderrama' and n2.nickname='Ferdinand Columbia' return n2.lastlogintime, n1.gender, n2.nickname, n1.personId, n1.personname, n2.phonenum, n2.email, n2.accouttype, n1.birthday, n2.accountlevel, n2.isblocked, n2.createtime skip 15 limit 7
# 数据的总行数: 7 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Carranza' return n2.nickname, n2.accouttype, n2.accountid, n1.personname, n1.isBlocked, n1.createtime, n1.country, n2.phonenum, n2.freqlogintype, r1.createtime, n2.lastlogintime, n2.createtime, n1.gender
# 数据的总行数: 8 	 查询语句 match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Janson' return n2.phonenum, n1.createtime, n2.nickname, n1.personId, n2.accouttype, n1.city, n1.isBlocked, n1.gender, n2.accountlevel, n1.birthday, r1.createtime, n2.lastlogintime, n2.freqlogintype, n2.accountid, n2.createtime, n1.country
# 654

# %%
import re
import json
node_pattern = re.compile(r'(.+?)\[(.+?)\](\{.*?\})', re.S)
edge_pattern = re.compile(r'(.+?)\[(.+?)\]\[(.+?),(.+?)\](\{.*?\})', re.S)
def resolve_node(row_data):
    m = node_pattern.match(row_data)
    label = m.group(1)
    vid = m.group(2)
    props = json.loads(m.group(3))
    return (label, vid, props)

def resolve_edge(row_data):
    m = edge_pattern.match(row_data)
    label = m.group(1)
    eid = m.group(2)
    start = m.group(3)
    end = m.group(4)
    props = json.loads(m.group(5))
    return (label, eid, start, end, props)

def resolve_path(row_data):
    edges = []
    allmatch = edge_pattern.findall(row_data)
    for m in allmatch:
        label = m[0]
        if label.startswith(","):
            label =label[1:]
        eid = m[1]
        start = m[2]
        end = m[3]
        props = json.loads(m[4])
        edges.append( (label, eid, start, end, props))
    print(edges)
    return edges

schema_ldbc_info = {}

edge_schema = []
node_schema = []
## 对schema进行查询
import psycopg

pg_con = psycopg.connect(
            dbname="postgres",
            host="localhost",
            user="omm",
            password="ZAQ1234@esz",
            port=5432)
     
nodes = set()

edge_query = 'match (n)-[r]->(m) return n,r,m'

cur = pg_con.cursor()
cur.execute(f"set graph_path = {schema_name}")
### 节点类型
cur.execute(edge_query)
rows = cur.fetchall()

for row in rows:

    edge_desc= ""
    start_label_desc = ""
    end_label_desc = ""
    for i in range(len(row)):
            row_data = str(row[i])
            is_node = node_pattern.match(row_data)
            is_edge = edge_pattern.match(row_data)
            if is_edge:
                edge = resolve_edge(row_data)
                edge_label = edge[4]['name']
                edge_desc = '边的类型为：'+ edge_label

            elif is_node:
                node = resolve_node(row_data)
                node_label = node[2]['name']
                nodes.add(node_label)
                if i > 1:
                    end_label_desc = "终点类型为:"+ node_label
                else:
                    start_label_desc = "起点类型为:"+ node_label  
    edge_schema.append(edge_desc+','+start_label_desc+','+end_label_desc)
  

schema_ldbc_info['edges'] = edge_schema

cur.execute(f"set graph_path = {graph_path}")
for node in list(nodes):
    query = 'match (n:'+node+') return keys(n) limit 1'   
    ### 节点类型
    cur.execute(query)
    rows = cur.fetchall()
    for row in rows:
        node_schema.append("节点类型:"+node+',包含属性信息:' + str(row))

schema_ldbc_info['nodes'] = node_schema

# 方法一：使用json.dump()函数保存为JSON格式并写入文件
with open(f"schema_{graph_path}_info.json", "w") as file:
    json.dump(schema_ldbc_info, file,indent=4,ensure_ascii=False)
print(schema_ldbc_info)
pg_con.close()
# Out:
# {'edges': ['边的类型为：accounttransferaccount,起点类型为:account,终点类型为:account', '边的类型为：accountwithdrawaccount,起点类型为:account,终点类型为:account', '边的类型为：loandepositaccount,起点类型为:loan,终点类型为:account', '边的类型为：mediumsigninaccount,起点类型为:medium,终点类型为:account', '边的类型为：personownaccount,起点类型为:person,终点类型为:account', '边的类型为：companyguaranteecompany,起点类型为:company,终点类型为:company', '边的类型为：companyinvestcompany,起点类型为:company,终点类型为:company', '边的类型为：personinvestcompany,起点类型为:person,终点类型为:company', '边的类型为：accountrepayloan,起点类型为:account,终点类型为:loan', '边的类型为：companyapplyloan,起点类型为:company,终点类型为:loan', '边的类型为：personapplyLoan,起点类型为:person,终点类型为:loan', '边的类型为：personguaranteeperson,起点类型为:person,终点类型为:person'], 'nodes': ["节点类型:medium,包含属性信息:(['mediumId', 'isblocked', 'risklevel', 'createtime', 'mediumtype', 'lastlogintime'],)", "节点类型:person,包含属性信息:(['city', 'gender', 'country', 'birthday', 'personId', 'isBlocked', 'createtime', 'personname'],)", "节点类型:account,包含属性信息:(['email', 'nickname', 'phonenum', 'accountid', 'isblocked', 'accouttype', 'createtime', 'accountlevel', 'freqlogintype', 'lastlogintime'],)", "节点类型:company,包含属性信息:(['url', 'city', 'country', 'business', 'companyid', 'isblocked', 'createtime', 'companyname', 'description'],)", "节点类型:loan,包含属性信息:(['loanId', 'balance', 'loanusage', 'createtime', 'loanamount', 'interestrate'],)"]}

# %% [markdown]
# ### 这时候应该把上边的数据通过大的语言模型弄出自然语句查询来
# ### 大模型生成问答对之后再加入向量的上下文信息
# ### 执行下边这个代码的同时 可以执行第三个文件 生成通义千问的问答向量

# %%
# 安装 pip install -U dashscope

import json
import os
import dashscope

 

# 方法一：使用json.dump()函数保存为JSON格式并写入文件
with open("cypher_base_with_limit_skip_query_filter_none.json", "r") as file:
    cypher_base_with_limit_skip_query = json.load(file) 
    
cypher_querys = random.sample(cypher_base_with_limit_skip_query,240)

query_pair = []


for query in cypher_querys:
    response = dashscope.Generation.call(
    # 若没有配置环境变量，请用百炼API Key将下行替换为：api_key="sk-xxx",
    api_key='sk-8f8adba56edf4a29a185fb57c5808a1e',
    model="qwen-plus-2024-09-19", # 模型列表：https://help.aliyun.com/zh/model-studio/getting-started/models
    messages= [
        {"role": "user", "content": "我正在开发一个自然语言转Cypher的接口，但是我没有自然语言描述，你现在是一名Cypher图查询语言专家，你需要将我的Cypher查询语言转换为自然语言描述,使用中文描述,明确返回值所属的变量，只返回描述即可，不需要过多解释，一定要符合人类的自然语言描述习惯、有些查询不需要指明节点的label信息"},
        {"role": "assistant", "content": "好的"},
        {"role": "user", "content": "match (n1:forum)  where n1.title='Album 1 of Hossein Forouhar' return n1.id, n1.\"creationDate\", n1.title"},
        {"role": "assistant", "content": "查找Album 1 of Hossein Forouhar的id,创建日期和他的标题"},
        {"role": "user", "content": "match (n1:forum)-[r1:hastagforum]->(n2:tag)  where n1.title='Wall of Wojciech Ciesla' return n2.id, n2.name"},
        {"role": "assistant", "content": "查找Wall of Wojciech Ciesla的具有的标签信息的id和名称"},
            {"role": "user", "content": query},
    ],
    result_format='message'
    )
    print(response)
    nl_query = response.output.choices[0].message.content
    print(nl_query)
    print(query)
    query_pair.append({nl_query:query})

# 方法一：使用json.dump()函数保存为JSON格式并写入文件
with open("tongyi_query_pair_query.json", "w", encoding="utf-8") as file:
    json.dump(query_pair, file,indent=4,ensure_ascii=False)
# Out:
# {"status_code": 200, "request_id": "db82a1f6-b75c-929c-902b-980fbe554609", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Flachi投资的公司Little-Bergstrom的业务范围、公司名称、Flachi的创建时间、公司的国家和网址以及Flachi的性别"}}]}, "usage": {"input_tokens": 302, "output_tokens": 32, "total_tokens": 334}}
# 查找Flachi投资的公司Little-Bergstrom的业务范围、公司名称、Flachi的创建时间、公司的国家和网址以及Flachi的性别
# match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n2.companyname='Little-Bergstrom' and n1.personname='Flachi' return n2.business, n2.companyname, n1.createtime, n2.country, n2.url, n1.gender
# {"status_code": 200, "request_id": "c419f852-b4df-9426-b07f-17be893bcafd", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找名为Night的人对Herman-Bechtelar公司的投资比例，以及Night所在的城市、国家、是否被封禁，Herman-Bechtelar公司的网址、描述、国家、创建时间、公司名称和业务领域。"}}]}, "usage": {"input_tokens": 322, "output_tokens": 51, "total_tokens": 373}}
# 查找名为Night的人对Herman-Bechtelar公司的投资比例，以及Night所在的城市、国家、是否被封禁，Herman-Bechtelar公司的网址、描述、国家、创建时间、公司名称和业务领域。
# match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n1.personname='Night' and n2.companyname='Herman-Bechtelar' return n1.city, n2.url, n2.description, n1.country, n2.country, n2.createtime, n1.isBlocked, n2.companyname, n2.business, r1.ratio
# {"status_code": 200, "request_id": "5465baaa-3633-96be-9629-f494b62d44c8", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Von Kwiecinski且登录方式为IPv6的账号类型和最后登录时间"}}]}, "usage": {"input_tokens": 289, "output_tokens": 22, "total_tokens": 311}}
# 查找昵称为Von Kwiecinski且登录方式为IPv6的账号类型和最后登录时间
# match (n1:medium)-[r1:mediumsigninaccount]->(n2:account)  where n2.nickname='Von Kwiecinski' and n1.mediumtype='IPv6' return n2.accouttype, n1.lastlogintime
# {"status_code": 200, "request_id": "a787caa4-f8e9-9943-b23d-22ea4e253bd8", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Cordelia Ratcliffe的账户关联的贷款信息，包括贷款金额、账户类型、存款金额、电话号码、贷款用途和余额，最多返回20条记录。"}}]}, "usage": {"input_tokens": 304, "output_tokens": 39, "total_tokens": 343}}
# 查找与Cordelia Ratcliffe的账户关联的贷款信息，包括贷款金额、账户类型、存款金额、电话号码、贷款用途和余额，最多返回20条记录。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Cordelia Ratcliffe' return n1.loanamount, n2.accouttype, r1.amount, n2.phonenum, n1.loanusage, n1.balance limit 20
# {"status_code": 200, "request_id": "1c95c8e4-7794-95a9-8a11-82d6877a7ba6", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找公司名称为Little Inc的公司名称、国家、网址、业务和描述"}}]}, "usage": {"input_tokens": 271, "output_tokens": 17, "total_tokens": 288}}
# 查找公司名称为Little Inc的公司名称、国家、网址、业务和描述
# match (n1:company)  where n1.companyname='Little Inc' return n1.companyname, n1.country, n1.url, n1.business, n1.description
# {"status_code": 200, "request_id": "b5092976-5dba-9b81-89ef-e064a5a3b7c3", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Morissette Inc担保的公司Zemlak and Sons的相关信息，包括Zemlak and Sons的网址、业务、公司ID、城市、公司名称、是否被封禁、创建时间，以及Morissette Inc的描述、业务、创建时间、城市、关系、公司ID、是否被封禁、创建时间、网址和国家。"}}]}, "usage": {"input_tokens": 367, "output_tokens": 77, "total_tokens": 444}}
# 查找Morissette Inc担保的公司Zemlak and Sons的相关信息，包括Zemlak and Sons的网址、业务、公司ID、城市、公司名称、是否被封禁、创建时间，以及Morissette Inc的描述、业务、创建时间、城市、关系、公司ID、是否被封禁、创建时间、网址和国家。
# match (n1:company)-[r1:companyguaranteecompany]->(n2:company)  where n1.companyname='Morissette Inc' and n2.companyname='Zemlak and Sons' return n2.url, n1.createtime, n2.business, n2.companyid, n2.city, n2.companyname, n2.isblocked, n1.description, n1.business, n2.createtime, n1.city, r1.relation, n1.companyid, n1.isblocked, r1.createtime, n1.url, n1.country, n1.companyname
# {"status_code": 200, "request_id": "9ef0d494-b841-91e0-8e83-c723c7941834", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Drew Hamamoto从Peggy Gayheart账户中提现的信息，包括Drew Hamamoto的手机号、邮箱、账户等级、创建时间、常用登录类型、昵称，以及Peggy Gayheart的账户ID、昵称、账户类型、最后登录时间、手机号、是否被封禁，还有提现记录的创建时间。"}}]}, "usage": {"input_tokens": 354, "output_tokens": 73, "total_tokens": 427}}
# 查找Drew Hamamoto从Peggy Gayheart账户中提现的信息，包括Drew Hamamoto的手机号、邮箱、账户等级、创建时间、常用登录类型、昵称，以及Peggy Gayheart的账户ID、昵称、账户类型、最后登录时间、手机号、是否被封禁，还有提现记录的创建时间。
# match (n1:account)-[r1:accountwithdrawaccount]->(n2:account)  where n2.nickname='Peggy Gayheart' and n1.nickname='Drew Hamamoto' return n1.phonenum, n2.accountid, n2.nickname, n2.accouttype, n2.lastlogintime, n1.email, n1.accountlevel, n2.phonenum, n1.createtime, n2.freqlogintype, n1.freqlogintype, n1.nickname, n2.isblocked, r1.createtime
# {"status_code": 200, "request_id": "26d1efb8-479b-9bfc-a670-05a45ca5f790", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找公司Schmidt-Schroeder的国家、城市和网址"}}]}, "usage": {"input_tokens": 266, "output_tokens": 14, "total_tokens": 280}}
# 查找公司Schmidt-Schroeder的国家、城市和网址
# match (n1:company)  where n1.companyname='Schmidt-Schroeder' return n1.country, n1.city, n1.url
# {"status_code": 200, "request_id": "cce9bab0-d0fe-964b-960b-ec3a123bdb13", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Carissa Pasqualetti向Damian Warsing转账的时间，以及Damian Warsing的最后登录时间"}}]}, "usage": {"input_tokens": 290, "output_tokens": 24, "total_tokens": 314}}
# 查找Carissa Pasqualetti向Damian Warsing转账的时间，以及Damian Warsing的最后登录时间
# match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Carissa Pasqualetti' and n2.nickname='Damian Warsing' return r1.createtime, n2.lastlogintime
# {"status_code": 200, "request_id": "29065c8e-8c76-9424-ba93-1c00fea699e8", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Buck Morles的账户信息及其转账给其他账户的信息，包括Buck Morles的最后登录时间、账户等级、常用登录类型、转账金额、商品类型，以及接收方账户的是否被封禁、最后登录时间、昵称、账户ID、创建时间、Buck Morles的昵称、接收方的邮箱、Buck Morles的手机号、接收方的手机号、接收方的常用登录类型、转账订单号、Buck Morles的账户ID、接收方的账户类型、Buck Morles的邮箱、Buck Morles的是否被封禁。"}}]}, "usage": {"input_tokens": 374, "output_tokens": 128, "total_tokens": 502}}
# 查找Buck Morles的账户信息及其转账给其他账户的信息，包括Buck Morles的最后登录时间、账户等级、常用登录类型、转账金额、商品类型，以及接收方账户的是否被封禁、最后登录时间、昵称、账户ID、创建时间、Buck Morles的昵称、接收方的邮箱、Buck Morles的手机号、接收方的手机号、接收方的常用登录类型、转账订单号、Buck Morles的账户ID、接收方的账户类型、Buck Morles的邮箱、Buck Morles的是否被封禁。
# match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Buck Morles' return n1.lastlogintime, n1.accountlevel, n1.freqlogintype, r1.amount, r1.goodstype, n2.isblocked, n2.lastlogintime, n2.nickname, n2.accountid, r1.createtime, n1.nickname, n2.email, n1.phonenum, n2.phonenum, n2.freqlogintype, r1.ordernum, n1.accountid, n2.accouttype, n1.email, n1.isblocked
# {"status_code": 200, "request_id": "36379edc-00af-9792-869c-822f81d94b73", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Milford Zolla的账户级别、登录频率类型、邮箱、昵称，以及他转账给的账户的昵称、邮箱和创建时间，同时返回转账记录的创建时间"}}]}, "usage": {"input_tokens": 305, "output_tokens": 40, "total_tokens": 345}}
# 查找Milford Zolla的账户级别、登录频率类型、邮箱、昵称，以及他转账给的账户的昵称、邮箱和创建时间，同时返回转账记录的创建时间
# match (n1:account)-[r1:accountwithdrawaccount]->(n2:account)  where n1.nickname='Milford Zolla' return n1.accountlevel, n2.nickname, n1.freqlogintype, r1.createtime, n1.email, n2.email, n2.createtime, n1.nickname
# {"status_code": 200, "request_id": "38867fd7-1dc7-995a-ac02-b2da0d41896a", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找IPv4类型的最后登录时间和风险级别"}}]}, "usage": {"input_tokens": 263, "output_tokens": 9, "total_tokens": 272}}
# 查找IPv4类型的最后登录时间和风险级别
# match (n1:medium)  where n1.mediumtype='IPv4' return n1.lastlogintime, n1.risklevel
# {"status_code": 200, "request_id": "e05c2447-3acc-92af-92fe-7e7a7f49abc6", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Doyle LLC投资的公司的投资比例和Doyle LLC是否被封禁的状态"}}]}, "usage": {"input_tokens": 275, "output_tokens": 18, "total_tokens": 293}}
# 查找Doyle LLC投资的公司的投资比例和Doyle LLC是否被封禁的状态
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n1.companyname='Doyle LLC' return r1.ratio, n1.isblocked
# {"status_code": 200, "request_id": "722c0518-63af-9c16-8738-c4ede7571526", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找公司名为Lockman Ltd的公司的网址、是否被封禁、公司名、描述、公司ID、国家、创建时间和城市，最多返回11条结果"}}]}, "usage": {"input_tokens": 292, "output_tokens": 35, "total_tokens": 327}}
# 查找公司名为Lockman Ltd的公司的网址、是否被封禁、公司名、描述、公司ID、国家、创建时间和城市，最多返回11条结果
# match (n1:company)  where n1.companyname='Lockman Ltd' return n1.url, n1.isblocked, n1.companyname, n1.description, n1.companyid, n1.country, n1.createtime, n1.city limit 11
# {"status_code": 200, "request_id": "5a60eae9-5edd-9379-80bd-489af4205de0", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找McCullough-Witting公司申请的贷款信息，包括贷款ID、公司名称、贷款金额、公司创建时间、贷款利率、公司网址、公司ID、贷款创建时间、公司所在国家、组织类型、公司所在城市、公司描述、创建时间、贷款用途、公司是否被封锁、贷款余额和公司业务类型。"}}]}, "usage": {"input_tokens": 352, "output_tokens": 71, "total_tokens": 423}}
# 查找McCullough-Witting公司申请的贷款信息，包括贷款ID、公司名称、贷款金额、公司创建时间、贷款利率、公司网址、公司ID、贷款创建时间、公司所在国家、组织类型、公司所在城市、公司描述、创建时间、贷款用途、公司是否被封锁、贷款余额和公司业务类型。
# match (n1:company)-[r1:companyapplyloan]->(n2:loan)  where n1.companyname='McCullough-Witting' return n2.loanId, n1.companyname, n2.loanamount, n1.createtime, n2.interestrate, n1.url, n1.companyid, n2.createtime, n1.country, r1.org, n1.city, n1.description, r1.createtime, n2.loanusage, n1.isblocked, n2.balance, n1.business
# {"status_code": 200, "request_id": "0cbf2451-ae92-9dc8-9843-0282b7c217bd", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Danica Gollhofer的账户级别和账户类型"}}]}, "usage": {"input_tokens": 264, "output_tokens": 13, "total_tokens": 277}}
# 查找Danica Gollhofer的账户级别和账户类型
# match (n1:account)  where n1.nickname='Danica Gollhofer' return n1.accountlevel, n1.accouttype
# {"status_code": 200, "request_id": "979a200a-e0e1-9e5a-88c7-fb4e7057923e", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Jacobson-Yost公司被投资的描述信息，以及投资方的网址，最多返回13条记录"}}]}, "usage": {"input_tokens": 278, "output_tokens": 24, "total_tokens": 302}}
# 查找Jacobson-Yost公司被投资的描述信息，以及投资方的网址，最多返回13条记录
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n2.companyname='Jacobson-Yost' return n2.description, n1.url limit 13
# {"status_code": 200, "request_id": "2ce9839a-428f-9d6c-b484-89cfba824e52", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Kerluke-Kilback公司的国家、是否被封禁、公司名称、业务、公司ID和创建时间"}}]}, "usage": {"input_tokens": 284, "output_tokens": 26, "total_tokens": 310}}
# 查找Kerluke-Kilback公司的国家、是否被封禁、公司名称、业务、公司ID和创建时间
# match (n1:company)  where n1.companyname='Kerluke-Kilback' return n1.country, n1.isblocked, n1.companyname, n1.business, n1.companyid, n1.createtime
# {"status_code": 200, "request_id": "9fae336d-df48-93ef-9360-d2ffaef83bbf", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Fredric Nothstine的账户信息及其相关的转账记录，包括转账类型、订单号、创建时间、商品类型，以及转账双方的账户ID、登录频率、最后登录时间、账户等级、昵称、电话号码、邮箱、是否被封禁、创建时间和转账金额。"}}]}, "usage": {"input_tokens": 386, "output_tokens": 63, "total_tokens": 449}}
# 查找Fredric Nothstine的账户信息及其相关的转账记录，包括转账类型、订单号、创建时间、商品类型，以及转账双方的账户ID、登录频率、最后登录时间、账户等级、昵称、电话号码、邮箱、是否被封禁、创建时间和转账金额。
# match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Fredric Nothstine' return n2.accountid, n2.freqlogintype, n2.lastlogintime, r1.paytype, n2.accountlevel, n1.freqlogintype, r1.comment, n1.nickname, n2.phonenum, r1.amount, n2.isblocked, n1.accouttype, n2.email, n1.accountlevel, n2.nickname, n1.lastlogintime, n1.createtime, r1.ordernum, r1.createtime, n1.email, n1.phonenum, r1.goodstype
# {"status_code": 200, "request_id": "dd71eccf-60bb-9a61-8f34-43ca5f0f4f49", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Buck Morles向Fredric Nothstine转账的详细信息，包括转账金额、备注、支付方式，以及双方的账号类型、登录频率类型、是否被封禁、邮箱、最后登录时间、账号ID、创建时间、手机号、账号等级。"}}]}, "usage": {"input_tokens": 374, "output_tokens": 58, "total_tokens": 432}}
# 查找Buck Morles向Fredric Nothstine转账的详细信息，包括转账金额、备注、支付方式，以及双方的账号类型、登录频率类型、是否被封禁、邮箱、最后登录时间、账号ID、创建时间、手机号、账号等级。
# match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Buck Morles' and n2.nickname='Fredric Nothstine' return n2.freqlogintype, n1.isblocked, n2.accouttype, r1.comment, n1.freqlogintype, n1.email, n2.lastlogintime, n2.accountlevel, r1.paytype, n2.phonenum, n1.lastlogintime, n2.accountid, n1.createtime, n2.createtime, n2.nickname, n2.isblocked, r1.amount, n2.email
# {"status_code": 200, "request_id": "0dbb18d6-aa46-9737-86c5-8d4988fe2759", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Gennie Mautz向Fredric Nothstine转账的创建时间、评论、支付类型、转账创建时间、Fredric Nothstine的账户是否被封禁、账户ID、常用登录类型、Gennie Mautz的常用登录类型、转账的商品类型以及Gennie Mautz的账户是否被封禁"}}]}, "usage": {"input_tokens": 333, "output_tokens": 72, "total_tokens": 405}}
# 查找Gennie Mautz向Fredric Nothstine转账的创建时间、评论、支付类型、转账创建时间、Fredric Nothstine的账户是否被封禁、账户ID、常用登录类型、Gennie Mautz的常用登录类型、转账的商品类型以及Gennie Mautz的账户是否被封禁
# match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n2.nickname='Fredric Nothstine' and n1.nickname='Gennie Mautz' return n1.createtime, r1.comment, r1.paytype, r1.createtime, n2.isblocked, n2.accountid, n2.freqlogintype, n1.freqlogintype, r1.goodstype, n1.isblocked
# {"status_code": 200, "request_id": "b17e6776-affd-957b-b4d0-0e8729633303", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找名为Rowe的生日、个人ID和所在城市"}}]}, "usage": {"input_tokens": 264, "output_tokens": 12, "total_tokens": 276}}
# 查找名为Rowe的生日、个人ID和所在城市
# match (n1:person)  where n1.personname='Rowe' return n1.birthday, n1.personId, n1.city
# {"status_code": 200, "request_id": "2ee6bad6-ec1c-92b3-bd77-76c9c3911273", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Faustino Marolf的账号的登录频率类型、账号ID、手机号、账号类型、是否被封禁、创建时间、账号等级、昵称和最后登录时间"}}]}, "usage": {"input_tokens": 303, "output_tokens": 40, "total_tokens": 343}}
# 查找昵称为Faustino Marolf的账号的登录频率类型、账号ID、手机号、账号类型、是否被封禁、创建时间、账号等级、昵称和最后登录时间
# match (n1:account)  where n1.nickname='Faustino Marolf' return n1.freqlogintype, n1.accountid, n1.phonenum, n1.accouttype, n1.isblocked, n1.createtime, n1.accountlevel, n1.nickname, n1.lastlogintime
# {"status_code": 200, "request_id": "bdf865a8-e675-99f9-bdd1-1b7f392ab335", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Cordelia Ratcliffe的账户相关的贷款信息，包括账户的创建时间、常用登录类型、贷款金额、贷款用途、最后登录时间、电话号码、贷款余额和账户邮箱，最多返回8条记录。"}}]}, "usage": {"input_tokens": 321, "output_tokens": 48, "total_tokens": 369}}
# 查找与Cordelia Ratcliffe的账户相关的贷款信息，包括账户的创建时间、常用登录类型、贷款金额、贷款用途、最后登录时间、电话号码、贷款余额和账户邮箱，最多返回8条记录。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Cordelia Ratcliffe' return n2.createtime, n2.freqlogintype, r1.amount, n1.loanusage, n2.lastlogintime, n2.phonenum, n1.balance, n2.email, n1.loanamount limit 8
# {"status_code": 200, "request_id": "52120e22-3a4a-9e66-9dac-0f19fd9ec22e", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Quincy Palevic的账号的手机号、最后登录时间、是否被封禁、拥有该账号的人是否被封禁、国家、城市、账号创建时间、关系创建时间、常用登录类型、拥有该账号的人的创建时间、姓名、生日、个人ID、性别、账号类型、邮箱和账号ID"}}]}, "usage": {"input_tokens": 355, "output_tokens": 70, "total_tokens": 425}}
# 查找昵称为Quincy Palevic的账号的手机号、最后登录时间、是否被封禁、拥有该账号的人是否被封禁、国家、城市、账号创建时间、关系创建时间、常用登录类型、拥有该账号的人的创建时间、姓名、生日、个人ID、性别、账号类型、邮箱和账号ID
# match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Quincy Palevic' return n2.phonenum, n2.lastlogintime, n2.isblocked, n1.isBlocked, n1.country, n1.city, n2.createtime, r1.createtime, n2.freqlogintype, n1.createtime, n1.personname, n1.birthday, n1.personId, n1.gender, n2.accouttype, n2.email, n2.accountid
# {"status_code": 200, "request_id": "c9c76b8d-46c6-9c02-a6e1-8e46cf7d2d21", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Lynch-Green公司担保的Monahan PLC公司的详细信息，包括Lynch-Green的网址、创建时间、是否被封禁、国家和公司名称，以及Monahan PLC的创建时间、公司名称、描述、是否被封禁、业务领域、城市、国家和网址。"}}]}, "usage": {"input_tokens": 339, "output_tokens": 63, "total_tokens": 402}}
# 查找Lynch-Green公司担保的Monahan PLC公司的详细信息，包括Lynch-Green的网址、创建时间、是否被封禁、国家和公司名称，以及Monahan PLC的创建时间、公司名称、描述、是否被封禁、业务领域、城市、国家和网址。
# match (n1:company)-[r1:companyguaranteecompany]->(n2:company)  where n1.companyname='Lynch-Green' and n2.companyname='Monahan PLC' return n1.url, n1.createtime, n2.createtime, n2.companyname, n1.isblocked, n2.description, n2.isblocked, n2.business, n2.city, n1.country, n1.companyname, n2.url, n2.country
# {"status_code": 200, "request_id": "f95d4fd4-2474-9ba2-a363-5b54c31b57e4", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Pamelia Vanvranken的账号的账号ID、手机号、创建时间、常用登录类型、账号等级、账号类型、邮箱、最后登录时间和昵称"}}]}, "usage": {"input_tokens": 304, "output_tokens": 38, "total_tokens": 342}}
# 查找昵称为Pamelia Vanvranken的账号的账号ID、手机号、创建时间、常用登录类型、账号等级、账号类型、邮箱、最后登录时间和昵称
# match (n1:account)  where n1.nickname='Pamelia Vanvranken' return n1.accountid, n1.phonenum, n1.createtime, n1.freqlogintype, n1.accountlevel, n1.accouttype, n1.email, n1.lastlogintime, n1.nickname
# {"status_code": 200, "request_id": "d01a44ef-8158-925d-96b4-b3e5ac338cae", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Leo Astudillo的账户及其拥有者的详细信息，包括账户等级、拥有者是否被封禁、姓名、生日、城市、昵称、账户ID、邮箱、个人ID、账户类型、账户是否被封禁、手机号、关系创建时间、账户常用登录方式、拥有者创建时间和账户创建时间，限制返回5条结果。"}}]}, "usage": {"input_tokens": 356, "output_tokens": 77, "total_tokens": 433}}
# 查找昵称为Leo Astudillo的账户及其拥有者的详细信息，包括账户等级、拥有者是否被封禁、姓名、生日、城市、昵称、账户ID、邮箱、个人ID、账户类型、账户是否被封禁、手机号、关系创建时间、账户常用登录方式、拥有者创建时间和账户创建时间，限制返回5条结果。
# match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Leo Astudillo' return n2.accountlevel, n1.isBlocked, n1.personname, n1.birthday, n1.city, n2.nickname, n2.accountid, n2.email, n1.personId, n2.accouttype, n2.isblocked, n2.phonenum, r1.createtime, n2.freqlogintype, n1.createtime, n2.createtime, n1.gender limit 5
# {"status_code": 200, "request_id": "7e61cf38-cad8-9362-ac42-35d4209c5e92", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "跳过1条记录，限制返回5条记录，查找与Faustino Marolf账户关联的贷款信息，包括账户昵称、账户ID、贷款余额、账户等级、贷款ID、账户是否被封、贷款用途、贷款创建时间、账户常用登录类型、账户电话号码、贷款金额和账户创建时间。"}}]}, "usage": {"input_tokens": 340, "output_tokens": 70, "total_tokens": 410}}
# 跳过1条记录，限制返回5条记录，查找与Faustino Marolf账户关联的贷款信息，包括账户昵称、账户ID、贷款余额、账户等级、贷款ID、账户是否被封、贷款用途、贷款创建时间、账户常用登录类型、账户电话号码、贷款金额和账户创建时间。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Faustino Marolf' return n2.nickname, n2.accountid, n1.balance, n2.accountlevel, n1.loanId, n2.isblocked, n1.loanusage, n1.createtime, n2.freqlogintype, n2.phonenum, n1.loanamount, n2.createtime skip 1 limit 5
# {"status_code": 200, "request_id": "628cb8b8-da3c-9de1-ba57-110bd844e555", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Kautzer-Stamm公司为Bechtelar Inc公司提供担保的业务信息，限制返回2条结果"}}]}, "usage": {"input_tokens": 289, "output_tokens": 25, "total_tokens": 314}}
# 查找Kautzer-Stamm公司为Bechtelar Inc公司提供担保的业务信息，限制返回2条结果
# match (n1:company)-[r1:companyguaranteecompany]->(n2:company)  where n2.companyname='Bechtelar Inc' and n1.companyname='Kautzer-Stamm' return n1.business limit 2
# {"status_code": 200, "request_id": "406f60a8-3b3d-99fa-9385-ecf409963a68", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Thresa Jiran的邮箱、与她关联的贷款余额、她的昵称、账户类型、贷款利率以及账户是否被冻结的信息。"}}]}, "usage": {"input_tokens": 296, "output_tokens": 31, "total_tokens": 327}}
# 查找Thresa Jiran的邮箱、与她关联的贷款余额、她的昵称、账户类型、贷款利率以及账户是否被冻结的信息。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Thresa Jiran' return n2.email, n1.balance, n2.nickname, n2.accouttype, n1.interestrate, n2.isblocked
# {"status_code": 200, "request_id": "17dcf9f2-7eb4-9490-882a-f62acef01649", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找类型为IPv6的介质的风险级别"}}]}, "usage": {"input_tokens": 256, "output_tokens": 9, "total_tokens": 265}}
# 查找类型为IPv6的介质的风险级别
# match (n1:medium)  where n1.mediumtype='IPv6' return n1.risklevel
# {"status_code": 200, "request_id": "a9cfe988-16b5-9298-8c90-db0055460e74", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Eve Pusateri的账号创建时间"}}]}, "usage": {"input_tokens": 259, "output_tokens": 11, "total_tokens": 270}}
# 查找Eve Pusateri的账号创建时间
# match (n1:account)  where n1.nickname='Eve Pusateri' return n1.createtime
# {"status_code": 200, "request_id": "b2faf7b4-034d-92b1-b6ba-8061c32da3f4", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找类型为QRCode的medium的mediumId"}}]}, "usage": {"input_tokens": 255, "output_tokens": 10, "total_tokens": 265}}
# 查找类型为QRCode的medium的mediumId
# match (n1:medium)  where n1.mediumtype='QRCode' return n1.mediumId
# {"status_code": 200, "request_id": "6ea7e269-6ab7-9783-95d6-584a7c2dcf57", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Dickens-Ward担保的公司信息，包括被担保公司的国家、担保关系、Dickens-Ward的公司名称和业务范围，以及被担保公司的描述"}}]}, "usage": {"input_tokens": 291, "output_tokens": 35, "total_tokens": 326}}
# 查找Dickens-Ward担保的公司信息，包括被担保公司的国家、担保关系、Dickens-Ward的公司名称和业务范围，以及被担保公司的描述
# match (n1:company)-[r1:companyguaranteecompany]->(n2:company)  where n1.companyname='Dickens-Ward' return n2.country, r1.relation, n1.companyname, n1.business, n2.description
# {"status_code": 200, "request_id": "c5d94f75-844a-9db2-9205-5d1944db464f", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Von Kwiecinski的账户及其关联的媒体信息，包括账户昵称、媒体风险级别、关联关系创建时间、账户是否被封禁、常用登录类型、账户类型、手机号、关联关系位置、媒体最后登录时间、账户等级和媒体类型，跳过前7条记录，返回接下来的6条记录。"}}]}, "usage": {"input_tokens": 334, "output_tokens": 75, "total_tokens": 409}}
# 查找昵称为Von Kwiecinski的账户及其关联的媒体信息，包括账户昵称、媒体风险级别、关联关系创建时间、账户是否被封禁、常用登录类型、账户类型、手机号、关联关系位置、媒体最后登录时间、账户等级和媒体类型，跳过前7条记录，返回接下来的6条记录。
# match (n1:medium)-[r1:mediumsigninaccount]->(n2:account)  where n2.nickname='Von Kwiecinski' return n2.nickname, n1.risklevel, r1.createtime, n2.isblocked, n2.freqlogintype, n2.accouttype, n2.phonenum, r1.location, n1.lastlogintime, n2.accountlevel, n1.mediumtype skip 7 limit 6
# {"status_code": 200, "request_id": "8f338e61-27c4-9a30-a0ba-057e180ffd0c", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Echo Murrill偿还的贷款的贷款ID"}}]}, "usage": {"input_tokens": 272, "output_tokens": 11, "total_tokens": 283}}
# 查找Echo Murrill偿还的贷款的贷款ID
# match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n2.loanId
# {"status_code": 200, "request_id": "520ac292-d43e-963d-9524-9bc21066da81", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Echo Murrill的账户创建时间、账户类型、账户等级、登录频率类型、邮箱、是否被封禁、昵称以及最后登录时间，并返回与该账户相关的贷款用途、贷款ID和创建时间，跳过前19条记录，限制返回9条记录。"}}]}, "usage": {"input_tokens": 335, "output_tokens": 64, "total_tokens": 399}}
# 查找昵称为Echo Murrill的账户创建时间、账户类型、账户等级、登录频率类型、邮箱、是否被封禁、昵称以及最后登录时间，并返回与该账户相关的贷款用途、贷款ID和创建时间，跳过前19条记录，限制返回9条记录。
# match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n1.createtime, n1.accouttype, n1.accountlevel, n1.freqlogintype, n2.loanusage, n2.loanId, n1.email, n1.isblocked, n1.nickname, n2.createtime, n1.lastlogintime skip 19 limit 9
# {"status_code": 200, "request_id": "47dae569-92ca-9b8e-949b-51c59e7a343d", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Von Kwiecinski且姓名为Skala的人的国家、账户最后登录时间、创建时间和账户类型，最多返回11条记录"}}]}, "usage": {"input_tokens": 308, "output_tokens": 34, "total_tokens": 342}}
# 查找昵称为Von Kwiecinski且姓名为Skala的人的国家、账户最后登录时间、创建时间和账户类型，最多返回11条记录
# match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Von Kwiecinski' and n1.personname='Skala' return n1.country, n2.lastlogintime, n1.createtime, n1.personname, n2.accouttype limit 11
# {"status_code": 200, "request_id": "41911024-a32a-99d1-a461-391517231650", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Faustino Marolf的账户所偿还的贷款信息，包括贷款的创建时间、利率、账户的昵称、登录频率类型、账户ID、电话号码、账户类型、账户创建时间、贷款ID、最后登录时间、贷款金额、偿还金额、贷款余额和账户是否被封禁，限制返回15条结果。"}}]}, "usage": {"input_tokens": 355, "output_tokens": 75, "total_tokens": 430}}
# 查找昵称为Faustino Marolf的账户所偿还的贷款信息，包括贷款的创建时间、利率、账户的昵称、登录频率类型、账户ID、电话号码、账户类型、账户创建时间、贷款ID、最后登录时间、贷款金额、偿还金额、贷款余额和账户是否被封禁，限制返回15条结果。
# match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Faustino Marolf' return n2.createtime, n2.interestrate, n1.nickname, n1.freqlogintype, n1.accountid, n1.phonenum, n1.accouttype, n1.createtime, n2.loanId, n1.lastlogintime, n2.loanamount, r1.amount, n2.balance, n1.isblocked, n2.loanusage limit 15
# {"status_code": 200, "request_id": "0472615b-25fd-9c73-bbe4-67dd7563ddd5", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Laurence Mccoil的账户是否被封禁，以及他提现到的账户的最后登录时间、昵称、常用登录类型、手机号，同时返回Laurence Mccoil的常用登录类型、昵称和创建时间"}}]}, "usage": {"input_tokens": 312, "output_tokens": 50, "total_tokens": 362}}
# 查找Laurence Mccoil的账户是否被封禁，以及他提现到的账户的最后登录时间、昵称、常用登录类型、手机号，同时返回Laurence Mccoil的常用登录类型、昵称和创建时间
# match (n1:account)-[r1:accountwithdrawaccount]->(n2:account)  where n1.nickname='Laurence Mccoil' return n1.isblocked, n2.lastlogintime, n2.nickname, n2.freqlogintype, n2.phonenum, n1.freqlogintype, n1.nickname, n1.createtime
# {"status_code": 200, "request_id": "2b4afa76-06a5-9b4d-a77a-7a3f812c86c9", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Mimi Voelkel的最后登录时间、是否被封禁、昵称和创建时间，并限制返回结果为4条"}}]}, "usage": {"input_tokens": 291, "output_tokens": 28, "total_tokens": 319}}
# 查找Mimi Voelkel的最后登录时间、是否被封禁、昵称和创建时间，并限制返回结果为4条
# match (n1:account)-[r1:accountwithdrawaccount]->(n2:account)  where n1.nickname='Mimi Voelkel' return n1.lastlogintime, n1.isblocked, n1.nickname, n1.createtime limit 4
# {"status_code": 200, "request_id": "ae981b83-2a10-9b4f-b132-2fbf8e04ddd4", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Rogelio Thaut的手机号码、账户类型、账户ID、常用登录类型、电子邮件和昵称"}}]}, "usage": {"input_tokens": 285, "output_tokens": 25, "total_tokens": 310}}
# 查找Rogelio Thaut的手机号码、账户类型、账户ID、常用登录类型、电子邮件和昵称
# match (n1:account)  where n1.nickname='Rogelio Thaut' return n1.phonenum, n1.accouttype, n1.accountid, n1.freqlogintype, n1.email, n1.nickname
# {"status_code": 200, "request_id": "32488741-a717-989e-8f94-55550e146571", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Faustino Marolf账户关联的贷款的利率、贷款金额，以及该账户的登录频率类型、是否被封锁、账户类型和关联时间"}}]}, "usage": {"input_tokens": 304, "output_tokens": 34, "total_tokens": 338}}
# 查找与Faustino Marolf账户关联的贷款的利率、贷款金额，以及该账户的登录频率类型、是否被封锁、账户类型和关联时间
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Faustino Marolf' return n1.interestrate, n1.loanamount, n2.freqlogintype, n2.isblocked, n2.accouttype, r1.createtime
# {"status_code": 200, "request_id": "7eaf1845-0177-9b20-aa28-173239b156f2", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Bert Inverso的账户等级、账户类型、创建时间、是否被封禁、常用登录方式、最后登录时间、手机号和邮箱"}}]}, "usage": {"input_tokens": 302, "output_tokens": 32, "total_tokens": 334}}
# 查找Bert Inverso的账户等级、账户类型、创建时间、是否被封禁、常用登录方式、最后登录时间、手机号和邮箱
# match (n1:account)  where n1.nickname='Bert Inverso' return n1.accountlevel, n1.accouttype, n1.createtime, n1.isblocked, n1.freqlogintype, n1.lastlogintime, n1.phonenum, n1.nickname, n1.email
# {"status_code": 200, "request_id": "a4f01367-f481-92eb-b39a-4daa01939270", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Jaskolski Group的公司城市、国家、网址、创建时间、公司名称、是否被封禁、业务范围、描述和公司ID，最多返回11条结果"}}]}, "usage": {"input_tokens": 298, "output_tokens": 39, "total_tokens": 337}}
# 查找Jaskolski Group的公司城市、国家、网址、创建时间、公司名称、是否被封禁、业务范围、描述和公司ID，最多返回11条结果
# match (n1:company)  where n1.companyname='Jaskolski Group' return n1.city, n1.country, n1.url, n1.createtime, n1.companyname, n1.isblocked, n1.business, n1.description, n1.companyid limit 11
# {"status_code": 200, "request_id": "c028e787-8211-9441-b0cd-f8b8852955f5", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Eve Pusateri的电话号码、账户ID、昵称、常用登录类型和账户等级，以及与她有账户提现关系的账户的账户类型和账户等级。"}}]}, "usage": {"input_tokens": 300, "output_tokens": 40, "total_tokens": 340}}
# 查找Eve Pusateri的电话号码、账户ID、昵称、常用登录类型和账户等级，以及与她有账户提现关系的账户的账户类型和账户等级。
# match (n1:account)-[r1:accountwithdrawaccount]->(n2:account)  where n2.nickname='Eve Pusateri' return n2.phonenum, n1.accountid, n2.nickname, n2.freqlogintype, n1.accouttype, n2.accountlevel
# {"status_code": 200, "request_id": "7c60caa7-66c8-9865-92d9-cd80e7250dd1", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Leonila Hagedorn相关的贷款信息，包括她的登录频率类型、昵称、贷款金额、关联时间以及她的电话号码，最多返回11条记录。"}}]}, "usage": {"input_tokens": 301, "output_tokens": 37, "total_tokens": 338}}
# 查找与Leonila Hagedorn相关的贷款信息，包括她的登录频率类型、昵称、贷款金额、关联时间以及她的电话号码，最多返回11条记录。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Leonila Hagedorn' return n2.freqlogintype, n2.nickname, n1.loanamount, r1.createtime, n2.phonenum limit 11
# {"status_code": 200, "request_id": "0d4f2a0e-23fe-9eba-bcfe-9cf043ad5ed7", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Peggy Gayheart且登录方式为NFC的账号信息，包括账号类型、关联关系创建时间、常用登录方式、账号创建时间、是否被封禁、昵称、登录方式、风险等级、账号等级、账号创建时间和最后一次登录时间，以及关联关系的位置信息。"}}]}, "usage": {"input_tokens": 342, "output_tokens": 65, "total_tokens": 407}}
# 查找昵称为Peggy Gayheart且登录方式为NFC的账号信息，包括账号类型、关联关系创建时间、常用登录方式、账号创建时间、是否被封禁、昵称、登录方式、风险等级、账号等级、账号创建时间和最后一次登录时间，以及关联关系的位置信息。
# match (n1:medium)-[r1:mediumsigninaccount]->(n2:account)  where n2.nickname='Peggy Gayheart' and n1.mediumtype='NFC' return n2.accouttype, r1.createtime, n2.freqlogintype, n1.createtime, n2.isblocked, n2.nickname, n1.mediumtype, n1.risklevel, n2.accountlevel, n2.createtime, n1.lastlogintime, r1.location
# {"status_code": 200, "request_id": "42b899f5-a325-95a3-89bc-d41f87813cde", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Pfeffer-Bradtke公司的公司ID、业务、贷款ID、是否被封锁、申请贷款的创建时间、贷款金额、公司网址和国家，并限制结果为9条记录。"}}]}, "usage": {"input_tokens": 312, "output_tokens": 42, "total_tokens": 354}}
# 查找Pfeffer-Bradtke公司的公司ID、业务、贷款ID、是否被封锁、申请贷款的创建时间、贷款金额、公司网址和国家，并限制结果为9条记录。
# match (n1:company)-[r1:companyapplyloan]->(n2:loan)  where n1.companyname='Pfeffer-Bradtke' return n1.companyid, n1.business, n2.loanId, n1.isblocked, r1.createtime, n2.loanamount, n1.url, n1.country limit 9
# {"status_code": 200, "request_id": "98bea316-5314-9f8b-8df9-2058aed4295e", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Stroman-Swift投资的公司Schulist-Pollich的相关信息，包括Stroman-Swift和Schulist-Pollich的公司名称、创建时间、网址、城市、是否被封禁、描述、业务范围、公司ID、国家，以及投资关系的创建时间和投资比例。"}}]}, "usage": {"input_tokens": 372, "output_tokens": 64, "total_tokens": 436}}
# 查找Stroman-Swift投资的公司Schulist-Pollich的相关信息，包括Stroman-Swift和Schulist-Pollich的公司名称、创建时间、网址、城市、是否被封禁、描述、业务范围、公司ID、国家，以及投资关系的创建时间和投资比例。
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n1.companyname='Stroman-Swift' and n2.companyname='Schulist-Pollich' return n1.companyname, n2.companyname, n2.createtime, n2.url, n1.city, n1.url, r1.createtime, r1.ratio, n2.isblocked, n1.isblocked, n1.createtime, n2.description, n1.description, n1.business, n1.companyid, n2.business, n2.companyid, n2.country, n1.country, n2.city
# {"status_code": 200, "request_id": "fbef643c-10c4-93a9-b821-2073a6e26c46", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Randolph Gica关联的贷款账户的创建时间、最后登录时间、贷款ID、利率、余额、登录频率类型、电话号码、账户等级、账户ID、昵称、贷款创建时间、账户类型、贷款金额、电子邮件、关系创建时间和账户是否被封禁的信息。"}}]}, "usage": {"input_tokens": 356, "output_tokens": 63, "total_tokens": 419}}
# 查找与Randolph Gica关联的贷款账户的创建时间、最后登录时间、贷款ID、利率、余额、登录频率类型、电话号码、账户等级、账户ID、昵称、贷款创建时间、账户类型、贷款金额、电子邮件、关系创建时间和账户是否被封禁的信息。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Randolph Gica' return n2.createtime, n2.lastlogintime, n1.loanId, n1.interestrate, n1.balance, n2.freqlogintype, n2.phonenum, n2.accountlevel, n2.accountid, n2.nickname, n1.createtime, n2.accouttype, n1.loanamount, n2.email, r1.createtime, n2.isblocked
# {"status_code": 200, "request_id": "063f34d9-7280-9e17-bbd8-b666c53ee85f", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Tromp and Sons的公司名称和描述"}}]}, "usage": {"input_tokens": 262, "output_tokens": 11, "total_tokens": 273}}
# 查找Tromp and Sons的公司名称和描述
# match (n1:company)  where n1.companyname='Tromp and Sons' return n1.companyname, n1.description
# {"status_code": 200, "request_id": "01774bc7-a00c-96ef-9b02-d90a5bc2742d", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Reilly-Labadie担保的公司中名为Schmitt-Blick的公司的相关信息，包括Reilly-Labadie的城市、公司ID、是否被封禁、业务范围、创建时间，以及Schmitt-Blick的是否被封禁、城市、描述、公司名称和担保关系，限制返回16条结果。"}}]}, "usage": {"input_tokens": 332, "output_tokens": 69, "total_tokens": 401}}
# 查找Reilly-Labadie担保的公司中名为Schmitt-Blick的公司的相关信息，包括Reilly-Labadie的城市、公司ID、是否被封禁、业务范围、创建时间，以及Schmitt-Blick的是否被封禁、城市、描述、公司名称和担保关系，限制返回16条结果。
# match (n1:company)-[r1:companyguaranteecompany]->(n2:company)  where n1.companyname='Reilly-Labadie' and n2.companyname='Schmitt-Blick' return n1.city, n1.companyid, n2.isblocked, n2.city, n1.isblocked, n1.business, n2.description, n1.createtime, r1.relation, n2.companyname limit 16
# {"status_code": 200, "request_id": "1e940d62-6847-9bf0-8691-ce4eba502c33", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找使用QRCode作为登录方式的账号的登录频率类型、昵称、是否被封禁、关联关系的创建时间、媒体的创建时间、账号的创建时间、最后登录时间、账号ID、媒体的最后登录时间、邮箱、账号等级、媒体是否被封禁、关联关系的位置、媒体的风险级别、手机号和媒体类型，跳过前8条记录，返回接下来的13条记录。"}}]}, "usage": {"input_tokens": 364, "output_tokens": 90, "total_tokens": 454}}
# 查找使用QRCode作为登录方式的账号的登录频率类型、昵称、是否被封禁、关联关系的创建时间、媒体的创建时间、账号的创建时间、最后登录时间、账号ID、媒体的最后登录时间、邮箱、账号等级、媒体是否被封禁、关联关系的位置、媒体的风险级别、手机号和媒体类型，跳过前8条记录，返回接下来的13条记录。
# match (n1:medium)-[r1:mediumsigninaccount]->(n2:account)  where n1.mediumtype='QRCode' return n2.freqlogintype, n2.nickname, n2.isblocked, r1.createtime, n1.createtime, n2.createtime, n2.lastlogintime, n2.accountid, n1.lastlogintime, n2.email, n2.accountlevel, n1.isblocked, r1.location, n1.risklevel, n2.phonenum, n1.mediumtype, n1.mediumId skip 8 limit 13
# {"status_code": 200, "request_id": "8d938677-e4f1-9206-9ac0-6d8fc23e330c", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Funk PLC公司的网址、国家、申请的贷款余额、贷款机构、贷款利率、公司ID、贷款金额、贷款ID、申请时间、公司名称、贷款创建时间、公司是否被封禁、城市、公司创建时间和贷款用途"}}]}, "usage": {"input_tokens": 342, "output_tokens": 52, "total_tokens": 394}}
# 查找Funk PLC公司的网址、国家、申请的贷款余额、贷款机构、贷款利率、公司ID、贷款金额、贷款ID、申请时间、公司名称、贷款创建时间、公司是否被封禁、城市、公司创建时间和贷款用途
# match (n1:company)-[r1:companyapplyloan]->(n2:loan)  where n1.companyname='Funk PLC' return n1.url, n1.country, n2.balance, r1.org, n2.interestrate, n1.companyid, n2.loanamount, n2.loanId, r1.createtime, n1.companyname, n2.createtime, n1.isblocked, n1.city, n1.createtime, n2.loanusage
# {"status_code": 200, "request_id": "30765346-a388-9df5-a260-91a6af55e6a0", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找投资了Lockman Ltd的公司及其相关信息，包括投资公司的国家、网址、业务、公司ID、描述、是否被封禁，以及投资关系的创建时间和投资比例，还有Lockman Ltd的城市、国家、描述、业务、公司名称、是否被封禁和公司ID。"}}]}, "usage": {"input_tokens": 333, "output_tokens": 62, "total_tokens": 395}}
# 查找投资了Lockman Ltd的公司及其相关信息，包括投资公司的国家、网址、业务、公司ID、描述、是否被封禁，以及投资关系的创建时间和投资比例，还有Lockman Ltd的城市、国家、描述、业务、公司名称、是否被封禁和公司ID。
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n2.companyname='Lockman Ltd' return n1.country, n1.url, n2.city, r1.createtime, n2.country, n1.business, n2.isblocked, n1.companyid, r1.ratio, n2.description, n1.description, n2.business, n2.companyname, n1.isblocked, n2.companyid
# {"status_code": 200, "request_id": "667d1d2d-342a-9f90-9c66-9d4428d91628", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Quincy Palevic且使用电话注册的账号信息，包括账号类型、最后登录时间、是否被封禁、注册时间、电话号码、风险等级以及注册地点，限制返回8条结果"}}]}, "usage": {"input_tokens": 315, "output_tokens": 45, "total_tokens": 360}}
# 查找昵称为Quincy Palevic且使用电话注册的账号信息，包括账号类型、最后登录时间、是否被封禁、注册时间、电话号码、风险等级以及注册地点，限制返回8条结果
# match (n1:medium)-[r1:mediumsigninaccount]->(n2:account)  where n1.mediumtype='PHONE' and n2.nickname='Quincy Palevic' return n1.createtime, n2.accouttype, n1.mediumId, n2.lastlogintime, r1.location, n1.risklevel, n2.isblocked limit 8
# {"status_code": 200, "request_id": "6280017b-e78e-949b-9a07-492becd5587b", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Randolph Gica关联的贷款信息，返回账户的创建时间、最后登录时间、贷款ID、账户ID、账户等级和频繁登录类型"}}]}, "usage": {"input_tokens": 303, "output_tokens": 33, "total_tokens": 336}}
# 查找与Randolph Gica关联的贷款信息，返回账户的创建时间、最后登录时间、贷款ID、账户ID、账户等级和频繁登录类型
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Randolph Gica' return n2.createtime, n2.lastlogintime, n1.loanId, n2.accountid, n2.accountlevel, n2.freqlogintype
# {"status_code": 200, "request_id": "634cdf6d-64ab-9233-899b-bc851873a18e", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Vandervort-Rowe公司担保的其他公司的创建时间、城市、Vandervort-Rowe公司的城市、网址、被担保公司的网址及担保关系，限制返回5条结果"}}]}, "usage": {"input_tokens": 307, "output_tokens": 43, "total_tokens": 350}}
# 查找Vandervort-Rowe公司担保的其他公司的创建时间、城市、Vandervort-Rowe公司的城市、网址、被担保公司的网址及担保关系，限制返回5条结果
# match (n1:company)-[r1:companyguaranteecompany]->(n2:company)  where n1.companyname='Vandervort-Rowe' return n2.createtime, n2.city, n1.city, n1.url, n1.companyname, n2.url, r1.relation limit 5
# {"status_code": 200, "request_id": "a04c6187-94ff-9e3a-9cc9-1a462d13761a", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找公司Bernier-Hill的公司ID、网址、描述、创建时间、是否被封禁、所在国家、所在城市和公司名称"}}]}, "usage": {"input_tokens": 289, "output_tokens": 30, "total_tokens": 319}}
# 查找公司Bernier-Hill的公司ID、网址、描述、创建时间、是否被封禁、所在国家、所在城市和公司名称
# match (n1:company)  where n1.companyname='Bernier-Hill' return n1.companyid, n1.url, n1.description, n1.createtime, n1.isblocked, n1.country, n1.city, n1.companyname
# {"status_code": 200, "request_id": "6ad07dc6-b3fc-9a0b-b2e2-fd8c382f8e9e", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Betsey Kristensen的最后登录时间、账户ID、账户类型、常用登录类型、昵称、邮箱和账户等级"}}]}, "usage": {"input_tokens": 289, "output_tokens": 27, "total_tokens": 316}}
# 查找Betsey Kristensen的最后登录时间、账户ID、账户类型、常用登录类型、昵称、邮箱和账户等级
# match (n1:account)  where n1.nickname='Betsey Kristensen' return n1.lastlogintime, n1.accountid, n1.accouttype, n1.freqlogintype, n1.nickname, n1.email, n1.accountlevel
# {"status_code": 200, "request_id": "7972d84e-97d4-97d3-98d5-f2576e5708d8", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找名为Baggesen的人在Veum Inc公司的投资信息，返回Baggesen的名字和Veum Inc的业务信息，最多返回12条记录"}}]}, "usage": {"input_tokens": 288, "output_tokens": 33, "total_tokens": 321}}
# 查找名为Baggesen的人在Veum Inc公司的投资信息，返回Baggesen的名字和Veum Inc的业务信息，最多返回12条记录
# match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n1.personname='Baggesen' and n2.companyname='Veum Inc' return n1.personname, n2.business limit 12
# {"status_code": 200, "request_id": "df0d9b10-e63d-90f0-97b8-f7966c7d7d51", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Lynch-Green公司有投资关系的人的信息，包括公司的ID、业务、城市、国家、创建时间、是否被封禁，以及投资者的ID、性别、城市、国家、姓名、生日、是否被封禁、创建时间，还有投资比例和关系的创建时间。"}}]}, "usage": {"input_tokens": 352, "output_tokens": 63, "total_tokens": 415}}
# 查找与Lynch-Green公司有投资关系的人的信息，包括公司的ID、业务、城市、国家、创建时间、是否被封禁，以及投资者的ID、性别、城市、国家、姓名、生日、是否被封禁、创建时间，还有投资比例和关系的创建时间。
# match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n2.companyname='Lynch-Green' return n2.companyid, n1.personId, n1.gender, n2.business, n1.city, r1.ratio, n2.url, n2.city, n2.country, n1.country, n1.personname, n2.createtime, n1.isBlocked, n1.createtime, r1.createtime, n2.companyname, n2.isblocked, n1.birthday
# {"status_code": 200, "request_id": "fcc10641-771f-9695-a04b-2a510d30c033", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找前12个IPv4类型的媒介，返回它们是否被阻塞和媒介ID"}}]}, "usage": {"input_tokens": 264, "output_tokens": 19, "total_tokens": 283}}
# 查找前12个IPv4类型的媒介，返回它们是否被阻塞和媒介ID
# match (n1:medium)  where n1.mediumtype='IPv4' return n1.isblocked, n1.mediumId limit 12
# {"status_code": 200, "request_id": "646c880d-8dea-92c9-943c-42c7cc3dbd06", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Roman创建时间和他投资的公司的业务信息"}}]}, "usage": {"input_tokens": 273, "output_tokens": 10, "total_tokens": 283}}
# 查找Roman创建时间和他投资的公司的业务信息
# match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n1.personname='Roman' return n1.createtime, n2.business
# {"status_code": 200, "request_id": "10340fb8-48b6-9f5c-9a38-c91350312090", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Smith-Powlowski投资的Lesch-Bergnaum公司的城市、投资比例、Smith-Powlowski的创建时间、Lesch-Bergnaum的业务范围和创建时间，以及Smith-Powlowski的城市"}}]}, "usage": {"input_tokens": 308, "output_tokens": 46, "total_tokens": 354}}
# 查找Smith-Powlowski投资的Lesch-Bergnaum公司的城市、投资比例、Smith-Powlowski的创建时间、Lesch-Bergnaum的业务范围和创建时间，以及Smith-Powlowski的城市
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n1.companyname='Smith-Powlowski' and n2.companyname='Lesch-Bergnaum' return n2.city, r1.ratio, n1.createtime, n2.business, n2.createtime, n1.city
# {"status_code": 200, "request_id": "6bc243d6-e1ce-90ea-b779-46462d9eb108", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Ashely Rundlett的账户信息，包括手机号、账户ID、电子邮件，以及她转账给的账户的被封状态、账户ID、账户等级、创建时间，同时返回转账的订单号、Ashely Rundlett的账户类型、常用登录方式、最后登录时间和对方账户的账户类型。"}}]}, "usage": {"input_tokens": 346, "output_tokens": 67, "total_tokens": 413}}
# 查找Ashely Rundlett的账户信息，包括手机号、账户ID、电子邮件，以及她转账给的账户的被封状态、账户ID、账户等级、创建时间，同时返回转账的订单号、Ashely Rundlett的账户类型、常用登录方式、最后登录时间和对方账户的账户类型。
# match (n1:account)-[r1:accounttransferaccount]->(n2:account)  where n1.nickname='Ashely Rundlett' return n1.phonenum, n1.accountid, n1.email, n2.isblocked, n2.accountid, n1.accountlevel, n2.createtime, r1.ordernum, n1.accouttype, n1.freqlogintype, n2.accountlevel, n2.phonenum, n1.lastlogintime, n2.accouttype
# {"status_code": 200, "request_id": "66da211f-c01f-9a94-bc8d-c43823d8384b", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Luettgen-McGlynn公司的投资者信息，包括公司名称、投资者是否被封禁、投资者姓名、投资时间、投资者性别、投资者ID、投资比例、公司是否被封禁、投资者创建时间、投资者生日、投资者国家、投资者城市、公司业务、公司描述、公司国家、公司城市和公司创建时间。"}}]}, "usage": {"input_tokens": 351, "output_tokens": 73, "total_tokens": 424}}
# 查找Luettgen-McGlynn公司的投资者信息，包括公司名称、投资者是否被封禁、投资者姓名、投资时间、投资者性别、投资者ID、投资比例、公司是否被封禁、投资者创建时间、投资者生日、投资者国家、投资者城市、公司业务、公司描述、公司国家、公司城市和公司创建时间。
# match (n1:person)-[r1:personinvestcompany]->(n2:company)  where n2.companyname='Luettgen-McGlynn' return n2.companyname, n1.isBlocked, n1.personname, r1.createtime, n1.gender, n1.personId, r1.ratio, n2.isblocked, n1.createtime, n1.birthday, n1.country, n1.city, n2.business, n2.description, n2.country, n2.city, n2.createtime
# ...
# 查找名为Gunn的人拥有的账户信息，包括该人的国家、性别、城市、是否被封禁、姓名、生日；以及账户的类型、等级、创建时间、账户ID、电话号码、最后登录时间和常用登录方式，限制返回16条结果。
# match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Gunn' return n1.country, n2.accouttype, n2.accountlevel, r1.createtime, n2.accountid, n2.phonenum, n1.gender, n1.city, n1.isBlocked, n2.isblocked, n1.personname, n2.lastlogintime, n2.freqlogintype, n1.birthday limit 16
# {"status_code": 200, "request_id": "af0b3295-6599-92fc-b8df-6aa807655779", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Dickens-Ward投资的公司中公司名为Roberts LLC的相关信息，包括Roberts LLC的公司名、创建时间、公司ID、是否被封禁、所在城市、创建时间、所在国家、业务范围、公司网址，以及Dickens-Ward的创建时间、是否被封禁、所在国家、业务范围、所在城市、公司网址，同时返回投资关系的创建时间，限制结果数量为3条。"}}]}, "usage": {"input_tokens": 359, "output_tokens": 92, "total_tokens": 451}}
# 查找Dickens-Ward投资的公司中公司名为Roberts LLC的相关信息，包括Roberts LLC的公司名、创建时间、公司ID、是否被封禁、所在城市、创建时间、所在国家、业务范围、公司网址，以及Dickens-Ward的创建时间、是否被封禁、所在国家、业务范围、所在城市、公司网址，同时返回投资关系的创建时间，限制结果数量为3条。
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n1.companyname='Dickens-Ward' and n2.companyname='Roberts LLC' return n2.companyname, n1.createtime, n2.companyid, n2.isblocked, n1.isblocked, n2.city, n2.createtime, n1.country, n1.companyid, n1.url, n2.business, n1.companyname, r1.createtime, n2.country, n1.business, n1.city, n2.url limit 3
# {"status_code": 200, "request_id": "34fb16ea-eb34-9a77-9b13-e666f013e4d2", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Von Kwiecinski且类型为QRCode的账号的关联信息，包括关系的创建时间、风险级别、介质的创建时间、账号的创建时间、关系的位置、账号是否被封禁、介质的最后登录时间和介质类型"}}]}, "usage": {"input_tokens": 321, "output_tokens": 55, "total_tokens": 376}}
# 查找昵称为Von Kwiecinski且类型为QRCode的账号的关联信息，包括关系的创建时间、风险级别、介质的创建时间、账号的创建时间、关系的位置、账号是否被封禁、介质的最后登录时间和介质类型
# match (n1:medium)-[r1:mediumsigninaccount]->(n2:account)  where n2.nickname='Von Kwiecinski' and n1.mediumtype='QRCode' return r1.createtime, n1.risklevel, n1.createtime, n2.createtime, r1.location, n2.isblocked, n1.lastlogintime, n1.mediumtype
# {"status_code": 200, "request_id": "de40f874-4b2b-934d-927d-2af01d26b258", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Renato Holness的账户对应的个人信息，包括昵称、姓名、性别、生日、账户类型、城市、国家、创建时间、常用登录方式和最后登录时间"}}]}, "usage": {"input_tokens": 317, "output_tokens": 39, "total_tokens": 356}}
# 查找昵称为Renato Holness的账户对应的个人信息，包括昵称、姓名、性别、生日、账户类型、城市、国家、创建时间、常用登录方式和最后登录时间
# match (n1:person)-[r1:personownaccount]->(n2:account)  where n2.nickname='Renato Holness' return n2.nickname, n1.personname, n1.gender, n1.birthday, n2.accouttype, n1.city, n1.country, n1.createtime, n2.freqlogintype, n2.lastlogintime
# {"status_code": 200, "request_id": "b2afc14f-e43e-9662-b8a8-bece3f03e0ea", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Baardsen的所在城市、创建时间、性别和是否被封禁的信息"}}]}, "usage": {"input_tokens": 270, "output_tokens": 18, "total_tokens": 288}}
# 查找Baardsen的所在城市、创建时间、性别和是否被封禁的信息
# match (n1:person)  where n1.personname='Baardsen' return n1.city, n1.createtime, n1.gender, n1.isBlocked
# {"status_code": 200, "request_id": "d675d073-4dc0-919c-95b2-966124226b69", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找名为Abutalybov的人的ID和所在城市"}}]}, "usage": {"input_tokens": 262, "output_tokens": 13, "total_tokens": 275}}
# 查找名为Abutalybov的人的ID和所在城市
# match (n1:person)  where n1.personname='Abutalybov' return n1.personId, n1.city
# {"status_code": 200, "request_id": "d8a67d6f-43de-9079-84a3-463fb3199659", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Jenkins-Macejkovic投资的公司信息，包括被投资公司的公司ID、Jenkins-Macejkovic是否被封禁、所在国家、投资时间、业务范围、创建时间、投资比例、被投资公司的业务范围、Jenkins-Macejkovic的网址、公司名称、被投资公司是否被封禁、所在国家。"}}]}, "usage": {"input_tokens": 325, "output_tokens": 74, "total_tokens": 399}}
# 查找Jenkins-Macejkovic投资的公司信息，包括被投资公司的公司ID、Jenkins-Macejkovic是否被封禁、所在国家、投资时间、业务范围、创建时间、投资比例、被投资公司的业务范围、Jenkins-Macejkovic的网址、公司名称、被投资公司是否被封禁、所在国家。
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n1.companyname='Jenkins-Macejkovic' return n2.companyid, n1.isblocked, n1.country, r1.createtime, n1.business, n2.createtime, r1.ratio, n2.business, n1.url, n1.companyname, n2.isblocked, n2.country
# {"status_code": 200, "request_id": "f58cae3c-1d3d-9567-acb2-015ec97c1855", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Reilly-Langworth投资的Boyer-Morissette公司的业务范围，以及这两个公司的所在城市和Reilly-Langworth的公司ID"}}]}, "usage": {"input_tokens": 297, "output_tokens": 32, "total_tokens": 329}}
# 查找Reilly-Langworth投资的Boyer-Morissette公司的业务范围，以及这两个公司的所在城市和Reilly-Langworth的公司ID
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n2.companyname='Boyer-Morissette' and n1.companyname='Reilly-Langworth' return n2.business, n1.city, n2.city, n1.companyid
# {"status_code": 200, "request_id": "398bbdc9-715c-92be-9892-a7e5c01e1ee6", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Stroman-Swift公司申请的贷款的用途、公司网址、贷款金额、贷款创建时间、公司创建时间、公司是否被封禁、贷款利率、申请时间、公司名称、公司所在国家、公司ID、公司描述、贷款余额"}}]}, "usage": {"input_tokens": 338, "output_tokens": 54, "total_tokens": 392}}
# 查找Stroman-Swift公司申请的贷款的用途、公司网址、贷款金额、贷款创建时间、公司创建时间、公司是否被封禁、贷款利率、申请时间、公司名称、公司所在国家、公司ID、公司描述、贷款余额
# match (n1:company)-[r1:companyapplyloan]->(n2:loan)  where n1.companyname='Stroman-Swift' return n2.loanusage, n1.url, n2.loanamount, n2.createtime, n1.createtime, n1.isblocked, n2.interestrate, r1.createtime, n1.companyname, n1.country, n1.companyid, n1.description, r1.org, n2.balance
# {"status_code": 200, "request_id": "7bbdc158-4760-930a-ab8c-6b508bc2430e", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Jacob Sheild的账户信息及其转账给其他账户的信息，包括Jacob Sheild的邮箱、账户类型、最后登录时间、账户ID、是否被封禁、创建时间、昵称、账户等级、常用登录类型，以及转账目标账户的账户类型、邮箱、昵称、账户等级、最后登录时间、是否被封禁、创建时间、电话号码，同时返回转账记录的创建时间和转账金额。跳过前13条记录，返回接下来的18条记录。"}}]}, "usage": {"input_tokens": 386, "output_tokens": 106, "total_tokens": 492}}
# 查找Jacob Sheild的账户信息及其转账给其他账户的信息，包括Jacob Sheild的邮箱、账户类型、最后登录时间、账户ID、是否被封禁、创建时间、昵称、账户等级、常用登录类型，以及转账目标账户的账户类型、邮箱、昵称、账户等级、最后登录时间、是否被封禁、创建时间、电话号码，同时返回转账记录的创建时间和转账金额。跳过前13条记录，返回接下来的18条记录。
# match (n1:account)-[r1:accountwithdrawaccount]->(n2:account)  where n1.nickname='Jacob Sheild' return n1.email, n1.accouttype, n1.lastlogintime, n2.accouttype, n1.freqlogintype, n1.accountid, n2.email, n1.isblocked, n2.nickname, n2.accountlevel, n1.createtime, n2.lastlogintime, n1.nickname, n2.accountid, n1.accountlevel, r1.createtime, n2.createtime, n2.isblocked, n2.freqlogintype, r1.amount, n2.phonenum skip 13 limit 18
# {"status_code": 200, "request_id": "7a4390d0-7336-94ca-8d4d-75078bd300ef", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Cordelia Ratcliffe的账户关联的贷款信息，返回关联时间、账户类型和贷款用途，最多返回10条记录"}}]}, "usage": {"input_tokens": 290, "output_tokens": 30, "total_tokens": 320}}
# 查找与Cordelia Ratcliffe的账户关联的贷款信息，返回关联时间、账户类型和贷款用途，最多返回10条记录
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Cordelia Ratcliffe' return r1.createtime, n2.accouttype, n1.loanusage limit 10
# {"status_code": 200, "request_id": "8ebbfb34-f562-9c2b-ab5c-9daa706164b7", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Pia Glasper账户相关的贷款信息，包括贷款ID、关联时间、账户最后登录时间、贷款创建时间、贷款余额、贷款金额、贷款用途、账户是否被封锁、关联金额、账户类型、昵称、电话号码、账户创建时间和邮箱地址。"}}]}, "usage": {"input_tokens": 348, "output_tokens": 59, "total_tokens": 407}}
# 查找与Pia Glasper账户相关的贷款信息，包括贷款ID、关联时间、账户最后登录时间、贷款创建时间、贷款余额、贷款金额、贷款用途、账户是否被封锁、关联金额、账户类型、昵称、电话号码、账户创建时间和邮箱地址。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Pia Glasper' return n1.loanId, r1.createtime, n2.lastlogintime, n1.createtime, n1.balance, n1.loanamount, n1.loanusage, n2.isblocked, r1.amount, n2.accouttype, n2.nickname, n2.phonenum, n2.createtime, n2.email, n2.accountlevel
# {"status_code": 200, "request_id": "48742c72-98b3-9ab0-bab6-65cfd61aadb0", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找类型为IPv6的媒介的id和风险等级"}}]}, "usage": {"input_tokens": 261, "output_tokens": 12, "total_tokens": 273}}
# 查找类型为IPv6的媒介的id和风险等级
# match (n1:medium)  where n1.mediumtype='IPv6' return n1.mediumId, n1.risklevel
# {"status_code": 200, "request_id": "21583c6a-36f4-9e2b-9872-db249dcc3654", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Leonila Hagedorn账户关联的贷款信息，包括贷款金额、利率、用途、余额和创建时间，以及账户的登录频率类型、电子邮件、创建时间、账户类型、昵称、账户ID和电话号码，同时返回关联关系的创建时间。"}}]}, "usage": {"input_tokens": 340, "output_tokens": 58, "total_tokens": 398}}
# 查找与Leonila Hagedorn账户关联的贷款信息，包括贷款金额、利率、用途、余额和创建时间，以及账户的登录频率类型、电子邮件、创建时间、账户类型、昵称、账户ID和电话号码，同时返回关联关系的创建时间。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Leonila Hagedorn' return n1.loanamount, n2.freqlogintype, n1.interestrate, n2.email, r1.createtime, n1.loanusage, n2.createtime, n2.accouttype, n1.balance, n2.nickname, n1.createtime, n2.accountid, n2.phonenum
# {"status_code": 200, "request_id": "eb9ebe2d-d00d-94a3-b292-d1b2e41d9289", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Kerluke-Kilback公司担保的Stroman-Kerluke公司的业务类型和所在城市"}}]}, "usage": {"input_tokens": 293, "output_tokens": 23, "total_tokens": 316}}
# 查找Kerluke-Kilback公司担保的Stroman-Kerluke公司的业务类型和所在城市
# match (n1:company)-[r1:companyguaranteecompany]->(n2:company)  where n1.companyname='Kerluke-Kilback' and n2.companyname='Stroman-Kerluke' return n1.business, n2.city
# {"status_code": 200, "request_id": "2e9c390f-4188-99a7-a394-903d88efde58", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Faustino Marolf相关的账户的账户级别、是否被封锁、关联的贷款金额、贷款利率、最后登录时间、账户类型、电话号码、贷款金额、贷款ID、关联时间、频繁登录类型和贷款用途"}}]}, "usage": {"input_tokens": 338, "output_tokens": 50, "total_tokens": 388}}
# 查找与Faustino Marolf相关的账户的账户级别、是否被封锁、关联的贷款金额、贷款利率、最后登录时间、账户类型、电话号码、贷款金额、贷款ID、关联时间、频繁登录类型和贷款用途
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Faustino Marolf' return n2.accountlevel, n2.isblocked, r1.amount, n1.interestrate, n2.lastlogintime, n2.accouttype, n2.phonenum, n1.loanamount, n1.loanId, r1.createtime, n2.freqlogintype, n1.loanusage
# {"status_code": 200, "request_id": "157a569c-eb41-9e9e-a830-dd35a7bf7fed", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找名为Culver的个人账户信息，包括性别、账户ID、是否被封禁、个人ID、账户类型、最后登录时间、个人姓名、常用登录类型、国家、账户等级、邮箱、创建时间、关系创建时间、手机号、生日、昵称、城市和账户是否被封禁，跳过1条记录，限制返回16条记录。"}}]}, "usage": {"input_tokens": 371, "output_tokens": 80, "total_tokens": 451}}
# 查找名为Culver的个人账户信息，包括性别、账户ID、是否被封禁、个人ID、账户类型、最后登录时间、个人姓名、常用登录类型、国家、账户等级、邮箱、创建时间、关系创建时间、手机号、生日、昵称、城市和账户是否被封禁，跳过1条记录，限制返回16条记录。
# match (n1:person)-[r1:personownaccount]->(n2:account)  where n1.personname='Culver' return n1.gender, n2.accountid, n1.isBlocked, n1.personId, n2.accouttype, n2.lastlogintime, n1.personname, n2.freqlogintype, n1.country, n2.accountlevel, n2.email, n2.createtime, n1.createtime, r1.createtime, n2.phonenum, n1.birthday, n2.nickname, n1.city, n2.isblocked skip 1 limit 16
# {"status_code": 200, "request_id": "897ff731-2f16-944e-85dd-b44b70a60db3", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Echo Murrill的账户的创建时间、电话号码、是否被封禁、常用登录类型、邮箱、昵称、账户ID，以及该账户还款的贷款的贷款ID、利率、余额、贷款用途、贷款金额，同时返回还款记录的创建时间和还款金额"}}]}, "usage": {"input_tokens": 341, "output_tokens": 62, "total_tokens": 403}}
# 查找昵称为Echo Murrill的账户的创建时间、电话号码、是否被封禁、常用登录类型、邮箱、昵称、账户ID，以及该账户还款的贷款的贷款ID、利率、余额、贷款用途、贷款金额，同时返回还款记录的创建时间和还款金额
# match (n1:account)-[r1:accountrepayloan]->(n2:loan)  where n1.nickname='Echo Murrill' return n1.createtime, r1.createtime, n1.phonenum, n1.isblocked, n1.freqlogintype, n1.email, n1.nickname, n2.loanId, n2.interestrate, n1.accountid, r1.amount, n2.balance, n2.loanusage, n2.loanamount
# {"status_code": 200, "request_id": "68e66a0d-a10b-9742-8a4e-2cc9552f8f35", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找与Kathleen Salvador相关的账户的电话号码、电子邮件，以及她关联的贷款的利率、创建时间、账户等级和账户ID，最多返回19条记录。"}}]}, "usage": {"input_tokens": 303, "output_tokens": 38, "total_tokens": 341}}
# 查找与Kathleen Salvador相关的账户的电话号码、电子邮件，以及她关联的贷款的利率、创建时间、账户等级和账户ID，最多返回19条记录。
# match (n1:loan)-[r1:loandepositaccount]->(n2:account)  where n2.nickname='Kathleen Salvador' return n2.phonenum, n2.email, n1.interestrate, n1.createtime, n2.accountlevel, n2.accountid limit 19
# {"status_code": 200, "request_id": "6ba05608-74b6-9863-a232-79e534c99e5a", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找Herzog Ltd被Schmidt-Schroeder投资的公司id、Schmidt-Schroeder的创建时间、Herzog Ltd的业务和所在国家"}}]}, "usage": {"input_tokens": 298, "output_tokens": 36, "total_tokens": 334}}
# 查找Herzog Ltd被Schmidt-Schroeder投资的公司id、Schmidt-Schroeder的创建时间、Herzog Ltd的业务和所在国家
# match (n1:company)-[r1:companyinvestcompany]->(n2:company)  where n2.companyname='Herzog Ltd' and n1.companyname='Schmidt-Schroeder' return n2.companyid, n1.createtime, n2.business, n2.country
# {"status_code": 200, "request_id": "7f5679ac-30bc-94ac-9b8e-6f62d0253e8e", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找公司Homenick-Jacobi的创建时间、描述、国家、公司ID和是否被封锁的信息"}}]}, "usage": {"input_tokens": 278, "output_tokens": 23, "total_tokens": 301}}
# 查找公司Homenick-Jacobi的创建时间、描述、国家、公司ID和是否被封锁的信息
# match (n1:company)  where n1.companyname='Homenick-Jacobi' return n1.createtime, n1.description, n1.country, n1.companyid, n1.isblocked
# {"status_code": 200, "request_id": "c8a2f1f5-6d21-921e-977b-66bebc477c5d", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找昵称为Rubin Maenaga的账号的最后登录时间、创建时间、手机号码、昵称、账号ID和常用登录类型"}}]}, "usage": {"input_tokens": 287, "output_tokens": 30, "total_tokens": 317}}
# 查找昵称为Rubin Maenaga的账号的最后登录时间、创建时间、手机号码、昵称、账号ID和常用登录类型
# match (n1:account)  where n1.nickname='Rubin Maenaga' return n1.lastlogintime, n1.createtime, n1.phonenum, n1.nickname, n1.accountid, n1.freqlogintype
# {"status_code": 200, "request_id": "fe128155-28c4-9fd1-98b0-9c8d2c174b9e", "code": "", "message": "", "output": {"text": null, "finish_reason": null, "choices": [{"finish_reason": "stop", "message": {"role": "assistant", "content": "查找类型为QRCode的媒体的创建时间、媒体ID和是否被封禁的状态"}}]}, "usage": {"input_tokens": 266, "output_tokens": 19, "total_tokens": 285}}
# 查找类型为QRCode的媒体的创建时间、媒体ID和是否被封禁的状态
# match (n1:medium)  where n1.mediumtype='QRCode' return n1.createtime, n1.mediumId, n1.isblocked

# %%
### 接着处理数据集  生成自然语言描述的embedding
node_label_names = list(label_where_key.keys())


import psycopg
import json
from pgvector.psycopg import register_vector
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain_community.document_loaders import DirectoryLoader
import numpy as np

model_name = "/home/work/liuytest/demo/maidalun1020/bce-embedding-base_v1"
model_kwargs = {'device': 'npu:0'}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity
model = HuggingFaceBgeEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

def find_real_prompt_from_pg_vector(user_query):
    pg_con = psycopg.connect(
            dbname="postgres",
            host="localhost",
            user="omm",
            password="ZAQ1234@esz",
            port=5432)
     
     
    pg_con.autocommit=True       
    cur = pg_con.cursor()
    register_vector(pg_con)

    embeddings = model.embed_documents(
        [
            user_query
        ]
    )
    embedding = embeddings[0]
    pg_con.execute(f'SET graph_path  = {graph_path};' )
    pg_con.execute('SET hnsw.ef_search = 100;' )
    embedding = np.asarray(embedding)
    datas = []

    prompt = "已知数据库中存在以下数据信息:\n"
    found = False
    for node in node_label_names:
        # pg_con.execute(f'drop  TABLE IF  EXISTS  zyykg_data_{node} cascade') match (n:person) return  n.feature_emd as emb  order by   (emb <#> %s)* -1 desc  LIMIT 1
        data = pg_con.execute(f'match (n:{node}) where (n.feature_emd::vector <#> %s) < -0.5  return  n ,(n.feature_emd::vector <#> %s) as score order by  score asc  LIMIT 3', (embedding,embedding,)).fetchall()
        if len(data)>0:
            found = True
            for data_inrow in data:
                dn_node = resolve_node(data_inrow[0])
                prompt= prompt+f"label为{dn_node[0]},属性{label_where_key[node]}='{dn_node[2][label_where_key[node]]}'的节点\n"  
    if found:
        return prompt 
    else:
        return "" 



key_values = None
with open("tongyi_query_pair_query.json", 'r',encoding="utf-8") as json_file:
    key_values = json.load(json_file) 

new_query_pair_train = []
for row in key_values:
    new_row ={}
    for key,value in row.items():
        user_query = key
        data_prompt = find_real_prompt_from_pg_vector(user_query)
        print(user_query)
        print(data_prompt)
        new_row["instruction"] = data_prompt+"\n" + "请将以下自然语言翻译为对该数据库的Cypher查询:\n"+user_query
        new_row["output"]=value
        new_query_pair_train.append(new_row)
    if len(data_prompt) > 0:
        print("----------------------------------------------------------------------------------------------------")
        print(user_query)
        print(data_prompt)
        print("----------------------------------------------------------------------------------------------------")

with open('tongyi_query_pair_query_train.json', 'w',encoding="utf-8") as json_file:
    json.dump(new_query_pair_train, json_file ,ensure_ascii=False,indent=4)
# Out:
# 查找昵称为Renato Holness的账号的邮箱、常用登录方式、账号ID、账号等级、账号类型、昵称、创建时间、是否被封禁、手机号和最后登录时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Renato Holness'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Renato Holness的账号的邮箱、常用登录方式、账号ID、账号等级、账号类型、昵称、创建时间、是否被封禁、手机号和最后登录时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Renato Holness'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Kurt Fernandes的账号的电话号码、账号类型、是否被封禁、昵称、创建时间、电子邮件、最后登录时间和账号ID，最多返回14条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kurt Fernandes'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Kurt Fernandes的账号的电话号码、账号类型、是否被封禁、昵称、创建时间、电子邮件、最后登录时间和账号ID，最多返回14条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kurt Fernandes'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Laverna Model的账户类型、昵称、电子邮件、账户ID、最后登录时间、常用登录类型、创建时间和账户等级以及是否被封禁的信息
#
# 查找Peggy Gayheart的账户级别
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Peggy Gayheart'的节点
# label为account,属性nickname='Peggy Gayheart'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Peggy Gayheart的账户级别
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Peggy Gayheart'的节点
# label为account,属性nickname='Peggy Gayheart'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Bethann Fasching的账号的类型、常用登录方式、账号等级、邮箱、昵称、是否被封禁、创建时间和手机号，并限制返回结果为6条。
#
# 查找Linwood Musca的账号是否被封禁
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Linwood Musca'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Linwood Musca的账号是否被封禁
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Linwood Musca'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Quincy Palevic的账号的邮箱、创建时间、是否被封禁、账号ID、昵称、常用登录类型、手机号和账户类型
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Quincy Palevic'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Quincy Palevic的账号的邮箱、创建时间、是否被封禁、账号ID、昵称、常用登录类型、手机号和账户类型
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Quincy Palevic'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica的最后登录时间、创建时间、手机号、账号ID和是否被封禁的状态
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica的最后登录时间、创建时间、手机号、账号ID和是否被封禁的状态
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Lesa Fuchser的邮箱、常用登录方式、账号类型、账号等级、昵称和创建时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Lesa Fuchser'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Lesa Fuchser的邮箱、常用登录方式、账号类型、账号等级、昵称和创建时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Lesa Fuchser'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Freeman Murchinson的账号的昵称、创建时间和常用登录方式
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Freeman Murchinson'的节点
# label为account,属性nickname='Freeman Murchinson'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Freeman Murchinson的账号的昵称、创建时间和常用登录方式
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Freeman Murchinson'的节点
# label为account,属性nickname='Freeman Murchinson'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Von Kwiecinski的账号类型，最多返回3个结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Von Kwiecinski'的节点
# label为account,属性nickname='Von Kwiecinski'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Von Kwiecinski的账号类型，最多返回3个结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Von Kwiecinski'的节点
# label为account,属性nickname='Von Kwiecinski'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Keri Dowless的账号是否被封禁、最后登录时间、昵称、电话号码、电子邮件和账号类型
#
# 查找昵称为Mee Litehiser的账户的最后登录时间、账户等级、邮箱、创建时间、是否被封禁、账户类型和昵称，限制返回17条结果
#
# 查找昵称为Preston Sankovich的账号的账号ID、最后登录时间和账号类型，最多返回14条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Preston Sankovich'的节点
# label为account,属性nickname='Preston Sankovich'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Preston Sankovich的账号的账号ID、最后登录时间和账号类型，最多返回14条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Preston Sankovich'的节点
# label为account,属性nickname='Preston Sankovich'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Jared Keeran的账户类型、账户ID、最后登录时间、电子邮件和电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Jared Keeran'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Jared Keeran的账户类型、账户ID、最后登录时间、电子邮件和电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Jared Keeran'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Betsey Kristensen的创建时间、账号ID、是否被封禁、电子邮件、账户类型、电话号码和最后登录时间
#
# 查找昵称为Gennie Mautz的账户的昵称、最后登录时间、账户等级、创建时间、账户类型、账户ID、常用登录类型、是否被封禁、电子邮件和电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Gennie Mautz'的节点
# label为account,属性nickname='Gennie Mautz'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Gennie Mautz的账户的昵称、最后登录时间、账户等级、创建时间、账户类型、账户ID、常用登录类型、是否被封禁、电子邮件和电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Gennie Mautz'的节点
# label为account,属性nickname='Gennie Mautz'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Paula Kreiman的账户级别和常见登录类型
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Paula Kreiman'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Paula Kreiman的账户级别和常见登录类型
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Paula Kreiman'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Laurence Mccoil的账号的昵称、是否被封禁、手机号、账号ID、账号等级、常用登录类型、创建时间、邮箱、最后登录时间和账号类型
#
# 查找Norberto Cocco的登录频率类型和最后登录时间
#
# 查找Jimmie Poldrack的最后登录时间、常用登录方式和他的昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Jimmie Poldrack'的节点
# label为account,属性nickname='Jimmie Poldrack'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Jimmie Poldrack的最后登录时间、常用登录方式和他的昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Jimmie Poldrack'的节点
# label为account,属性nickname='Jimmie Poldrack'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Hilario Dedecker的账户登录类型频率、创建时间、账户ID、最后登录时间、账户等级和是否被封禁状态
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Hilario Dedecker'的节点
# label为account,属性nickname='Hilario Dedecker'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Hilario Dedecker的账户登录类型频率、创建时间、账户ID、最后登录时间、账户等级和是否被封禁状态
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Hilario Dedecker'的节点
# label为account,属性nickname='Hilario Dedecker'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Crissy Rehmann的账户类型、昵称、创建时间、是否被封禁和最后登录时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Crissy Rehmann'的节点
# label为account,属性nickname='Crissy Rehmann'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Crissy Rehmann的账户类型、昵称、创建时间、是否被封禁和最后登录时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Crissy Rehmann'的节点
# label为account,属性nickname='Crissy Rehmann'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Mohammad Creitz的登录类型频率、手机号码、最后登录时间、电子邮件和是否被封禁的状态
#
# 查找昵称为Leo Astudillo的账号的邮箱、账号类型、是否被封禁、账号ID、常用登录方式、账号等级和电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Leo Astudillo'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Leo Astudillo的账号的邮箱、账号类型、是否被封禁、账号ID、常用登录方式、账号等级和电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Leo Astudillo'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Andre Craigwell的账号的账号ID、昵称、邮箱、账号等级、最后登录时间和账号类型以及创建时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Andre Craigwell'的节点
# label为account,属性nickname='Andre Craigwell'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Andre Craigwell的账号的账号ID、昵称、邮箱、账号等级、最后登录时间和账号类型以及创建时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Andre Craigwell'的节点
# label为account,属性nickname='Andre Craigwell'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Vince Moznett的账号的等级、类型、创建时间、邮箱、是否被封禁、最后登录时间、常用登录类型、手机号、昵称和账号ID
#
# 查找昵称为Harold Apolito的账号的是否被封禁、邮箱、最后登录时间、创建时间和账号等级，最多返回10条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Harold Apolito'的节点
# label为account,属性nickname='Harold Apolito'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Harold Apolito的账号的是否被封禁、邮箱、最后登录时间、创建时间和账号等级，最多返回10条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Harold Apolito'的节点
# label为account,属性nickname='Harold Apolito'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Theresia Wight的邮箱、创建时间、账户等级、账户类型、常用登录方式、昵称和手机号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Theresia Wight'的节点
# label为account,属性nickname='Theresia Wight'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Theresia Wight的邮箱、创建时间、账户等级、账户类型、常用登录方式、昵称和手机号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Theresia Wight'的节点
# label为account,属性nickname='Theresia Wight'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Rogelio Thaut的账户信息，包括登录频率类型、账户等级、电子邮件、创建时间、是否被封禁、最后登录时间、昵称、账户类型、手机号码和账户ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Rogelio Thaut'的节点
# label为account,属性nickname='Rogelio Thaut'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Rogelio Thaut的账户信息，包括登录频率类型、账户等级、电子邮件、创建时间、是否被封禁、最后登录时间、昵称、账户类型、手机号码和账户ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Rogelio Thaut'的节点
# label为account,属性nickname='Rogelio Thaut'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Deangelo Gephart的账号的等级、账号ID、创建时间、手机号和常用登录类型，最多返回2条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Deangelo Gephart'的节点
# label为account,属性nickname='Deangelo Gephart'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Deangelo Gephart的账号的等级、账号ID、创建时间、手机号和常用登录类型，最多返回2条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Deangelo Gephart'的节点
# label为account,属性nickname='Deangelo Gephart'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Eve Pusateri的手机号、创建时间、常用登录类型、账号类型、昵称、账号等级、最后登录时间和账号ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Eve Pusateri'的节点
# label为account,属性nickname='Eve Pusateri'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Eve Pusateri的手机号、创建时间、常用登录类型、账号类型、昵称、账号等级、最后登录时间和账号ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Eve Pusateri'的节点
# label为account,属性nickname='Eve Pusateri'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Tania Kensey的手机号码、常用登录方式、昵称、账号ID、是否被封禁、账号等级、账号类型和邮箱
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Tania Kensey'的节点
# label为account,属性nickname='Tania Kensey'的节点
# label为account,属性nickname='Regina Kenely'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Tania Kensey的手机号码、常用登录方式、昵称、账号ID、是否被封禁、账号等级、账号类型和邮箱
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Tania Kensey'的节点
# label为account,属性nickname='Tania Kensey'的节点
# label为account,属性nickname='Regina Kenely'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Alesia Dragovich的账号是否被封禁、账号类型和最后一次登录时间，最多返回9条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Angelika Dubovsky'的节点
# label为account,属性nickname='Angelika Dubovsky'的节点
# label为account,属性nickname='Alesia Dragovich'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Alesia Dragovich的账号是否被封禁、账号类型和最后一次登录时间，最多返回9条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Angelika Dubovsky'的节点
# label为account,属性nickname='Angelika Dubovsky'的节点
# label为account,属性nickname='Alesia Dragovich'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Donn Burgbacher的手机号和账户类型
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Donn Burgbacher'的节点
# label为account,属性nickname='Donn Burgbacher'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Donn Burgbacher的手机号和账户类型
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Donn Burgbacher'的节点
# label为account,属性nickname='Donn Burgbacher'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Noe Trites的账号的最后登录时间、账号类型、电子邮件、常用登录方式和电话号码，最多返回11条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Noe Trites'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Noe Trites的账号的最后登录时间、账号类型、电子邮件、常用登录方式和电话号码，最多返回11条结果
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Noe Trites'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Bert Inverso的账号是否被封禁、账号等级和最后登录时间
#
# 查找Lauren Marich的账户等级和电话号码
#
# 查找Danica Gollhofer的创建时间、昵称和手机号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Danica Gollhofer的创建时间、昵称和手机号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Rubin Maenaga的手机号码、账户等级、是否被封禁和账户ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Rubin Maenaga'的节点
# label为account,属性nickname='Rubin Maenaga'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Rubin Maenaga的手机号码、账户等级、是否被封禁和账户ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Rubin Maenaga'的节点
# label为account,属性nickname='Rubin Maenaga'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Clementine Buchberger的账户是否被封禁、昵称、账户等级和邮箱
#
# 查找Stephan Esqueda的账号是否被封禁、昵称、最后登录时间、账号类型、邮箱、账号ID和手机号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Stephan Esqueda'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Stephan Esqueda的账号是否被封禁、昵称、最后登录时间、账号类型、邮箱、账号ID和手机号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Stephan Esqueda'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Andrew Sweeney的账户类型、昵称、电话号码、最后登录时间、账户ID、是否被封禁和邮箱
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Andrew Sweeney'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Andrew Sweeney的账户类型、昵称、电话号码、最后登录时间、账户ID、是否被封禁和邮箱
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Andrew Sweeney'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Lolita Desilvo的账号信息，包括账号ID、账号等级、常用登录类型、最后登录时间、创建时间、账号类型、昵称、手机号和邮箱，最多返回2条记录
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Lolita Desilvo'的节点
# label为account,属性nickname='Almeda Lopardo'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Lolita Desilvo的账号信息，包括账号ID、账号等级、常用登录类型、最后登录时间、创建时间、账号类型、昵称、手机号和邮箱，最多返回2条记录
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Lolita Desilvo'的节点
# label为account,属性nickname='Almeda Lopardo'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Ferdinand Columbia的常用登录方式和他的昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Ferdinand Columbia'的节点
# label为account,属性nickname='Ferdinand Columbia'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Ferdinand Columbia的常用登录方式和他的昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Ferdinand Columbia'的节点
# label为account,属性nickname='Ferdinand Columbia'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Pamelia Vanvranken的登录频率类型、手机号、昵称和账号ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Pamelia Vanvranken'的节点
# label为account,属性nickname='Pamelia Vanvranken'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Pamelia Vanvranken的登录频率类型、手机号、昵称和账号ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Pamelia Vanvranken'的节点
# label为account,属性nickname='Pamelia Vanvranken'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Faustino Marolf的账号的常用登录类型和是否被封禁的状态
#
# 查找昵称为Faustino Marolf的账户对贷款的还款金额、账户邮箱、昵称、贷款创建时间、还款创建时间、账户ID、贷款余额、账户创建时间和账户是否被封禁的信息
#
# 查找昵称为Faustino Marolf的账户还款的贷款信息，包括贷款余额、账户等级、昵称、贷款ID、登录频率类型、手机号、还款金额、账户ID、贷款用途、账户是否被封禁、最后一次登录时间、还款创建时间、账户创建时间、贷款利率、贷款金额、贷款创建时间，并跳过前5条记录，限制返回17条记录。
#
# 查找Faustino Marolf的账户信息，包括账户ID、昵称、最后登录时间、是否被封禁、登录频率类型、邮箱、电话号码、创建时间，以及他偿还的贷款信息，包括贷款用途、贷款ID、利率、余额、贷款创建时间和偿还金额。
#
# 查找昵称为Faustino Marolf的账户的创建时间、账户ID、邮箱、昵称，以及他偿还贷款的金额和贷款的利率，还有偿还记录的创建时间
#
# 查找昵称为Kathleen Salvador的账户的登录频率类型、账户等级、账户ID、账户类型和手机号，以及她还款的贷款的利率、还款金额、贷款余额，并跳过前2条记录，返回接下来的15条记录。
#
# 查找Kathleen Salvador的账户信息及其偿还的贷款详情，包括账户ID、贷款用途、贷款创建时间、昵称、是否被封禁、最后登录时间、贷款利率、邮箱、账户创建时间、手机号、贷款金额、账户等级、账户类型、贷款余额、贷款ID以及偿还记录的创建时间。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Kathleen Salvador的账户信息及其偿还的贷款详情，包括账户ID、贷款用途、贷款创建时间、昵称、是否被封禁、最后登录时间、贷款利率、邮箱、账户创建时间、手机号、贷款金额、账户等级、账户类型、贷款余额、贷款ID以及偿还记录的创建时间。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Kathleen Salvador的账户是否被封禁、账户类型、她偿还的贷款的创建时间、偿还金额、贷款ID以及她的电子邮件地址
#
# 查找Kathleen Salvador的账户类型、常用登录方式、昵称和创建时间，以及她偿还的贷款的贷款ID、贷款用途和贷款金额
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Kathleen Salvador的账户类型、常用登录方式、昵称和创建时间，以及她偿还的贷款的贷款ID、贷款用途和贷款金额
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Mildred Clever的账号昵称、账号ID、手机号、常用登录方式、账号等级和最后登录时间
#
# 查找Mildred Clever的账户是否被封禁、登录频率类型、账户ID、账户等级、贷款ID以及账户类型和昵称
#
# 查找Randolph Gica的登录频率类型、最后登录时间和是否被封禁，以及他关联的贷款的创建时间及电话号码，限制返回17条记录
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica的登录频率类型、最后登录时间和是否被封禁，以及他关联的贷款的创建时间及电话号码，限制返回17条记录
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica的账户还款记录的创建时间和他的电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica的账户还款记录的创建时间和他的电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica账户关联的贷款信息，包括他的昵称、贷款的创建时间、贷款金额、贷款用途、账户是否被封禁、最后登录时间、贷款利率、账户类型和账户ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica账户关联的贷款信息，包括他的昵称、贷款的创建时间、贷款金额、贷款用途、账户是否被封禁、最后登录时间、贷款利率、账户类型和账户ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica的账户登录频率类型、邮箱、以及他偿还的贷款的创建时间、账户类型、贷款金额、利率、昵称、贷款ID和账户ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica的账户登录频率类型、邮箱、以及他偿还的贷款的创建时间、账户类型、贷款金额、利率、昵称、贷款ID和账户ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Randolph Gica'的节点
# label为account,属性nickname='Randolph Gica'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Faustino Marolf的账户的登录频率类型、账户类型、电子邮件、电话号码、贷款ID、利率、贷款用途、是否被封禁、昵称、账户与贷款关系的创建时间以及最后登录时间
#
# 查找昵称为Faustino Marolf的账户还款的贷款信息，包括贷款用途、贷款ID、贷款金额、还款时间、账户等级、是否被封禁、账户类型、最后登录时间、贷款余额、登录频率类型、邮箱、手机号、贷款利率、贷款创建时间和账户创建时间
#
# 查找昵称为Faustino Marolf的账户信息及其偿还的贷款信息，包括账户类型、贷款创建时间、账户等级、邮箱、电话号码、最后登录时间、贷款利率、是否被封禁、账户ID、贷款用途、登录频率类型、贷款余额和偿还记录的创建时间，限制返回10条结果。
#
# 查找昵称为Faustino Marolf的账户信息，包括账户类型、最后登录时间、常用登录方式、昵称、是否被封禁、创建时间、手机号、邮箱、账户等级、账户ID，以及该账户偿还的贷款信息，包括贷款利率、余额、贷款ID、贷款金额，同时返回偿还金额，限制返回2条结果。
#
# 查找昵称为Thresa Jiran的账户是否被封禁、最后登录时间、账户类型、昵称、邮箱、账户等级、账户ID、手机号、创建时间，以及她偿还的贷款的贷款ID、金额、利率、贷款金额、余额、创建时间和偿还时间，最多返回16条记录。
#
# 查找昵称为Echo Murrill的账户创建时间，以及他偿还的贷款余额和偿还金额，从第14条记录开始，返回3条记录
#
# 查找昵称为Echo Murrill的账户偿还贷款的信息，包括贷款余额、账户创建时间、昵称、邮箱、账户ID、手机号、贷款利率、偿还金额、贷款ID、偿还创建时间和账户等级及类型
#
# 查找昵称为Echo Murrill的账户ID、创建时间、昵称、是否被封禁、手机号、贷款ID、账户类型、还款金额、邮箱、账户等级以及贷款用途
#
# 查找Echo Murrill最近偿还的17个贷款的创建时间和她的常用登录类型
#
# 查找Mary Cariaga的账户信息及其偿还的贷款信息，包括贷款的创建时间、用途、余额、金额、利率、贷款ID，以及账户的创建时间、登录频率类型、邮箱、最后登录时间、账户等级、账户ID、账户类型和是否被封禁状态。
#
# 查找昵称为Danica Gollhofer的账户创建时间、贷款创建时间、贷款金额、贷款用途、电话号码、邮箱、账户ID、贷款ID以及登录频率类型和贷款利率，最多返回9条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Danica Gollhofer的账户创建时间、贷款创建时间、贷款金额、贷款用途、电话号码、邮箱、账户ID、贷款ID以及登录频率类型和贷款利率，最多返回9条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Danica Gollhofer的账户与贷款之间的还款记录，返回账户的邮箱、最后一次登录时间、账户等级、是否被封禁、账户类型、创建时间、账户ID、昵称、电话号码，以及贷款的余额、用途、利率、贷款金额、创建时间，还有还款记录的金额和创建时间，限制返回18条记录。
#
# 查找昵称为Danica Gollhofer的账户的电子邮件、账户类型、最后登录时间、还款金额、昵称、贷款利率、账户ID、还款创建时间和贷款金额及贷款ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Danica Gollhofer的账户的电子邮件、账户类型、最后登录时间、还款金额、昵称、贷款利率、账户ID、还款创建时间和贷款金额及贷款ID
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Danica Gollhofer的账户信息及其偿还的贷款详情，包括贷款用途、贷款金额、账户登录频率、账户等级、昵称、偿还金额、贷款ID、账户创建时间、贷款余额、账户邮箱、偿还创建时间和贷款利率、账户类型及贷款创建时间。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Danica Gollhofer的账户信息及其偿还的贷款详情，包括贷款用途、贷款金额、账户登录频率、账户等级、昵称、偿还金额、贷款ID、账户创建时间、贷款余额、账户邮箱、偿还创建时间和贷款利率、账户类型及贷款创建时间。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Mildred Clever账户还款的贷款信息，包括还款金额、账户是否被封、账户创建时间、手机号、贷款创建时间、登录频率类型、贷款利率、账户ID、昵称、最后登录时间和贷款金额、账户等级。
#
# 查找昵称为Mildred Clever的账户创建时间、手机号码、账户等级、登录频率类型、是否被封禁、账户ID，以及该账户偿还的贷款的利率、贷款用途、贷款ID、贷款余额、贷款创建时间，还有偿还记录的创建时间和金额。
#
# 查找昵称为Mildred Clever的账户及其还款的贷款信息，包括账户ID、昵称、贷款利率、贷款用途、账户等级、还款金额、贷款余额、贷款金额、贷款ID、邮箱、是否被封禁、手机号、最后登录时间、还款创建时间、贷款创建时间、登录频率类型、账户创建时间和账户类型。
#
# 查找Mildred Clever的邮箱，以及她偿还的贷款余额、还款金额、贷款利率、贷款金额、登录频率类型、最后登录时间和账户等级
#
# 查找昵称为Faustino Marolf的账户的昵称、手机号和账户类型，以及他偿还的贷款的贷款ID
#
# 查找昵称为Faustino Marolf的账户的邮箱、手机号、账户还款贷款的创建时间、账户的创建时间、贷款用途以及账户的常用登录类型
#
# 查找昵称为Faustino Marolf的账户是否被封禁、账户ID、最后登录时间、贷款ID、创建时间和账户等级以及邮箱地址
#
# 查找昵称为Faustino Marolf的账户级别、昵称、是否被封禁、账户创建时间、登录频率类型、账户ID、手机号，以及该账户还款的贷款的创建时间、还款时间、还款金额、贷款ID、利率、余额、贷款用途、贷款金额。
#
# 查找昵称为Hope Metherell的账户创建时间、账户类型、最后登录时间、手机号和账户等级，以及该账户偿还的贷款金额、贷款ID、贷款余额和偿还金额。
#
# 查找昵称为Antonietta Archbold的账户最后一次登录时间、账号类型、电话号码、频繁登录类型、账号ID、账号等级、创建时间、邮箱地址、是否被封禁，以及该账户还款的贷款的贷款ID、利率、创建时间、贷款用途、余额和还款金额。
#
# 查找Kathleen Salvador的账户ID、账户类型、创建时间、是否被封禁、最后登录时间，以及她偿还的贷款的用途、贷款ID和利率，同时返回偿还记录的创建时间
#
# 查找Kathleen Salvador的账户与贷款之间的还款记录，返回贷款的创建时间、还款记录的创建时间、账户的登录频率类型、是否被封禁、电话号码、账户类型、还款金额、昵称、贷款用途、贷款ID、贷款余额、贷款利率、账户等级、账户创建时间、贷款金额、账户邮箱、最后登录时间和账户ID，限制返回3条记录。
#
# 查找Kathleen Salvador账户下的贷款信息，包括账户ID、贷款金额、昵称、账户创建时间、手机号、邮箱、贷款利率、还款记录创建时间和贷款创建时间，仅返回一条记录。
#
# 查找Kathleen Salvador的最后一次登录时间、账户类型、是否被封禁、常用登录类型，以及她偿还的贷款的贷款ID、贷款金额、贷款用途和偿还记录的创建时间
#
# 查找昵称为Echo Murrill的账户偿还的贷款信息，包括贷款用途、账户创建时间、贷款余额、贷款创建时间、还款创建时间、账户等级、还款金额、账户ID、账户最后登录时间以及贷款ID，跳过前12条记录，返回接下来的16条记录。
#
# 查找Echo Murrill偿还的贷款用途
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Echo Murrill'的节点
# label为account,属性nickname='Echo Murrill'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Echo Murrill偿还的贷款用途
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Echo Murrill'的节点
# label为account,属性nickname='Echo Murrill'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Echo Murrill账户还款的贷款信息，包括贷款的创建时间、账户的手机号、贷款用途、账户邮箱、还款金额、账户登录频率类型、账户等级、账户昵称、账户ID、贷款金额和贷款ID，限制返回2条结果。
#
# 查找昵称为Echo Murrill的账户信息及其还款的贷款详情，包括贷款余额、昵称、贷款ID、账户ID、账户创建时间、账户类型、贷款用途、贷款金额、邮箱、贷款创建时间、账户是否被封禁、最后登录时间、账户等级、贷款利率、电话号码以及还款金额和账户登录频率类型。
#
# 查找Kathleen Salvador的最后一次登录时间、账户类型、邮箱、账户ID、昵称，以及她偿还的贷款的创建时间、贷款ID、电话号码、贷款用途、利率和偿还金额
#
# 查找Kathleen Salvador的贷款记录，返回贷款ID、还款创建时间、贷款用途以及账户最后登录时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Kathleen Salvador的贷款记录，返回贷款ID、还款创建时间、贷款用途以及账户最后登录时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Kathleen Salvador的账户是否被封禁、常用登录类型、以及她偿还的贷款的利率、创建时间、邮箱、昵称和电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Kathleen Salvador的账户是否被封禁、常用登录类型、以及她偿还的贷款的利率、创建时间、邮箱、昵称和电话号码
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Peggy Gayheart进行账户转账的目标账户的邮箱、昵称、是否被封禁、常用登录类型、最后登录时间、创建时间、手机号、账户类型、账户等级，以及转账记录的支付类型、商品类型、订单号、创建时间、金额和备注。同时返回Peggy Gayheart的邮箱、是否被封禁、常用登录类型、最后登录时间、创建时间、手机号、账户类型、账户ID和账户等级。
#
# 查找Peggy Gayheart向Theresia Wight转账的Theresia Wight的邮箱、电话号码，以及Peggy Gayheart的账户等级、常用登录类型，转账的商品类型，和Theresia Wight是否被封禁的信息。
#
# 查找Peggy Gayheart向Theresia Wight转账的详细信息，包括Peggy Gayheart的电话号码和最后登录时间，Theresia Wight的账户等级、账户类型、频繁登录类型、是否被封禁，以及转账的商品类型、金额、创建时间和备注。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Peggy Gayheart'的节点
# label为account,属性nickname='Peggy Gayheart'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Peggy Gayheart向Theresia Wight转账的详细信息，包括Peggy Gayheart的电话号码和最后登录时间，Theresia Wight的账户等级、账户类型、频繁登录类型、是否被封禁，以及转账的商品类型、金额、创建时间和备注。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Peggy Gayheart'的节点
# label为account,属性nickname='Peggy Gayheart'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Peggy Gayheart向Theresia Wight转账的详细信息，包括Theresia Wight的账户状态、邮箱、昵称、常用登录类型、最后登录时间、手机号、创建时间；以及Peggy Gayheart的手机号、商品类型、常用登录类型、最后登录时间、支付类型、订单号、金额、评论、创建时间、账户类型、昵称、账户ID、邮箱、账户等级。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Peggy Gayheart'的节点
# label为account,属性nickname='Peggy Gayheart'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Peggy Gayheart向Theresia Wight转账的详细信息，包括Theresia Wight的账户状态、邮箱、昵称、常用登录类型、最后登录时间、手机号、创建时间；以及Peggy Gayheart的手机号、商品类型、常用登录类型、最后登录时间、支付类型、订单号、金额、评论、创建时间、账户类型、昵称、账户ID、邮箱、账户等级。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Peggy Gayheart'的节点
# label为account,属性nickname='Peggy Gayheart'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Jimmie Poldrack账户转账给其他账户的信息，返回转账顺序号、Jimmie Poldrack的账户类型、接收账户的账户等级、转账金额、接收账户的账户类型、接收账户的手机号、接收账户的最后登录时间以及Jimmie Poldrack的手机号，跳过前18条记录，限制返回15条记录
#
# 查找Jimmie Poldrack账户转账给其他账户的信息，包括接收方的昵称、发送方的是否被封禁、转账的商品类型、接收方的创建时间、支付方式、发送方的最后登录时间、订单数量、接收方的最后登录时间、转账的创建时间、发送方的邮箱、发送方的常用登录方式、发送方的账户ID、发送方的电话号码、发送方的昵称、发送方的创建时间、转账金额、接收方的账户等级、接收方的常用登录方式、转账备注、接收方的账户ID、接收方的邮箱。
#
# 查找Mohammad Creitz转账给的账户的创建时间、是否被封禁、转账备注、接收方最后登录时间、转账方登录频率类型、转账方邮箱、转账方账号ID、支付类型、接收方昵称、接收方账号ID、转账金额、转账方创建时间、转账方手机号、接收方是否被封禁、接收方账户类型、订单号、转账方最后登录时间、接收方登录频率类型、转账方账户类型、商品类型、转账创建时间、接收方手机号、接收方邮箱、接收方账户等级
#
# 查找与Pamelia Vanvranken账户有关的转账记录，包括Pamelia Vanvranken的账户等级、创建时间、是否被封禁、账户类型、最后登录时间、手机号、邮箱，以及转账方的登录频率类型、昵称、账户类型、创建时间、是否被封禁、最后登录时间、手机号，同时返回转账记录的支付方式、订单号、备注、创建时间、商品类型、金额，限制返回7条记录。
#
# 查找Laura Hanavan的账户的常用登录类型、与她有转账关系的账户的邮箱、转账方式、转账备注、她的电话号码以及订单号
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Laura Hanavan'的节点
# label为account,属性nickname='Laura Hanavan'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Laura Hanavan的账户的常用登录类型、与她有转账关系的账户的邮箱、转账方式、转账备注、她的电话号码以及订单号
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Laura Hanavan'的节点
# label为account,属性nickname='Laura Hanavan'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Mee Litehiser向Laura Hanavan转账的账户信息，包括Mee Litehiser的邮箱、昵称、账户类型、账户等级、创建时间、是否被封禁，以及Laura Hanavan的账户类型、昵称、账户等级、创建时间、是否被封禁，还有转账的商品类型和支付类型。
#
# 查找Laura Hanavan收到的最近14笔转账记录的创建时间、转账方的账户类型和转账金额
#
# 查找Mee Litehiser转账给其他账户的详细信息，包括转账备注，接收方的账号ID、创建时间、昵称、邮箱、账号类型、账号等级、电话号码、是否被封禁、常用登录方式、最后登录时间，以及发送方的邮箱、账号ID、账号类型、电话号码、是否被封禁、常用登录方式、最后登录时间，转账的商品类型、创建时间、金额。
#
# 查找Betsey Kristensen向Jacob Sheild转账的记录，返回转账的商品类型、接收方昵称、发送方账户类型、接收方最后登录时间、订单号、支付方式、发送方最后登录时间、接收方账户ID、转账金额、接收方账户等级、评论、创建时间、发送方账户ID、接收方账户类型、发送方昵称、发送方是否被封禁以及发送方电话号码。
#
# 查找从Betsey Kristensen转账给Jacob Sheild的账户信息，包括Jacob Sheild的昵称、是否被封禁、邮箱以及Betsey Kristensen的账户ID
#
# 查找Betsey Kristensen向Jacob Sheild转账的账户信息，包括转账订单号、商品类型、转账金额、支付方式、转账时间，以及双方的账户等级、邮箱、创建时间、是否被封禁、最后登录时间、账户ID、电话号码、常用登录类型、账户类型，限制返回9条记录。
#
# 查找Betsey Kristensen向Jacob Sheild转账的账户类型、订单号、昵称、邮箱、接收方的账户等级、最后登录时间、是否被封禁、常用登录方式、创建时间、转账的商品类型、转账的创建时间、发送方的最后登录时间、发送方的账户ID、接收方的账户类型。
#
# 查找Jimmie Poldrack向Jared Keeran转账的账户信息，包括Jimmie Poldrack的创建时间、账户等级、账户类型、最后登录时间、是否被封禁，转账记录的创建时间、订单号、金额、备注，以及Jared Keeran的账户ID、创建时间、账户类型、电话号码、昵称、常用登录方式。
#
# 查找Jimmie Poldrack向Jared Keeran转账的时间，以及Jimmie Poldrack的最后登录时间和昵称及账户等级
#
# 查找Jimmie Poldrack的账户常用登录类型
#
# 查找Jimmie Poldrack向Andrew Sweeney转账的详细信息，包括Andrew Sweeney的最后登录时间、邮箱、手机号、常用登录类型、昵称、账户类型，以及Jimmie Poldrack的是否被封禁、最后登录时间、邮箱、常用登录类型、昵称、账户类型，同时返回转账的商品类型、金额、支付方式和订单号。
#
# 查找Gennie Mautz账户的转账记录，包括转账类型、转账双方的账户类型、账户ID、邮箱、创建时间、最后登录时间、是否被封禁、电话号码、转账顺序号、转账金额、账户等级和常用登录类型。
#
# 查找Willian Stream账户转账给的账户的账户等级、登录频率类型、邮箱、登录频率类型、创建时间、是否被封禁以及账户ID，同时返回Willian Stream的登录频率类型、邮箱和账户ID
#
# 查找昵称为Freeman Murchinson的账户向昵称为Fredric Nothstine的账户转账的详细信息，包括转账双方的手机号、账户ID、登录频率类型、是否被封禁、转账备注、创建时间、账户类型、最后登录时间、邮箱和昵称。
#
# 查找昵称为Freeman Murchinson的账户向其他账户转账的信息，包括转账时间、接收方昵称、转账金额、发送方最后登录时间、接收方邮箱、接收方账户ID、转账订单号、转账备注、接收方最后登录时间、发送方邮箱、发送方账户ID、转账商品类型、接收方是否被封禁、发送方是否被封禁、接收方常用登录类型、发送方电话号码
#
# 查找Freeman Murchinson向Fredric Nothstine转账的账户ID、创建时间、账户类型、昵称、最后登录时间、转账创建时间和支付类型
#
# 查找昵称为Freeman Murchinson的账户与另一个账户之间的转账记录，返回转账的商品类型、Freeman Murchinson的账户是否被封禁、手机号、对方账户的最后登录时间、账户ID、常用登录方式、Freeman Murchinson的最后登录时间、账户ID、转账订单号、账户类型、创建时间和账户等级以及邮箱。
#
# 查找Del Hallam向Fredric Nothstine转账的支付类型、转账备注、双方的账号状态、账号类型、昵称、电话号码、账号等级、最后登录时间、创建时间、账号ID、邮箱以及转账的订单号、金额，最多返回9条记录。
#
# 查找Fredric Nothstine的账户信息，包括账户类型、电话号码、转账订单号、备注、创建时间、昵称、支付方式、对方账户等级、是否被封禁、账户ID、账户类型、频率登录方式、邮箱、对方账户等级、电话号码、频率登录方式、账户ID、商品类型、是否被封禁、最后登录时间。同时返回转账记录的创建时间和商品类型。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Fredric Nothstine'的节点
# label为account,属性nickname='Fredric Nothstine'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Fredric Nothstine的账户信息，包括账户类型、电话号码、转账订单号、备注、创建时间、昵称、支付方式、对方账户等级、是否被封禁、账户ID、账户类型、频率登录方式、邮箱、对方账户等级、电话号码、频率登录方式、账户ID、商品类型、是否被封禁、最后登录时间。同时返回转账记录的创建时间和商品类型。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Fredric Nothstine'的节点
# label为account,属性nickname='Fredric Nothstine'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Del Hallam的账户创建时间、转账金额、转账时间、接收账户的等级、接收账户ID、发送账户ID、发送账户是否被封禁、支付类型、转账备注、接收账户最后登录时间、接收账户邮箱、发送账户常用登录类型、发送账户手机号和发送账户昵称、接收账户类型
#
# 查找Del Hallam向Fredric Nothstine转账的详细信息，包括转账金额、订单号、支付类型、商品类型、评论，以及双方的账号ID、账号类型、登录时间、电话号码、账号等级和常用登录方式，限制返回8条记录。
#
# 查找与Mike Senecal有关的账户转账记录的创建时间、支付类型、商品类型、对方账户的手机号、是否被封禁、订单号、创建时间、账户ID、评论、昵称和账户等级
#
# 查找Damian Warsing和Carissa Pasqualetti之间的账户转账记录，返回Damian Warsing的最后登录时间、Carissa Pasqualetti的邮箱、转账的商品类型、Carissa Pasqualetti的创建时间、Damian Warsing的账户ID、转账金额、转账备注、Carissa Pasqualetti的账户ID、Carissa Pasqualetti的电话号码、Damian Warsing的电话号码、Damian Warsing是否被封禁、Carissa Pasqualetti的账户类型、Damian Warsing的创建时间、Carissa Pasqualetti是否被封禁、转账支付方式、Damian Warsing的账户类型、Carissa Pasqualetti的账户等级、转账订单号，限制返回18条记录。
#
# 查找Carissa Pasqualetti向Damian Warsing转账的记录，返回Damian Warsing的昵称、最后登录时间、Carissa Pasqualetti的账户等级、Damian Warsing的常用登录类型、转账备注、Damian Warsing的创建时间、Carissa Pasqualetti的电话号码、Carissa Pasqualetti的常用登录类型和Carissa Pasqualetti的最后登录时间，限制返回17条记录。
#
# 查找Carissa Pasqualetti向Damian Warsing转账的详细信息，包括转账备注、转账物品类型、转账金额、订单号，以及两个账户的创建时间、账户类型、昵称、最后登录时间、登录频率类型、账户等级、是否被封禁、手机号、账户ID和邮箱。
#
# 查找Carissa Pasqualetti向Damian Warsing转账的记录，返回Damian Warsing的最后登录时间、转账备注、Damian Warsing的常用登录类型、Carissa Pasqualetti的账号等级、Damian Warsing的账号类型、Damian Warsing是否被封禁、Carissa Pasqualetti的常用登录类型、Damian Warsing的账号等级、转账支付方式、Carissa Pasqualetti的账号ID、Carissa Pasqualetti的手机号、转账金额、Carissa Pasqualetti的昵称、Damian Warsing的昵称、Damian Warsing的账号ID、Carissa Pasqualetti的邮箱，最多返回6条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Carissa Pasqualetti'的节点
# label为account,属性nickname='Carissa Pasqualetti'的节点
# label为account,属性nickname='Waneta Giovannini'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Carissa Pasqualetti向Damian Warsing转账的记录，返回Damian Warsing的最后登录时间、转账备注、Damian Warsing的常用登录类型、Carissa Pasqualetti的账号等级、Damian Warsing的账号类型、Damian Warsing是否被封禁、Carissa Pasqualetti的常用登录类型、Damian Warsing的账号等级、转账支付方式、Carissa Pasqualetti的账号ID、Carissa Pasqualetti的手机号、转账金额、Carissa Pasqualetti的昵称、Damian Warsing的昵称、Damian Warsing的账号ID、Carissa Pasqualetti的邮箱，最多返回6条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Carissa Pasqualetti'的节点
# label为account,属性nickname='Carissa Pasqualetti'的节点
# label为account,属性nickname='Waneta Giovannini'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Gennie Mautz向Fredric Nothstine转账的账户类型
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Gennie Mautz'的节点
# label为account,属性nickname='Gennie Mautz'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Gennie Mautz向Fredric Nothstine转账的账户类型
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Gennie Mautz'的节点
# label为account,属性nickname='Gennie Mautz'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Gennie Mautz向Fredric Nothstine转账的账户信息，包括Gennie Mautz的账户等级、最后登录时间、创建时间、邮箱，Fredric Nothstine的登录频率类型、是否被封禁、最后登录时间、账户ID、账户等级、电话号码，以及转账金额和支付类型，最多返回16条记录。
#
# 查找Gennie Mautz和Fredric Nothstine之间的账户转账记录，返回转账的商品类型、Gennie Mautz的账户等级、支付方式、是否被封禁、Fredric Nothstine的账户类型、Gennie Mautz的最后登录时间、Fredric Nothstine的邮箱、Gennie Mautz的邮箱、转账记录的创建时间、Gennie Mautz的电话号码、Fredric Nothstine的最后登录时间、转账订单号、Fredric Nothstine的账户等级、Gennie Mautz的昵称、转账备注、Gennie Mautz的常用登录方式、Fredric Nothstine的常用登录方式以及Fredric Nothstine的账户ID。
#
# 查找Gennie Mautz转账给Fredric Nothstine的账户类型，跳过前14条记录，返回接下来的6条记录
#
# 查找Norberto Cocco转账给Cordelia Ratcliffe的账户的最后登录时间
#
# 查找Norberto Cocco向Cordelia Ratcliffe转账的创建时间和Norberto Cocco的电话号码，限制返回5条记录
#
# 查找Norberto Cocco向Cordelia Ratcliffe转账的评论、接收方昵称、发起方账户等级、订单号、发起方邮箱、发起方昵称、发起方是否被封禁、接收方创建时间、支付类型、接收方账户等级、发起方常用登录方式、接收方是否被封禁、转账创建时间和转账金额
#
# 查找与Cordelia Ratcliffe账户有转账关系的账户信息，包括Cordelia Ratcliffe的账户等级、转账发起方的账户ID、登录频率类型、邮箱、账户等级、最后登录时间、昵称、是否被封禁，以及转账的商品类型、订单号、备注，同时返回Cordelia Ratcliffe的邮箱、昵称、手机号、账户类型。
#
# 查找Luis Thies接收的账户转账的支付类型
#
# 查找Buck Morles的账户信息及其转账给其他账户的信息，包括Buck Morles的昵称、是否被封禁、对方账户的常用登录类型、账户类型、最后登录时间、Buck Morles的账户ID、对方账户的等级、昵称、Buck Morles的邮箱、转账的商品类型以及对方账户的ID。
#
# 查找Fredric Nothstine最后一次登录时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Fredric Nothstine'的节点
# label为account,属性nickname='Fredric Nothstine'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Fredric Nothstine最后一次登录时间
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Fredric Nothstine'的节点
# label为account,属性nickname='Fredric Nothstine'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Buck Morles向Fredric Nothstine转账的账户信息，包括Fredric Nothstine的昵称、账户类型、转账的商品类型、创建时间、Buck Morles的是否被封禁、账户等级、电话号码、账户类型和邮箱
#
# 查找Buck Morles账户转账给的账户的邮箱、常用登录类型以及Buck Morles账户的创建时间
#
# 查找Freeman Murchinson转账给的账户是否被封禁了
#
# 查找Fredric Nothstine接收的账户转账记录的创建时间、账户ID、转账金额、账户等级、最后登录时间、手机号、创建时间和转账方是否被封禁状态以及Fredric Nothstine的邮箱。
#
# 查找Quincy Palevic账户的提现记录，返回提现目标账户的ID、电话号码、邮箱、昵称、是否被封禁、创建时间，以及Quincy Palevic的昵称、邮箱、最后登录时间、账户ID、账户类型和账户等级。
#
# 查找Kurt Fernandes从Linwood Musca账户中提现的账户类型、最后登录时间、手机号、邮箱、常用登录类型、昵称、账户等级、创建时间、是否被封禁等信息。
#
# 查找Kurt Fernandes账户的转账记录，返回转账时间、Kurt Fernandes的账户等级、转账金额、Kurt Fernandes的账户ID、接收账户的昵称、Kurt Fernandes的是否被封禁状态、接收账户的邮箱、Kurt Fernandes的创建时间、接收账户的账户ID、Kurt Fernandes的手机号、Kurt Fernandes的常用登录方式、接收账户的最后登录时间、Kurt Fernandes的最后登录时间、Kurt Fernandes的昵称、接收账户的账户等级、接收账户的手机号、Kurt Fernandes的邮箱、Kurt Fernandes的账户类型、接收账户的是否被封禁状态、接收账户的账户类型，限制返回3条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kurt Fernandes'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Kurt Fernandes账户的转账记录，返回转账时间、Kurt Fernandes的账户等级、转账金额、Kurt Fernandes的账户ID、接收账户的昵称、Kurt Fernandes的是否被封禁状态、接收账户的邮箱、Kurt Fernandes的创建时间、接收账户的账户ID、Kurt Fernandes的手机号、Kurt Fernandes的常用登录方式、接收账户的最后登录时间、Kurt Fernandes的最后登录时间、Kurt Fernandes的昵称、接收账户的账户等级、接收账户的手机号、Kurt Fernandes的邮箱、Kurt Fernandes的账户类型、接收账户的是否被封禁状态、接收账户的账户类型，限制返回3条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kurt Fernandes'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Andre Craigwell的账户信息，包括是否被封禁、账户ID、登录频率类型、邮箱、昵称、电话号码、最后登录时间、创建时间和账户类型。同时返回与该账户有提现关系的另一个账户的信息，包括账户ID、账户类型、电话号码、最后登录时间、账户等级、昵称、登录频率类型、创建时间、邮箱、是否被封禁，以及提现关系的金额和创建时间。
#
# 查找Eve Pusateri和Andre Craigwell之间的账户转账记录，返回Eve Pusateri的登录频率类型、账户等级、账户类型，以及Andre Craigwell的电话号码、是否被封禁、账户类型、创建时间，同时返回转账记录的创建时间。
#
# 查找Eve Pusateri和Andre Craigwell之间的账户转账记录，返回Eve Pusateri的最后登录时间、常用登录类型、转账金额、转账创建时间、账户类型、账户等级、邮箱、创建时间、是否被封禁、账户ID、昵称、电话号码；以及Andre Craigwell的电话号码、常用登录类型、账户等级、是否被封禁、账户ID、账户类型、创建时间。
#
# 查找Andre Craigwell转账给的账户的账户ID、转账金额、他的电话号码、接收者的昵称、接收者的账户类型以及接收者的账户是否被封禁
#
# 查找Jacob Sheild向Danica Gollhofer转账的记录，返回转账时间、Jacob Sheild的创建时间、Danica Gollhofer的昵称、转账金额、Jacob Sheild的账户是否被封、最后登录时间、账户ID、账户类型、Danica Gollhofer的最后登录时间、常用登录方式、Jacob Sheild的电话号码、常用登录方式、账户等级以及Danica Gollhofer的账户等级，最多返回11条记录。
#
# 查找与Danica Gollhofer账户有提现关系的账户信息，包括双方的账户等级、电话号码、昵称、提现时间、是否被封禁、最后登录时间、账户类型、创建时间和邮箱，以及提现金额和频繁登录类型。
#
# 查找Jacob Sheild从其他账户中提现的记录，返回Jacob Sheild的登录频率类型、账户等级、手机号、是否被封禁、账户ID、邮箱、昵称、最后登录时间，以及对方账户的账户类型、账户等级、邮箱、账户ID、昵称、创建时间，提现记录的创建时间和金额。跳过前13条记录，返回接下来的19条记录。
#
# 查找Laurence Mccoil账户的转账记录，返回接收账户的最后登录时间、是否被封禁、转账金额、接收账户的创建时间、账户等级、电话号码、账户类型、昵称、账户ID、常用登录类型、邮箱，以及转账记录的创建时间，限制返回16条记录。
#
# 查找Laurence Mccoil向Luis Thies转账的账户信息，包括Laurence Mccoil的最后登录时间、邮箱、账户类型、是否被封禁以及Luis Thies的账户ID和Laurence Mccoil的常用登录类型
#
# 查找Milford Zolla向Danica Gollhofer转账的账户信息，包括Danica Gollhofer的创建时间、是否被封禁、账户ID、电子邮件、转账时间，以及Milford Zolla的创建时间、登录频率类型、账户ID、账户类型、手机号、昵称、登录频率类型、最后登录时间、电子邮件、账户类型、账户等级和是否被封禁。
#
# 查找Milford Zolla和Danica Gollhofer之间的账户转账记录，返回Milford Zolla的昵称、手机号、账户类型、常用登录类型、是否被封禁、最后登录时间、创建时间、邮箱，以及Danica Gollhofer的最后登录时间、账户ID、是否被封禁、邮箱，同时返回转账记录的创建时间和金额。
#
# 查找向Danica Gollher转账的账户的电话号码，以及转账的时间和Danica Gollhofer的昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找向Danica Gollher转账的账户的电话号码，以及转账的时间和Danica Gollhofer的昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Danica Gollhofer'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Milford Zolla从Danica Gollhofer账户中提现的记录，返回Milford Zolla的昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Milford Zolla'的节点
# label为account,属性nickname='Milford Zolla'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Milford Zolla从Danica Gollhofer账户中提现的记录，返回Milford Zolla的昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Milford Zolla'的节点
# label为account,属性nickname='Milford Zolla'的节点
# label为account,属性nickname='Danica Gollhofer'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找与Paula Kreiman有账户提现关系的账户的登录频率类型、昵称、邮箱、创建时间、最后登录时间、账户类型、电话号码、账户等级、账户ID以及关系的创建时间。返回的信息包括两个账户的详细信息和它们之间的关系创建时间。
#
# 查找 Ferdinand Columbia 转账给 Peggy Gayheart 的账户的邮箱、转账时间、Peggy Gayheart 的昵称以及 Ferdinand Columbia 的电话号码，跳过前2条结果，返回最多10条记录。
#
# 查找Peggy Gayheart的账户被其他账户转账的信息，包括转账双方的最后登录时间、账户ID、电话号码、账户类型、是否被封禁、账户等级、创建时间、昵称、常用登录方式、邮箱，以及转账金额和转账记录的创建时间。
#
# 查找从Peggy Gayheart账户中提现的账户的最后登录时间、登录频率类型、账户ID、提现时间、提现金额、账户是否被封禁、账户等级、账户类型、昵称以及Peggy Gayheart账户的相关信息。
#
# 查找Ferdinand Columbia账户提现的账户类型、昵称和创建时间
#
# 查找Milford Zolla的账户级别、他转账的目标账户昵称、他的电话号码以及目标账户的常用登录类型
#
# 查找Milford Zolla的账户信息，包括他的邮箱、账户级别、以及他转账给的账户的邮箱、账户类型、昵称、常用登录方式、转账时间及接收方账户的创建时间
#
# 查找Milford Zolla向Danica Gollhofer转账的账户信息，包括Milford Zolla的邮箱、账户ID、是否被封禁、常用登录类型、昵称、账户类型和最后登录时间，以及Danica Gollhofer的账户等级、邮箱、账户ID、是否被封禁、账户类型和最后登录时间，同时返回转账的创建时间。
#
# 查找Milford Zolla向Danica Gollhofer转账的记录，返回Milford Zolla的最后登录时间、Danica Gollhofer的是否被封禁状态、转账金额、Danica Gollhofer的邮箱、账户ID、Milford Zolla的创建时间、手机号、Danica Gollhofer的账户类型、Milford Zolla的账户等级、Milford Zolla的邮箱、Milford Zolla的常用登录方式、Danica Gollhofer的手机号，限制返回10条记录。
#
# 查找Drew Hamamoto向Peggy Gayheart转账的详细信息，包括Peggy Gayheart的邮箱、账户类型、创建时间、昵称、账户等级、是否被封禁、转账金额、账户ID、转账时间、登录频率类型，以及Drew Hamamoto的账户等级、邮箱、最后登录时间、账户ID、是否被封禁和创建时间。
#
# 查找向Peggy Gayheart转账的账户的昵称、账户类型、登录频率类型、创建时间、最后登录时间、转账金额、邮箱、是否被封禁、账户等级，以及Peggy Gayheart的账户类型、最后登录时间、邮箱、是否被封禁、账户ID、账户等级，限制返回7条结果
#
# 查找Quincy Palevic向Kacy Lenkiewicz转账的账户类型、Quincy Palevic的账户ID、Kacy Lenkiewicz的邮箱、Kacy Lenkiewicz的创建时间、Quincy Palevic的创建时间、Quincy Palevic的常用登录方式、Quincy Palevic的昵称、Kacy Lenkiewicz是否被封禁、转账的创建时间和转账金额以及Quincy Palevic的邮箱
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Quincy Palevic'的节点
# label为account,属性nickname='Kayleigh Lapinsky'的节点
# label为account,属性nickname='Kayleigh Lapinsky'的节点
# label为company,属性companyname='McKenzie-Predovic'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Quincy Palevic向Kacy Lenkiewicz转账的账户类型、Quincy Palevic的账户ID、Kacy Lenkiewicz的邮箱、Kacy Lenkiewicz的创建时间、Quincy Palevic的创建时间、Quincy Palevic的常用登录方式、Quincy Palevic的昵称、Kacy Lenkiewicz是否被封禁、转账的创建时间和转账金额以及Quincy Palevic的邮箱
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Quincy Palevic'的节点
# label为account,属性nickname='Kayleigh Lapinsky'的节点
# label为account,属性nickname='Kayleigh Lapinsky'的节点
# label为company,属性companyname='McKenzie-Predovic'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Quincy Palevic转账给的账户是否被封禁、转账金额、Quincy Palevic的创建时间和接收账户的电话号码，仅返回一条结果
#
# 查找Hugo Speir向Freeman Murchinson转账的账户ID、账户类型、转账金额，以及Freeman Murchinson的账户ID、登录频率类型、账户等级和电子邮件地址。
#
# 查找Hugo Speir进行账户提现操作的目标账户的邮箱、是否被封禁状态，以及Hugo Speir和目标账户的手机号码
#
# 查找Geraldine Bonnie向Luis Thies转账的账户信息，包括Geraldine Bonnie的电话号码、账户等级、电子邮件、最后登录时间、常用登录类型、账户类型、账户ID和是否被封禁；以及Luis Thies的账户ID、最后登录时间、常用登录类型、电话号码、昵称、账户类型、是否被封禁、电子邮件、创建时间和账户等级。
#
# 查找Geraldine Bonnie账户提现的时间
#
# 查找与Micah Claybrooks账户有提现关系的账户信息，包括双方的是否被封禁、电话号码、最后一次登录时间、创建时间、常用登录类型、账户类型、账户ID、账户等级以及关系的创建时间。同时返回Micah Claybrooks的昵称、电话号码、邮箱和账户等级。
#
# 查找Micah Claybrooks的账户类型、最后一次登录时间和创建时间，以及与之有资金往来关系的账户的账户类型、电话号码和电子邮件。
#
# 查找Hope Metherell的账户信息，包括她的最后登录时间、账户ID、昵称、手机号、账户等级、是否被封禁、邮箱、常用登录类型，以及与她有资金往来关系的账户的相同信息，同时返回该关系的创建时间和转账金额。
#
# 查找从Micah Claybrooks账户中提现的账户昵称、提现时间、Micah Claybrooks的最后登录时间、提现账户的电话号码、Micah Claybrooks的账户ID、账户等级和常用登录类型
#
# 查找Micah Claybrooks的账户级别、与其关联的账户的最后登录时间、账户类型、转账金额、关联账户的账户级别、电话号码和昵称，以及转账的创建时间
#
# 查找Mimi Voelkel账户转账给其他账户的信息，包括接收方的账户是否被封禁、常用登录类型、转账金额、Mimi Voelkel的账户等级、接收方的账户类型、双方的创建时间、接收方的昵称、Mimi Voelkel的手机号、账户ID、常用登录类型、账户类型、最后登录时间、接收方的账户等级、接收方的手机号、账户ID和邮箱。
#
# 查找从Micah Claybrooks账户中提现的账户的登录类型、昵称、账户等级、电话号码、账户等级、是否被封禁、账户ID，以及提现金额和目标账户的创建时间
#
# 查找Mimi Voelkel的账户信息及其转账给的账户信息，包括Mimi Voelkel的手机号、是否被封禁、创建时间、账户ID、邮箱、账户类型、账户等级，以及对方账户的是否被封禁、最后登录时间、账户等级、常用登录类型、手机号、昵称，同时返回转账的时间和金额。
#
# 查找Luis Thies的账户信息，包括创建时间、最后登录时间、昵称、账户类型、常用登录方式、转账金额、对方账户类型、对方账户级别、对方账户ID、对方邮箱、对方账户是否被封禁、对方常用登录方式、自己账户是否被封禁、自己账户创建时间、自己账户ID、自己邮箱、自己账户级别。
#
# 查找与Stephanie Pieters账户有关的账户提现记录，返回记录的创建时间，Stephanie Pieters的账户ID、邮箱、是否被封禁、账户等级、电话号码、账户类型，以及相关账户的账户等级、电话号码、账户ID和最后登录时间，跳过前7条记录，限制返回9条记录。
#
# 查找Arlena Penha账户的提现记录，返回提现时间、Arlena Penha的账户等级和提现金额
#
# 查找Arlena Penha从Edmund Sautter账户中提现的信息，包括Edmund Sautter的账户类型、创建时间、昵称、最后登录时间、是否被封禁、账户ID、邮箱、电话号码，以及Arlena Penha的账户ID、账户类型、邮箱、是否被封禁、最后登录时间、电话号码，还有提现记录的创建时间。
#
# 查找与Drew Hamamoto关联的贷款账户的详细信息，包括账户类型、贷款余额、电子邮件、账户级别、昵称、常用登录类型、是否被封禁、贷款金额、利率、创建时间、电话号码、最后登录时间、账户ID和贷款ID，以及关联的存款金额和创建时间。
#
# 查找Thresa Jiran的账户信息及其关联的贷款信息，包括账户的登录频率类型、最后登录时间、账户类型、是否被封锁、邮箱、电话号码、昵称、创建时间，以及贷款ID、贷款用途、贷款金额和关联关系的创建时间，仅返回一条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Thresa Jiran'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Thresa Jiran的账户信息及其关联的贷款信息，包括账户的登录频率类型、最后登录时间、账户类型、是否被封锁、邮箱、电话号码、昵称、创建时间，以及贷款ID、贷款用途、贷款金额和关联关系的创建时间，仅返回一条记录。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Thresa Jiran'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Randolph Gica的账户类型、贷款金额、最后登录时间和贷款创建时间
#
# 查找与Randolph Gica关联的账户的账户ID、账户等级、电子邮件和最后登录时间，以及与其关联的贷款的贷款ID、余额和贷款用途。
#
# 查找与Randolph Gica关联的贷款信息，包括贷款ID、余额、最近登录时间、电子邮件、账户类型、频繁登录类型、电话号码、利率、昵称和账户等级，限制返回15条记录。
#
# 查找Randolph Gica的账户创建时间、贷款金额、登录频率类型、贷款利率、账户等级、是否被封禁、账户ID、手机号、贷款余额、邮箱、贷款ID、昵称和贷款用途
#
# 查找与Faustino Marolf的账户关联的贷款信息，包括账户ID、贷款用途、贷款金额和余额，限制返回17条记录
#
# 查找与Faustino Marolf账户关联的贷款信息，返回该账户是否被冻结、账户类型以及贷款创建时间
#
# 查找与Faustino Marolf相关的贷款账户信息，包括账户的电话号码、电子邮件、是否被封禁、贷款的利率、账户和贷款的创建时间、关联关系的创建时间、账户类型、最后登录时间、常用登录类型、贷款ID、贷款金额、账户ID、昵称、账户等级、贷款余额和贷款用途，限制返回16条结果。
#
# 查找与Mildred Clever账户相关的贷款信息，包括账户的创建时间、贷款用途、账户ID、贷款利率、贷款余额、贷款金额、存款金额、贷款创建时间和账户昵称
#
# 跳过5条记录，查找与Mildred Clever关联的贷款信息，返回Mildred Clever的创建时间、昵称、电话号码、邮箱、账户类型、频繁登录类型，以及贷款的用途、创建时间、利率、余额、贷款ID，还有贷款与账户之间的关联金额和创建时间。
#
# 查找与Mildred Clever相关的贷款账户信息，包括账户最后登录时间、创建时间、昵称、贷款利率、余额、是否被封禁、账户类型、账户等级、账户ID、关联关系的创建时间、贷款ID、贷款创建时间、电话号码和贷款金额。
#
# 查找与Mildred Clever账户关联的贷款信息的创建时间和账户的昵称及最后登录时间
#
# 查找与Tori Spotorno相关的账户的邮箱、账户ID、贷款利率、账户类型、贷款创建时间、账户等级和贷款余额
#
# 查找与Tori Spotorno账户关联的贷款信息，包括贷款金额、利率、关联时间、贷款余额、贷款用途，以及账户的创建时间、是否被封禁、电子邮件、账户等级、电话号码和账户ID。
#
# 查找与Rachell Degree关联的贷款账户的详细信息，包括账户的创建时间、是否被封锁、账户ID、邮箱、账户类型、最后登录时间、电话号码、账户等级，以及贷款的余额、创建时间、贷款金额、利率、贷款用途和关联关系的金额及创建时间。
#
# 查找与Rachell Degree关联的贷款账户的账户等级、贷款利率、昵称、电话号码、电子邮件、账户ID、贷款用途、关联时间、是否被封锁以及常用登录类型
#
# 查找与Rachell Degree关联的贷款账户信息，包括账户ID、账户类型、常用登录类型、昵称、电话号码、邮箱、关系创建时间、是否被封禁、贷款利率、创建时间、贷款金额、贷款用途、最后登录时间以及贷款ID，限制返回11条结果。
#
# 查找与Rachell Degree相关的贷款账户信息，包括账户级别、贷款余额、关联时间、贷款金额、昵称、关联金额、手机号、贷款ID、利率、是否被封禁、账户ID、创建时间、邮箱、账户类型、最后登录时间和贷款用途，限制返回11条记录。
#
# 查找与Tori Spotorno账户关联的贷款信息，返回账户的创建时间、贷款用途、电子邮件、贷款金额、账户ID、账户类型、账户等级以及贷款余额
#
# 查找与Tori Spotorno账户关联的贷款的利率
#
# 查找与Cordelia Ratcliffe账户关联的贷款信息，包括账户最后登录时间、贷款利率、贷款金额、账户等级、账户创建时间、贷款ID、账户登录频率类型、账户类型、账户是否被封锁、贷款用途以及关联关系的创建时间，跳过前7条记录，返回接下来的20条记录。
#
# 查找与Cordelia Ratcliffe账户关联的贷款信息，包括贷款的创建时间、用途、余额，以及账户的最后登录时间、账户等级、电子邮件、是否被封禁、昵称、创建时间、常用登录类型、账户类型、关联关系的创建时间、电话号码和账户ID。
#
# 查找Cordelia Ratcliffe的账户关联的贷款金额和账户级别
#
# 查找与Cordelia Ratcliffe的账户关联的贷款信息，包括账户昵称、电话号码、贷款利率、关联时间、贷款用途、电子邮件、最后登录时间、账户等级、账户创建时间、贷款创建时间和关联金额
#
# 查找Kathleen Salvador的账户关联的贷款信息，包括贷款ID、账户等级、昵称、电话号码、常用登录类型、贷款创建时间、贷款金额、存款金额、贷款用途、账户创建时间、账户类型、贷款利率、账户ID和最后登录时间。
#
# 查找Kathleen Salvador的账户信息，包括邮箱、账户等级、创建时间、贷款用途、昵称、贷款创建时间、账户ID、是否被封禁、账户类型、频繁登录类型、贷款余额、贷款金额、关联关系的创建时间、电话号码、最后登录时间和贷款ID及利率。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找Kathleen Salvador的账户信息，包括邮箱、账户等级、创建时间、贷款用途、昵称、贷款创建时间、账户ID、是否被封禁、账户类型、频繁登录类型、贷款余额、贷款金额、关联关系的创建时间、电话号码、最后登录时间和贷款ID及利率。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Kathleen Salvador'的节点
# label为account,属性nickname='Kathleen Salvador'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找与Kathleen Salvador账户相关的贷款信息，包括贷款ID、账户创建时间、贷款金额、账户类型、贷款利率、贷款用途、账户昵称、关联金额、账户邮箱和账户ID
#
# 查找与Kathleen Salvador账户关联的贷款信息，包括贷款金额、账户最后一次登录时间、邮箱、账户ID、是否被封禁、贷款余额、创建时间和利率，最多返回13条记录。
#
# 查找与Pia Glasper账户关联的贷款信息，包括贷款利率、账户登录频率类型、账户ID、昵称、贷款ID、关联创建时间、贷款金额和账户等级
#
# 查找与Leonila Hagedorn关联的贷款账户的账户类型、最后登录时间、贷款金额、账户等级、邮箱、贷款余额、创建时间和昵称，并返回前19条记录
#
# 跳过5条记录，查找与Leonila Hagedorn账户关联的贷款信息，返回贷款ID、账户ID、昵称、登录频率类型、利率、账户创建时间、最后登录时间、贷款金额和贷款创建时间，限制返回1条记录。
#
# 查找与Leonila Hagedorn关联的贷款信息，包括账户是否被封锁、昵称、贷款余额、贷款创建时间、账户创建时间、账户等级、贷款金额、账户类型、贷款用途、电子邮件、贷款利率、关联金额、账户ID和最后登录时间，以及贷款ID。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Leonila Hagedorn'的节点
# label为account,属性nickname='Leonila Hagedorn'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找与Leonila Hagedorn关联的贷款信息，包括账户是否被封锁、昵称、贷款余额、贷款创建时间、账户创建时间、账户等级、贷款金额、账户类型、贷款用途、电子邮件、贷款利率、关联金额、账户ID和最后登录时间，以及贷款ID。
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Leonila Hagedorn'的节点
# label为account,属性nickname='Leonila Hagedorn'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Leonila Hagedorn的账户类型、与之关联的贷款创建时间、利率、昵称、关联关系的创建时间、贷款用途以及账户的邮箱地址
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Leonila Hagedorn'的节点
# label为account,属性nickname='Leonila Hagedorn'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找昵称为Leonila Hagedorn的账户类型、与之关联的贷款创建时间、利率、昵称、关联关系的创建时间、贷款用途以及账户的邮箱地址
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Leonila Hagedorn'的节点
# label为account,属性nickname='Leonila Hagedorn'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找与Leonila Hagedorn相关的贷款信息，返回她的电话号码、贷款创建时间、账户类型、最后登录时间、账户ID、贷款ID、电子邮件和昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Leonila Hagedorn'的节点
# label为account,属性nickname='Leonila Hagedorn'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找与Leonila Hagedorn相关的贷款信息，返回她的电话号码、贷款创建时间、账户类型、最后登录时间、账户ID、贷款ID、电子邮件和昵称
# 已知数据库中存在以下数据信息:
# label为account,属性nickname='Leonila Hagedorn'的节点
# label为account,属性nickname='Leonila Hagedorn'的节点
#
# ----------------------------------------------------------------------------------------------------
# 查找与Leonila Hagedorn相关的账户的最后登录时间、贷款ID、邮箱、贷款账户关联的创建时间和贷款的创建时间及用途
#
# 查找与Leonila Hagedorn账户关联的贷款信息，包括贷款金额、用途、创建时间、贷款ID、利率、余额，以及账户的电话号码、账户等级、邮箱、是否被封禁、常用登录类型、创建时间、昵称、账户类型和最后一次登录时间，同时返回贷款和账户之间的关联金额及创建时间。
#
# 查找与Leonila Hagedorn相关的贷款账户的登录频率类型、昵称、贷款金额、账户等级、贷款创建时间和邮箱。
#
# 查找与Marcel Sutley的账户相关的贷款信息，包括贷款创建时间、账户等级、贷款金额、账户邮箱、贷款余额、关联金额、账户创建时间和账户ID，以及贷款ID和贷款创建时间。
#
# 查找与Tori Spotorno关联的贷款账户的账户ID、电话号码、贷款创建时间、常用登录类型、贷款ID、昵称以及贷款账户关联关系的创建时间和金额
#
# 查找与Tori Spotorno关联的贷款信息，包括账户最后登录时间、贷款用途、贷款余额、贷款ID、账户登录频率类型、昵称、关系创建时间、账户ID、邮箱、电话号码、账户创建时间、贷款金额、账户等级、贷款创建时间、关系金额、账户类型、账户是否被封锁以及贷款利率。
#
# 查找与Tori Spotorno关联的贷款账户的登录频率类型、账户级别、账户类型和是否被封锁，最多返回13条记录
#
# 查找与Tori Spotorno账户关联的贷款信息，包括账户的最后登录时间、账户等级、贷款用途、账户创建时间、贷款余额、账户邮箱、贷款金额、账户电话号码、贷款利率、贷款金额、账户是否被封禁、账户ID、账户昵称、账户类型、关联关系的创建时间和贷款ID、贷款创建时间，跳过前8条记录，返回接下来的12条记录。
#
# 查找与Merry Hairster关联的贷款账户的登录频率类型、贷款余额、电话号码、账户类型、关联创建时间、贷款利率和贷款用途
#
# 查找与Conrad Raugust相关的贷款账户的登录频率类型、创建时间、账户等级、贷款余额、贷款用途、昵称、贷款利率以及关联金额和创建时间，限制返回2条结果
#
# 查找Noe Trites的账户级别、创建时间、常用登录类型、账户类型、关联贷款的利率、是否被封禁、贷款创建时间、最后登录时间、账户ID、关联金额、昵称、贷款余额、贷款ID、邮箱、电话号码和账户创建时间。
#
# 查找与Deon Villagrana关联的贷款账户的创建时间、贷款金额、最后一次登录时间、账户等级和昵称，以及贷款金额和余额，跳过前10条记录，返回接下来的12条记录。
#
# 查找与Deon Villagrana相关的贷款账户的详细信息，包括账户的电子邮件、常用登录类型、账户级别、创建时间、贷款余额、是否被封禁、账户ID、最后登录时间、贷款用途、贷款金额、贷款ID、电话号码、贷款利率、账户类型以及关联关系的创建时间和金额。
#
# 查找与Rosina Carovski关联的贷款账户的详细信息，包括账户类型、是否被封锁、贷款用途、登录频率类型、账户ID、创建时间、账户等级、昵称、关系创建时间、邮箱、电话号码以及贷款余额，跳过前5条记录，返回接下来的19条记录。
