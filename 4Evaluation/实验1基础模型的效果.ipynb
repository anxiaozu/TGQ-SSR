# %%
'''
## 基础模型测试

## 语法正确率


GLM4 9B
GEMMA 9B
LLAma 8B
Qwen7B  
四种模型  四种prompt 未训练的时候评估

'''
import json
files = [
"/home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_normal_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_schema_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_schema_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_normal_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_schema_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_schema_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_vector_prompt.json_fix.json_result.json", 
"/home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_normal_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_schema_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_schema_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_normal_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_schema_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_schema_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_vector_prompt.json_fix.json_result.json",
]
import json

NP_data = []
SP_data = []
SVP_data = []
VP_data = []


for index,file in enumerate(files) :
    with open(file, 'r',encoding="utf-8") as json_file:
        GLM49B_train_normal_prompt = json.load(json_file)
    err_num = 0
    for row in   GLM49B_train_normal_prompt:
        if row['err'] == True:
            err_num = err_num+1
    
    print(f"{file}结果大小:{len(GLM49B_train_normal_prompt)}.错误个数:{err_num},语法正确率为{100-(err_num/len(GLM49B_train_normal_prompt)*100)}")
    
    if index % 4 == 0:
        NP_data.append(100-(err_num/len(GLM49B_train_normal_prompt)*100))
    if index % 4 == 1:
        SP_data.append(100-(err_num/len(GLM49B_train_normal_prompt)*100))
    if index % 4 == 2:
        SVP_data.append(100-(err_num/len(GLM49B_train_normal_prompt)*100))
    if index % 4 == 3:
        VP_data.append(100-(err_num/len(GLM49B_train_normal_prompt)*100))
# Out:
# /home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_normal_prompt.json_fix.json_result.json结果大小:385.错误个数:384,语法正确率为0.25974025974025494
# /home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_schema_prompt.json_fix.json_result.json结果大小:385.错误个数:162,语法正确率为57.922077922077925
# /home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_schema_vector_prompt.json_fix.json_result.json结果大小:385.错误个数:86,语法正确率为77.66233766233766
# /home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_vector_prompt.json_fix.json_result.json结果大小:385.错误个数:309,语法正确率为19.74025974025973
# /home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_normal_prompt.json_fix.json_result.json结果大小:385.错误个数:335,语法正确率为12.987012987012989
# /home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_schema_prompt.json_fix.json_result.json结果大小:385.错误个数:251,语法正确率为34.8051948051948
# /home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_schema_vector_prompt.json_fix.json_result.json结果大小:385.错误个数:233,语法正确率为39.48051948051948
# /home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_vector_prompt.json_fix.json_result.json结果大小:385.错误个数:279,语法正确率为27.532467532467535
# /home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_normal_prompt.json_fix.json_result.json结果大小:385.错误个数:367,语法正确率为4.675324675324674
# /home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_schema_prompt.json_fix.json_result.json结果大小:385.错误个数:264,语法正确率为31.42857142857143
# /home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_schema_vector_prompt.json_fix.json_result.json结果大小:385.错误个数:162,语法正确率为57.922077922077925
# /home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_vector_prompt.json_fix.json_result.json结果大小:385.错误个数:309,语法正确率为19.74025974025973
# /home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_normal_prompt.json_fix.json_result.json结果大小:385.错误个数:326,语法正确率为15.324675324675326
# /home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_schema_prompt.json_fix.json_result.json结果大小:385.错误个数:126,语法正确率为67.27272727272728
# /home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_schema_vector_prompt.json_fix.json_result.json结果大小:385.错误个数:101,语法正确率为73.76623376623377
# /home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_vector_prompt.json_fix.json_result.json结果大小:385.错误个数:306,语法正确率为20.51948051948051

# %%
### 语义正确率分析  精确率 召回率  行、列分别分析
import json


with open("/home/work/liuytest/大论文/4评估/ldbc_normal_test_7_3.json_result.json", 'r',encoding="utf-8") as json_file:
    core_train_result = json.load(json_file)

files = [
"/home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_normal_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_schema_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_schema_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_normal_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_schema_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_schema_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_vector_prompt.json_fix.json_result.json", 
"/home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_normal_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_schema_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_schema_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_normal_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_schema_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_schema_vector_prompt.json_fix.json_result.json",
"/home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_vector_prompt.json_fix.json_result.json",
]

NP_data_recall = []
SP_data_recall = []
SVP_data_recall = []
VP_data_recall = []

NP_data_precision = []
SP_data_precision = []
SVP_data_precision = []
VP_data_precision = []

with open("/home/work/liuytest/大论文/4评估/ldbc_normal_test_7_3.json_result.json", 'r',encoding="utf-8") as json_file:
    core_train_result = json.load(json_file)

print("对比结果的大小:",len(core_train_result))

for file_index,file in enumerate(files) :
    with open(file, 'r',encoding="utf-8") as json_file:
        GLM49B_train_normal_prompt = json.load(json_file)
    err_num = 0
    total_recall=0
    total_precision = 0
    for index,row in   enumerate(GLM49B_train_normal_prompt) :

        if row['err'] == True:
            err_num = err_num+1
            single_query_recall = 0
            single_query_precision = 0
        else:
            correct_row = core_train_result[index]
            if correct_row['output'] == row['output']:
                print("bangbangbangbangbangbangbangbangbangbangbangbangbangbang")
            label_rows =  correct_row['rows']
            
            pred_rows = row['rows']
            
            len_total_row = len(label_rows)
            
            if len_total_row != len(pred_rows):
                single_query_recall = 0
                single_query_precision = 0
            else:
                recall=0
                precision = 0
                for index,label_row in  enumerate(label_rows):
                    label_row = [str(data) for data in list(label_row)]
                    pred_colums_set = set(label_row)
                    pred_row = pred_rows[index]
                    pred_row = [str(data) for data in list(pred_row)]
                    label_colums_set = set(pred_row)
                    intersection = pred_colums_set.intersection(label_colums_set)
                    if len(intersection) == len(label_colums_set):
                        # print("colum bangbangbang")
                        pass
                    ### 列的语义分析准确率     回收率
                    recall =  recall+ len(intersection)/len(label_colums_set) *100  
                    ### 列的语义分析准确率     精确率
                    precision = precision + len(intersection)/len(pred_colums_set) *100 
                single_query_recall = recall/len_total_row
                single_query_precision = precision/len_total_row 
        total_recall = total_recall + single_query_recall
        total_precision = total_precision + single_query_precision
    total_recall = total_recall/len(GLM49B_train_normal_prompt)
    total_precision= total_precision/len(GLM49B_train_normal_prompt)                                        
    print(f"{file}的语义回收率为{total_recall}，语义精确率为{total_precision}") 
    if file_index % 4 == 0:
        NP_data_recall.append(total_recall)
        NP_data_precision.append(total_precision)
    if file_index % 4 == 1:
        SP_data_recall.append(total_recall)
        SP_data_precision.append(total_precision)
    if file_index % 4 == 2:
        SVP_data_recall.append(total_recall)
        SVP_data_precision.append(total_precision)
    if file_index % 4 == 3:
        VP_data_recall.append(total_recall)
        VP_data_precision.append(total_precision)
# Out:
# 对比结果的大小: 385
# /home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_normal_prompt.json_fix.json_result.json的语义回收率为0.0，语义精确率为0.0
# /home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_schema_prompt.json_fix.json_result.json的语义回收率为20.400537601879144，语义精确率为20.11617261902921
# /home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_schema_vector_prompt.json_fix.json_result.json的语义回收率为31.87548116201192，语义精确率为31.9273752770417
# /home/work/liuytest/大论文/4评估/1数据预处理/gemma9B_base_vector_prompt.json_fix.json_result.json的语义回收率为10.85930735930736，语义精确率为10.673675530818388
# /home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_normal_prompt.json_fix.json_result.json的语义回收率为2.2943722943722946，语义精确率为2.207792207792208
# /home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_schema_prompt.json_fix.json_result.json的语义回收率为14.980913256875306，语义精确率为15.023005565862707
# /home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_schema_vector_prompt.json_fix.json_result.json的语义回收率为19.70175516093883，语义精确率为19.0318518156864
# /home/work/liuytest/大论文/4评估/1数据预处理/Qwen2.57B_base_vector_prompt.json_fix.json_result.json的语义回收率为10.523191094619666，语义精确率为9.411564625850339
# /home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_normal_prompt.json_fix.json_result.json的语义回收率为0.0，语义精确率为0.0
# /home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_schema_prompt.json_fix.json_result.json的语义回收率为7.015253865903216，语义精确率为6.793386591027726
# /home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_schema_vector_prompt.json_fix.json_result.json的语义回收率为19.519362868334923，语义精确率为19.28166117608778
# /home/work/liuytest/大论文/4评估/1数据预处理/LLama8B_base_vector_prompt.json_fix.json_result.json的语义回收率为9.196660482374769，语义精确率为8.929086786229643
# /home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_normal_prompt.json_fix.json_result.json的语义回收率为1.2987012987012987，语义精确率为1.2987012987012987
# /home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_schema_prompt.json_fix.json_result.json的语义回收率为18.284443045403375，语义精确率为18.285926353053192
# /home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_schema_vector_prompt.json_fix.json_result.json的语义回收率为32.29839547436178，语义精确率为32.09786963047548
# /home/work/liuytest/大论文/4评估/1数据预处理/GLM49B_base_vector_prompt.json_fix.json_result.json的语义回收率为8.837950103846058，语义精确率为8.414616853923212

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
# plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题


species = ['GEMMA','QWEN','LLAMA','GLM']
penguin_means = {
    'NP':NP_data,
    'SP':SP_data,
    'SVP': SVP_data,
    'VP':VP_data,
}

x = np.arange(0,len(species)*2,step=2)  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize =(20, 7))


index_plot = 0
for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    if index_plot%2==0:
        multiplier = multiplier
        x_bar =x +   offset
    else:
        x_bar = x + offset
    index_plot= index_plot+1   
    rects = ax.bar(x_bar, measurement, width, label=attribute)
    
    for i, val in enumerate(measurement):
        if val == 0:
            ax.bar(x_bar[i], 100,width,hatch='/',color= rects[i].get_facecolor())  # 在柱状图上添加文本标记
    
    # ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('%')
ax.set_title('SYA')
ax.set_xticks(x + width*3, species)
ax.legend(loc='upper left', ncols=1)

plt.show()

# %%
## 语义正确率柱状图分析

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
# plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题


species = ['GEMMA','QWEN','LLAMA','GLM']
penguin_means = {
    'NP':NP_data_recall,
    'SP':SP_data_recall,
    'SVP': SVP_data_recall,
    'VP':VP_data_recall,
}

x = np.arange(0,len(species)*2,step=2)  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize =(20, 7))


index_plot = 0
for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    if index_plot%2==0:
        multiplier = multiplier
        x_bar =x +   offset
    else:
        x_bar = x + offset
    index_plot= index_plot+1   
    rects = ax.bar(x_bar, measurement, width, label=attribute)
    
    for i, val in enumerate(measurement):
        if val == 0:
            ax.bar(x_bar[i], 100,width,hatch='/',color= rects[i].get_facecolor())  # 在柱状图上添加文本标记
    
    # ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('%')
ax.set_title('SYA')
ax.set_xticks(x + width*3, species)
ax.legend(loc='upper left', ncols=1)

plt.show()

# %%
## 语义正确率柱状图分析

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
# plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题


species = ['GEMMA','QWEN','LLAMA','GLM']
penguin_means = {
    'NP':NP_data_precision,
    'SP':SP_data_precision,
    'SVP': SVP_data_precision,
    'VP':VP_data_precision,
}

x = np.arange(0,len(species)*2,step=2)  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize =(20, 7))


index_plot = 0
for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    if index_plot%2==0:
        multiplier = multiplier
        x_bar =x +   offset
    else:
        x_bar = x + offset
    index_plot= index_plot+1   
    rects = ax.bar(x_bar, measurement, width, label=attribute)
    
    for i, val in enumerate(measurement):
        if val == 0:
            ax.bar(x_bar[i], 100,width,hatch='/',color= rects[i].get_facecolor())  # 在柱状图上添加文本标记
    
    # ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('%')
ax.set_title('SYA')
ax.set_xticks(x + width*3, species)
ax.legend(loc='upper left', ncols=1)

plt.show()
