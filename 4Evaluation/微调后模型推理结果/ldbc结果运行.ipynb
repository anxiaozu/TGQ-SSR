# %%
import json
import psycopg

ori_query = [

    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_normal_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_schema_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_schema_vector_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_vector_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_train_normal_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_train_schema_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_train_schema_vector_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_train_vector_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_base_normal_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_base_schema_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_base_schema_vector_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_base_vector_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_train_normal_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_train_schema_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_train_schema_vector_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_train_vector_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/model_size_Qwen2.50.5B_my_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/model_size_Qwen2.51.5B_my_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/model_size_Qwen2.53B_my_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/model_size_Qwen2.57B_my_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/model_size_Qwen2.514B_my_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/model_size_Qwen2.532B_my_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_base_normal_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_base_schema_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_base_schema_vector_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_base_vector_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_train_normal_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_train_schema_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_train_schema_vector_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_train_vector_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_1_9_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_2_8_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_3_7_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_4_6_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_5_5_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_6_4_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_7_3_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_8_2_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/scala_9_1_Qwen2.57B_my_prompt.json", 
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/GLM49B_train_normal_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/GLM49B_train_schema_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/GLM49B_train_schema_vector_prompt.json",
    "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/GLM49B_train_vector_prompt.json",
]

pg_con = psycopg.connect(
            dbname="postgres",
            host="localhost",
            user="omm",
            password="ZAQ1234@esz",
            port=5432,
            options="-c statement_timeout=10000"
            ) 
pg_con.autocommit=True        
cur = pg_con.cursor()
cur.execute("set graph_path = ldbc")


for query_file in ori_query:
    print(query_file)
    all = query_file.split("/")
    file_name = all[len(all)-1]
    result = []
    
    query_pair = None
    with open(query_file, 'r',encoding="utf-8") as json_file:
        key_values = json.load(json_file)
    
    for query_row in key_values:
        try:    
            cur.execute(query_row["output"])
            # 这里应该把结果处理成表格  最后就好计算了
            rows = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("数据的总行数:",len(rows))
            print("数据的总列数:",len(column_names))
            query_result = len(rows)
            result.append({"instruction":query_row["instruction"],"output":query_row["output"],"column_names":column_names,"rows":rows,"err":False})
        except Exception as e:
            result.append({"instruction":query_row["instruction"],"output":query_row["output"],"column_names":None,"rows":None,"err":True})    
    # 方法一：使用json.dump()函数保存为JSON格式并写入文件
    with open(f"{file_name}_result.json", "w") as file:
        json.dump(result, file,indent=4,ensure_ascii=False,)
        
pg_con.close()
# Out:
# /home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_normal_prompt.json
# /home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_schema_prompt.json
# /home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_schema_vector_prompt.json
# /home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_vector_prompt.json
# /home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_train_normal_prompt.json
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 1
# 数据的总行数: 1
# 数据的总列数: 1
# 数据的总行数: 0
# 数据的总列数: 2
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 2
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 1
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 2
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 2
# 数据的总行数: 0
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 1
# 数据的总列数: 2
# 数据的总行数: 1
# 数据的总列数: 4
# 数据的总行数: 0
# 数据的总列数: 1
# 数据的总行数: 1
# 数据的总列数: 2
# 数据的总行数: 13
# ...

# %%
## 通过数据库的base_schema pattern 查询数据库 生成带有 where return order by
import json
import psycopg

ori_query = [
 "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_normal_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_schema_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_schema_vector_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_vector_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_base_normal_prompt.json_fix.json",
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_base_schema_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_base_schema_vector_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/LLama8B_base_vector_prompt.json_fix.json",
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_base_normal_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_base_schema_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_base_schema_vector_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/Qwen2.57B_base_vector_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/GLM49B_base_normal_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/GLM49B_base_schema_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/GLM49B_base_schema_vector_prompt.json_fix.json", 
  "/home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/GLM49B_base_vector_prompt.json_fix.json", 

]

pg_con = psycopg.connect(
            dbname="postgres",
            host="localhost",
            user="omm",
            password="ZAQ1234@esz",
            port=5432,
            options="-c statement_timeout=10000"
            ) 
pg_con.autocommit=True        
cur = pg_con.cursor()
cur.execute("set graph_path = ldbc")


for query_file in ori_query:
    print(query_file)
    all = query_file.split("/")
    file_name = all[len(all)-1]
    result = []
    
    query_pair = None
    with open(query_file, 'r',encoding="utf-8") as json_file:
        key_values = json.load(json_file)
    
    for query_row in key_values:
        try:    
            cur.execute(query_row["output"])
            # 这里应该把结果处理成表格  最后就好计算了
            rows = cur.fetchall()
            column_names = [desc[0] for desc in cur.description]
            print("数据的总行数:",len(rows))
            print("数据的总列数:",len(column_names))
            query_result = len(rows)
            result.append({"instruction":query_row["instruction"],"output":query_row["output"],"column_names":column_names,"rows":rows,"err":False})
        except Exception as e:
            result.append({"instruction":query_row["instruction"],"output":query_row["output"],"column_names":None,"rows":None,"err":True})    
    # 方法一：使用json.dump()函数保存为JSON格式并写入文件
    with open(f"{file_name}_result.json", "w") as file:
        json.dump(result, file,indent=4,ensure_ascii=False,)
        
pg_con.close()
# Out:
# /home/work/liuytest/LLaMA-Factory/src/llamafactory/chat/gemma9B_base_normal_prompt.json_fix.json
# 数据的总行数: 1
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 7
# 数据的总行数: 0
# 数据的总列数: 7
# 数据的总行数: 0
# 数据的总列数: 4
# 数据的总行数: 0
# 数据的总列数: 4
# 数据的总行数: 0
# 数据的总列数: 6
# 数据的总行数: 0
# 数据的总列数: 5
# 数据的总行数: 0
# 数据的总列数: 6
# 数据的总行数: 0
# 数据的总列数: 9
# 数据的总行数: 0
# 数据的总列数: 9
# 数据的总行数: 0
# 数据的总列数: 8
# 数据的总行数: 1
# 数据的总列数: 2
# 数据的总行数: 1
# 数据的总列数: 1
# 数据的总行数: 0
# 数据的总列数: 2
# 数据的总行数: 1
# 数据的总列数: 2
# 数据的总行数: 1
# 数据的总列数: 1
# 数据的总行数: 1
# 数据的总列数: 1
# 数据的总行数: 1
# 数据的总列数: 4
# 数据的总行数: 1
# 数据的总列数: 1
# 数据的总行数: 0
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 2
# 数据的总行数: 0
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 1
# 数据的总行数: 0
# 数据的总列数: 2
# 数据的总行数: 0
# 数据的总列数: 2
# 数据的总行数: 0
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 14
# 数据的总行数: 0
# 数据的总列数: 3
# 数据的总行数: 0
# 数据的总列数: 7
# 数据的总行数: 0
# 数据的总列数: 5
# 数据的总行数: 0
# 数据的总列数: 1
# 数据的总行数: 0
# 数据的总列数: 2
# 数据的总行数: 0
# 数据的总列数: 2
# 数据的总行数: 0
# 数据的总列数: 6
# 数据的总行数: 0
# ...
